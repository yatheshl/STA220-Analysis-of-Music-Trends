# %%
# Importing necessary libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Creating empty lists to store song titles and artists
song_titles = []
song_artists = []

# %%
# Defining the URL to scrape
link = "https://www.billboard.com/charts/year-end/2022/hot-rap-songs/"

# Using requests library to make a GET request to the URL and store the response
response = requests.get(link)

# print(response.status_code)

# Using BeautifulSoup library to parse the HTML content of the response text and create a BeautifulSoup object
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Loop through all the HTML elements with class "o-chart-results-list-row-container"
for song in soup.find_all("div", class_="o-chart-results-list-row-container"):
    # Find the first h3 element with class "c-title" inside the current element
    song_name = song.find_all("h3", class_="c-title")
    # Append the text content of this element to the song_titles list
    song_titles.append(song_name[0].text.strip())
    # Print the song name (without leading/trailing whitespace) to the console
    print(song_name[0].text.strip(), end=", ")
    
    # Find the second span element with class "c-label" inside the current element
    song_artist = song.find_all("span", class_="c-label")
    # Append the text content of this element to the song_artists list
    song_artists.append(song_artist[1].text.strip())
    # Print the song artist (without leading/trailing whitespace) to the console
    print(song_artist[1].text.strip())
# Out:
# First Class, Jack Harlow
# Wait For U, Future Featuring Drake & Tems
# Big Energy, Latto
# Super Gremlin, Kodak Black
# Industry Baby, Lil Nas X & Jack Harlow
# Jimmy Cooks, Drake Featuring 21 Savage
# Vegas, Doja Cat
# In A Minute, Lil Baby
# Pushin P, Gunna & Future Featuring Young Thug
# Sweetest Pie, Megan Thee Stallion & Dua Lipa
# Super Freaky Girl, Nicki Minaj
# Knife Talk, Drake Featuring 21 Savage & Project Pat
# Way 2 Sexy, Drake Featuring Future & Young Thug
# Broadway Girls, Lil Durk Featuring Morgan Wallen
# What Happened To Virgil, Lil Durk Featuring Gunna
# Puffin On Zootiez, Future
# Girls Want Girls, Drake Featuring Lil Baby
# To The Moon!, JNR CHOI & Sam Tompkins
# Sticky, Drake
# Who Want Smoke??, Nardo Wick Featuring G Herbo, Lil Durk & 21 Savage
# Betty (Get Money), Yung Gravy
# Cooped Up, Post Malone Featuring Roddy Ricch
# F.N.F. (Let's Go), Hitkidd & GloRilla
# Staying Alive, DJ Khaled Featuring Drake & Lil Baby
# Sleazy Flow, SleazyWorld Go Featuring Lil Baby
# Right On, Lil Baby
# Get Into It (Yuh), Doja Cat
# By Your Side, Rod Wave
# Do We Have A Problem?, Nicki Minaj X Lil Baby
# Hot Shit, Cardi B, Ye & Lil Durk
# Silent Hill, Kendrick Lamar & Kodak Black
# Freaky Deaky, Tyga X Doja Cat
# Me Or Sum, Nardo Wick, Lil Baby & Future
# Ahhh Ha, Lil Durk
# P Power, Gunna Featuring Drake
# Nail Tech, Jack Harlow
# Scorpio, Moneybagg Yo
# Tomorrow 2, GloRilla & Cardi B
# Hotel Lobby (Unc And Phew), Quavo & Takeoff
# Too Easy, Gunna & Future
# N95, Kendrick Lamar
# Rumors, Gucci Mane Featuring Lil Durk
# Chosen, Blxst & Tyga Featuring Ty Dolla $ign
# Dah Dah DahDah, Nardo Wick
# Handsomer, Russ Featuring Ktlyn
# Already Dead, Juice WRLD
# Family Ties, Baby Keem & Kendrick Lamar
# Alone, Rod Wave
# Plan B, Megan Thee Stallion
# Billie Eilish., Armani White

# %%
# Slice the lists to keep only the first 51 elements
song_titles = song_titles[0:51]
song_artists = song_artists[0:51]

# %%
# Print the number of songs and artists captured from the webpage
print(len(song_titles))
print(len(song_artists))
# Out:
# 50
# 50

# %%
# Create a new pandas DataFrame from a list of song titles and artists
df = pd.DataFrame(list(zip(song_titles, song_artists)), columns=['Song Title', 'Artist'])

# %%
#printing the DataFrame
df
# Out:
#                     Song Title  \
# 0                  First Class
# 1                   Wait For U
# 2                   Big Energy
# 3                Super Gremlin
# 4                Industry Baby
# 5                  Jimmy Cooks
# 6                        Vegas
# 7                  In A Minute
# 8                     Pushin P
# 9                 Sweetest Pie
# 10           Super Freaky Girl
# 11                  Knife Talk
# 12                  Way 2 Sexy
# 13              Broadway Girls
# 14     What Happened To Virgil
# 15           Puffin On Zootiez
# 16            Girls Want Girls
# 17                To The Moon!
# 18                      Sticky
# 19            Who Want Smoke??
# 20           Betty (Get Money)
# 21                   Cooped Up
# 22           F.N.F. (Let's Go)
# 23               Staying Alive
# 24                 Sleazy Flow
# 25                    Right On
# 26           Get Into It (Yuh)
# 27                By Your Side
# 28       Do We Have A Problem?
# 29                    Hot Shit
# 30                 Silent Hill
# 31                Freaky Deaky
# 32                   Me Or Sum
# 33                     Ahhh Ha
# 34                     P Power
# 35                   Nail Tech
# 36                     Scorpio
# 37                  Tomorrow 2
# 38  Hotel Lobby (Unc And Phew)
# 39                    Too Easy
# 40                         N95
# 41                      Rumors
# 42                      Chosen
# 43              Dah Dah DahDah
# 44                   Handsomer
# 45                Already Dead
# 46                 Family Ties
# 47                       Alone
# 48                      Plan B
# 49              Billie Eilish.
#
#                                                Artist
# 0                                         Jack Harlow
# 1                       Future Featuring Drake & Tems
# 2                                               Latto
# 3                                         Kodak Black
# 4                             Lil Nas X & Jack Harlow
# 5                           Drake Featuring 21 Savage
# 6                                            Doja Cat
# 7                                            Lil Baby
# 8                 Gunna & Future Featuring Young Thug
# 9                      Megan Thee Stallion & Dua Lipa
# 10                                        Nicki Minaj
# 11            Drake Featuring 21 Savage & Project Pat
# 12                Drake Featuring Future & Young Thug
# 13                   Lil Durk Featuring Morgan Wallen
# 14                           Lil Durk Featuring Gunna
# 15                                             Future
# 16                           Drake Featuring Lil Baby
# 17                            JNR CHOI & Sam Tompkins
# 18                                              Drake
# 19  Nardo Wick Featuring G Herbo, Lil Durk & 21 Sa...
# 20                                         Yung Gravy
# 21                  Post Malone Featuring Roddy Ricch
# 22                                 Hitkidd & GloRilla
# 23               DJ Khaled Featuring Drake & Lil Baby
# 24                  SleazyWorld Go Featuring Lil Baby
# 25                                           Lil Baby
# 26                                           Doja Cat
# 27                                           Rod Wave
# 28                             Nicki Minaj X Lil Baby
# 29                             Cardi B, Ye & Lil Durk
# 30                       Kendrick Lamar & Kodak Black
# 31                                    Tyga X Doja Cat
# 32                      Nardo Wick, Lil Baby & Future
# 33                                           Lil Durk
# 34                              Gunna Featuring Drake
# 35                                        Jack Harlow
# 36                                       Moneybagg Yo
# 37                                 GloRilla & Cardi B
# 38                                    Quavo & Takeoff
# 39                                     Gunna & Future
# 40                                     Kendrick Lamar
# 41                      Gucci Mane Featuring Lil Durk
# 42               Blxst & Tyga Featuring Ty Dolla $ign
# 43                                         Nardo Wick
# 44                               Russ Featuring Ktlyn
# 45                                         Juice WRLD
# 46                         Baby Keem & Kendrick Lamar
# 47                                           Rod Wave
# 48                                Megan Thee Stallion
# 49                                       Armani White

# %%
# Define a regular expression pattern to match strings containing '&', 'Featuring', or 'X'
pattern = r'\s&.+|\sFeaturing.+|\sX.+'

# Use the pattern to replace any matching substrings in the 'Artist' column of the DataFrame with an empty string
df['Artist'] = df['Artist'].str.replace(pattern, '', regex=True)

# Display the updated DataFrame
df
# Out:
#                     Song Title                Artist
# 0                  First Class           Jack Harlow
# 1                   Wait For U                Future
# 2                   Big Energy                 Latto
# 3                Super Gremlin           Kodak Black
# 4                Industry Baby               Lil Nas
# 5                  Jimmy Cooks                 Drake
# 6                        Vegas              Doja Cat
# 7                  In A Minute              Lil Baby
# 8                     Pushin P                 Gunna
# 9                 Sweetest Pie   Megan Thee Stallion
# 10           Super Freaky Girl           Nicki Minaj
# 11                  Knife Talk                 Drake
# 12                  Way 2 Sexy                 Drake
# 13              Broadway Girls              Lil Durk
# 14     What Happened To Virgil              Lil Durk
# 15           Puffin On Zootiez                Future
# 16            Girls Want Girls                 Drake
# 17                To The Moon!              JNR CHOI
# 18                      Sticky                 Drake
# 19            Who Want Smoke??            Nardo Wick
# 20           Betty (Get Money)            Yung Gravy
# 21                   Cooped Up           Post Malone
# 22           F.N.F. (Let's Go)               Hitkidd
# 23               Staying Alive             DJ Khaled
# 24                 Sleazy Flow        SleazyWorld Go
# 25                    Right On              Lil Baby
# 26           Get Into It (Yuh)              Doja Cat
# 27                By Your Side              Rod Wave
# 28       Do We Have A Problem?           Nicki Minaj
# 29                    Hot Shit           Cardi B, Ye
# 30                 Silent Hill        Kendrick Lamar
# 31                Freaky Deaky                  Tyga
# 32                   Me Or Sum  Nardo Wick, Lil Baby
# 33                     Ahhh Ha              Lil Durk
# 34                     P Power                 Gunna
# 35                   Nail Tech           Jack Harlow
# 36                     Scorpio          Moneybagg Yo
# 37                  Tomorrow 2              GloRilla
# 38  Hotel Lobby (Unc And Phew)                 Quavo
# 39                    Too Easy                 Gunna
# 40                         N95        Kendrick Lamar
# 41                      Rumors            Gucci Mane
# 42                      Chosen                 Blxst
# 43              Dah Dah DahDah            Nardo Wick
# 44                   Handsomer                  Russ
# 45                Already Dead            Juice WRLD
# 46                 Family Ties             Baby Keem
# 47                       Alone              Rod Wave
# 48                      Plan B   Megan Thee Stallion
# 49              Billie Eilish.          Armani White

# %%
# Open the file "SpotifyAPI.txt" in read mode
with open("SpotifyAPI.txt", "r") as f:
    File = f.read()

# Extract the client ID from the first line of the file
client_id = File.split("\n")[0]
client_id = client_id.split(":")[1]
client_id = client_id.strip()

# Extract the client secret from the second line of the file
client_secret = File.split("\n")[1]
client_secret = client_secret.split(":")[1]
client_secret = client_secret.strip()

# %%
# Create a Spotify client credentials manager using the client ID and client secret
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)

# Create a new Spotify object with the client credentials manager
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Use the Spotify object to search for a track by name and artist
result = sp.search(q='track:sicko mode artist:travis scott', type='track')

# Print the Spotify URI of the first result
print(result['tracks']['items'][0]['uri'])
# Out:
# spotify:track:2xLMifQCjDGFmkHkpNLD9h

# %%
# Create an empty list to store the Spotify URIs
uri = []

# Loop through each row of the DataFrame
for i, row in df.iterrows():
    
    # Use the Spotify object to search for a track by name and artist
    results = sp.search(q=f'track:'+row["Song Title"]+' artist:'+row["Artist"], type='track')
    
    # Get the Spotify URI of the first result and append it to the URI list
    uri.append(results['tracks']['items'][0]['uri'])

# Add the URI column to the DataFrame
df['URI'] = uri

# Print the updated DataFrame
df
# Out:
#                     Song Title                Artist  \
# 0                  First Class           Jack Harlow
# 1                   Wait For U                Future
# 2                   Big Energy                 Latto
# 3                Super Gremlin           Kodak Black
# 4                Industry Baby               Lil Nas
# 5                  Jimmy Cooks                 Drake
# 6                        Vegas              Doja Cat
# 7                  In A Minute              Lil Baby
# 8                     Pushin P                 Gunna
# 9                 Sweetest Pie   Megan Thee Stallion
# 10           Super Freaky Girl           Nicki Minaj
# 11                  Knife Talk                 Drake
# 12                  Way 2 Sexy                 Drake
# 13              Broadway Girls              Lil Durk
# 14     What Happened To Virgil              Lil Durk
# 15           Puffin On Zootiez                Future
# 16            Girls Want Girls                 Drake
# 17                To The Moon!              JNR CHOI
# 18                      Sticky                 Drake
# 19            Who Want Smoke??            Nardo Wick
# 20           Betty (Get Money)            Yung Gravy
# 21                   Cooped Up           Post Malone
# 22           F.N.F. (Let's Go)               Hitkidd
# 23               Staying Alive             DJ Khaled
# 24                 Sleazy Flow        SleazyWorld Go
# 25                    Right On              Lil Baby
# 26           Get Into It (Yuh)              Doja Cat
# 27                By Your Side              Rod Wave
# 28       Do We Have A Problem?           Nicki Minaj
# 29                    Hot Shit           Cardi B, Ye
# 30                 Silent Hill        Kendrick Lamar
# 31                Freaky Deaky                  Tyga
# 32                   Me Or Sum  Nardo Wick, Lil Baby
# 33                     Ahhh Ha              Lil Durk
# 34                     P Power                 Gunna
# 35                   Nail Tech           Jack Harlow
# 36                     Scorpio          Moneybagg Yo
# 37                  Tomorrow 2              GloRilla
# 38  Hotel Lobby (Unc And Phew)                 Quavo
# 39                    Too Easy                 Gunna
# 40                         N95        Kendrick Lamar
# 41                      Rumors            Gucci Mane
# 42                      Chosen                 Blxst
# 43              Dah Dah DahDah            Nardo Wick
# 44                   Handsomer                  Russ
# 45                Already Dead            Juice WRLD
# 46                 Family Ties             Baby Keem
# 47                       Alone              Rod Wave
# 48                      Plan B   Megan Thee Stallion
# 49              Billie Eilish.          Armani White
#
#                                      URI
# 0   spotify:track:0wHFktze2PHC5jDt3B17DC
# 1   spotify:track:59nOXPmaKlBfGMDeOVGrIK
# 2   spotify:track:6Zu3aw7FfjAF9WA0fA81Oq
# 3   spotify:track:4A8cWXxKfIL3lAyUDzXbCF
# 4   spotify:track:27NovPIUIRrOZoCHxABJwK
# 5   spotify:track:3F5CgOj3wFlRv51JsHbxhe
# 6   spotify:track:0hquQWY3xvYqN4qtiquniF
# 7   spotify:track:31lopd32BkJBTSgYE16c5e
# 8   spotify:track:3XOalgusokruzA5ZBA2Qcb
# 9   spotify:track:7mFj0LlWtEJaEigguaWqYh
# 10  spotify:track:4C6Uex2ILwJi9sZXRdmqXp
# 11  spotify:track:2BcMwX1MPV6ZHP4tUT9uq6
', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0wHFktze2PHC5jDt3B17DC', 'duration_ms': 173948, 'time_signature': 4}]

# %%
# Create empty lists to store tempo and energy values
tempo = []
energy = []

# Loop through each track URI in the variable 'uri'
for i in uri:
    # Retrieve audio features of each track using Spotify API
    audio_features = sp.audio_features(i)
    # Extract tempo and energy values from the audio features and append them to their respective lists
    tempo.append(audio_features[0]['tempo'])
    energy.append(audio_features[0]['energy'])

# Add tempo and energy values as columns to an existing pandas DataFrame 'df'
df['Tempo'] = tempo
df['Energy'] = energy

# Print the resulting DataFrame 'df'
df
# Out:
#                     Song Title                Artist  \
# 0                  First Class           Jack Harlow
# 1                   Wait For U                Future
# 2                   Big Energy                 Latto
# 3                Super Gremlin           Kodak Black
# 4                Industry Baby               Lil Nas
# 5                  Jimmy Cooks                 Drake
# 6                        Vegas              Doja Cat
# 7                  In A Minute              Lil Baby
# 8                     Pushin P                 Gunna
# 9                 Sweetest Pie   Megan Thee Stallion
# 10           Super Freaky Girl           Nicki Minaj
# 11                  Knife Talk                 Drake
# 12                  Way 2 Sexy                 Drake
# 13              Broadway Girls              Lil Durk
# 14     What Happened To Virgil              Lil Durk
# 15           Puffin On Zootiez                Future
# 16            Girls Want Girls                 Drake
# 17                To The Moon!              JNR CHOI
# 18                      Sticky                 Drake
# 19            Who Want Smoke??            Nardo Wick
# 20           Betty (Get Money)            Yung Gravy
# 21                   Cooped Up           Post Malone
# 22           F.N.F. (Let's Go)               Hitkidd
# 23               Staying Alive             DJ Khaled
# 24                 Sleazy Flow        SleazyWorld Go
# 25                    Right On              Lil Baby
# 26           Get Into It (Yuh)              Doja Cat
# 27                By Your Side              Rod Wave
# 28       Do We Have A Problem?           Nicki Minaj
# 29                    Hot Shit           Cardi B, Ye
# 30                 Silent Hill        Kendrick Lamar
# 31                Freaky Deaky                  Tyga
# 32                   Me Or Sum  Nardo Wick, Lil Baby
# 33                     Ahhh Ha              Lil Durk
# 34                     P Power                 Gunna
# 35                   Nail Tech           Jack Harlow
# 36                     Scorpio          Moneybagg Yo
# 37                  Tomorrow 2              GloRilla
# 38  Hotel Lobby (Unc And Phew)                 Quavo
# 39                    Too Easy                 Gunna
# 40                         N95        Kendrick Lamar
# 41                      Rumors            Gucci Mane
# 42                      Chosen                 Blxst
# 43              Dah Dah DahDah            Nardo Wick
# 44                   Handsomer                  Russ
# 45                Already Dead            Juice WRLD
# 46                 Family Ties             Baby Keem
# 47                       Alone              Rod Wave
# 48                      Plan B   Megan Thee Stallion
# 49              Billie Eilish.          Armani White
#
#                                      URI    Tempo  Energy
# 0   spotify:track:0wHFktze2PHC5jDt3B17DC  107.005   0.582
# 1   spotify:track:59nOXPmaKlBfGMDeOVGrIK   83.389   0.642
# 2   spotify:track:6Zu3aw7FfjAF9WA0fA81Oq  106.017   0.807
# 3   spotify:track:4A8cWXxKfIL3lAyUDzXbCF   72.993   0.414
# 4   spotify:track:27NovPIUIRrOZoCHxABJwK  149.995   0.704
# 5   spotify:track:3F5CgOj3wFlRv51JsHbxhe  165.921   0.673
# 6   spotify:track:0hquQWY3xvYqN4qtiquniF  159.969   0.601
# 7   spotify:track:31lopd32BkJBTSgYE16c5e  113.420   0.583
# 8   spotify:track:3XOalgusokruzA5ZBA2Qcb   77.502   0.422
# 9   spotify:track:7mFj0LlWtEJaEigguaWqYh  123.977   0.628
# 10  spotify:track:4C6Uex2ILwJi9sZXRdmqXp  133.010   0.891
