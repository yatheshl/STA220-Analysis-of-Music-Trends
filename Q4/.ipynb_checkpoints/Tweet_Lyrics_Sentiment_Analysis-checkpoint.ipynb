# %% [markdown]
# # Obtaining Tweets For A Particular Year
#
# As per news reports, Kanye West's account was blocked on 2nd December 2022. As per Wayback Machine, the last available snapshot of the Twitter account was available on Fri, 02 Dec 2022 05:30:51 GMT (http://web.archive.org/web/20221202053051/https://twitter.com/kanyewest). Therefore, for 2022, we will extract all the tweets.

# %%
# Package imports

import requests
from bs4 import BeautifulSoup
import lxml
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
import pickle
import time
import re
from urllib.error import HTTPError

# %%
# Fetch the 2022 year webpage
kanye_tweets_calendar_url = "http://web.archive.org/web/20220101000000*/https://twitter.com/kanyewest"
web_archive_response = requests.get(kanye_tweets_calendar_url)
web_archive_response.raise_for_status()

# %%
# Use BeautifulSoup to parse the html later
html = BeautifulSoup(web_archive_response.text, 'lxml')
print(html.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Wayback Machine
#   </title>
#   <script>
#    /*
#     @licstart  The following is the entire license notice for the JavaScript code in this page.
#
#     Copyright (C) 2020 Internet Archive
#
#     The JavaScript code in this page is free software: you can
#     redistribute it and/or modify it under the terms of the GNU Affero
#     General Public License as published by the Free Software
#     Foundation, either version 3 of the License, or (at your option)
#     any later version.  The code is distributed WITHOUT ANY WARRANTY;
#     without even the implied warranty of MERCHANTABILITY or FITNESS
#     FOR A PARTICULAR PURPOSE.  See the GNU GPL for more details.
#
#     As additional permission under GNU AGPL version 3 section 7, you
#     may distribute non-source (e.g., minimized or compacted) forms of
#     that code without the copy of the GNU AGPL normally required by
#     section 4, provided you include this license notice and a URL
#     through which recipients can access the Corresponding Source.
#
#     @licend  The above is the entire license notice for the JavaScript code in this page.
#     */
#   </script>
#   <script type="text/javascript">
#    window.webComponentLoaderConfig = {
#       baseUrl: 'https://archive.org',
#       version: '29e56e87'
#       }
#   </script>
#   <script src="https://polyfill.archive.org/v3/polyfill.min.js?features=fetch,IntersectionObserver,ResizeObserver,globalThis,Element.prototype.getAttributeNames,String.prototype.startsWith,Array.prototype.flat,Element.prototype.closest,Element.prototype.scroll,Element.prototype.remove,Object.entries,Object.values,Object.fromEntries">
#   </script>
#   <script src="//archive.org/includes/analytics.js?v=99cd22af" type="text/javascript">
#   </script>
#   <script src="//archive.org/components/npm/lit/polyfill-support.js?v=99cd22af" type="text/javascript">
#   </script>
#   <script src="//archive.org/components/npm/@webcomponents/webcomponentsjs/webcomponents-bundle.js?v=99cd22af" type="text/javascript">
#   </script>
#   <script src="//archive.org/includes/build/js/ia-topnav.min.js?v=99cd22af" type="text/javascript">
#   </script>
#   <script src="//archive.org/includes/build/js/archive.min.js?v=99cd22af" type="text/javascript">
#   </script>
#   <link href="//archive.org/includes/build/css/archive.min.css?v=99cd22af" rel="stylesheet" type="text/css"/>
#   <meta content="" property="mediatype"/>
#   <meta content="" property="primary_collection"/>
#   <script type="text/javascript">
#    if('archive_analytics' in window){var v=archive_analytics.values;v.path='/web';v.service='wb';v.server_name='wwwb-app224.us.archive.org';v.server_ms=361;archive_analytics.send_pageview_on_load()}
#   </script>
#   <link href="/_static/images/archive.ico" rel="shortcut icon"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <link href="/_static/css/styles.css?v=X-Ndhul9" rel="stylesheet" type="text/css"/>
#   <script charset="utf-8" src="/_static/js/ui.js?v=NTAW0JFh" type="text/javascript">
#   </script>
#   <base target="_top"/>
#   <link href="/_static/css/web.css" rel="stylesheet" type="text/css"/>
#   <!-- include component js and css -->
#   <link href="/static/bower_components/wayback-search-js/dist/vendors~main.03b707f24a12f0713158.chunk.css" rel="stylesheet" type="text/css"/>
#   <link href="/static/bower_components/wayback-search-js/dist/main.c4ddbcab83782ceda455.chunk.css" rel="stylesheet" type="text/css"/>
#   <script src="/static/bower_components/wayback-search-js/dist/runtime.8c43e03bdeab7483f8ff.js">
#   </script>
#   <script src="/static/bower_components/wayback-search-js/dist/vendors~main.03b707f24a12f0713158.chunk.js">
#   </script>
#   <script src="/static/bower_components/wayback-search-js/dist/main.c4ddbcab83782ceda455.chunk.js">
#   </script>
#   <script src="https://archive.org/web/carouFredSel/jquery.carouFredSel-6.2.1-packed.js?v6.2.1" type="text/javascript">
#   </script>
#   <style>
#    html, body { margin:0; padding:0 }
#       #faux-header {
#         height: 50px;
#         width: 100%;
#         margin:0;
#         background-color:black;
#       }
#       #react-wayback-search {
#         max-width: 1170px;
#         margin: 0 auto;
#         padding: 10px;
#       }
#   </style>
#  </head>
#  <body class="navia">
#   <div class="ia-banners">
#    <div class="ia-banner info pre-court-day" data-campaign="pre-court-day">
#     <p>
#      We're fighting for the future of our library in court.
#      <a href="https://blog.archive.org/2023/03/17/heres-how-to-participate-in-mondays-oral-arguments/" rel="nofollow">
#       Show your support now!
#      </a>
#     </p>
#     <form action="" class="banner-close" data-action="ia-banner-close" method="get">
#      <fieldset>
#       <button aria-label="Close Banner" type="submit">
#       </button>
#      </fieldset>
#     </form>
#    </div>
#   </div>
#   <div id="topnav">
#    <input class="js_nav_tweaks" type="hidden" value="[]"/>
#    <!-- Shady DOM styles for icon-hamburger -->
#    <style scope="icon-hamburger-1">
#     .icon-hamburger-1 svg.icon-hamburger {
#   display: block;
# }
#
# .icon-hamburger-1 .fill-color.icon-hamburger {
#   fill: #fff;
# }
#    </style>
#    <!-- Shady DOM styles for login-button -->
#    <style scope="login-button-1">
#     .login-button-1 .dropdown-toggle.login-button {
#   display: block;
#     height: 4rem;
#     font-size: 1.6rem;
#     text-transform: uppercase;
#     text-decoration: none;
#     color: #ccc;
#     cursor: pointer;
# }
#
# .login-button-1 .dropdown-toggle.login-button .fill-color.login-button {
#   fill: #999;
# }
#
# .login-button-1 .dropdown-toggle.login-button:active .fill-color.login-button,.login-button-1 .dropdown-toggle.login-button:focus .fill-color.login-button,.login-button-1 .dropdown-toggle.login-button:hover .fill-color.login-button {
#   fill: #fff;
# }
#
# .login-button-1 .active.login-button {
#   border-radius: 1rem 1rem 0 0;
#     background: #333;
# }
#
# .login-button-1 .active.login-button .fill-color.login-button {
#   fill: #fff;
# }
#
# .login-button-1 span.login-button {
#   display: none;
#     font-size: 1.4rem;
#     text-transform: uppercase;
#     color: #999;
# }
#
# .login-button-1 span.login-button a.login-button {
#   color: inherit;
#     text-decoration: none;
# }
#
# .login-button-1 a.login-button:hover,.login-button-1 a.login-button:active,.login-button-1 a.login-button:focus {
#   color: #fff;
# }
#
# @media (min-width: 890px) {
# .login-button-1 .logged-out-toolbar.login-button {
#   transform: translateY(-.5rem);
# }
#
# .login-button-1 .active.login-button {
#   background: transparent;
# }
#
# .login-button-1 .dropdown-toggle.login-button {
#   display: inline-block;
#       vertical-align: middle;
# }
#
# .login-button-1 span.login-button {
#   display: inline;
#       vertical-align: middle;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for nav-search -->
#    <style scope="nav-search-1">
#     .nav-search-1 input.nav-search[type="text"] {
#   color: #222;
# }
#
# .nav-search-1 input.nav-search:focus {
#   outline: none;
# }
#
# .nav-search-1 button.nav-search {
#   background: none;
#     color: inherit;
#     border: none;
#     font: inherit;
#     cursor: pointer;
# }
#
# .nav-search-1 button.nav-search:focus {
#   outline: none;
# }
#
# .nav-search-1 .search.nav-search {
#   padding-top: 0;
#     margin-right: 0.5rem;
# }
#
# .nav-search-1 .search.nav-search svg.nav-search {
#   position: relative;
#     top: -5px;
#     right: -3px;
#     fill:;
# }
#
# .nav-search-1 .search-activated.nav-search {
#   display: -webkit-box;
#     display: -ms-flexbox;
#     display: flex;
#     position: absolute;
#     top: 0;
#     right: 4rem;
#     bottom: 0;
#     left: 4rem;
#     z-index: 3;
#     padding: 0.5rem 0.2rem;
#     border-radius: 1rem 1rem 0 0;
#     background: #333;
# }
#
# .nav-search-1 .search-inactive.nav-search {
#   display: none;
# }
#
# .nav-search-1 .search-activated.nav-search .highlight.nav-search,.nav-search-1 .search-activated.nav-search .search.nav-search {
#   background: #fff;
#     border-radius: 0.5rem;
# }
#
# .nav-search-1 .search-activated.nav-search .highlight.nav-search {
#   display: -webkit-box;
#     display: -ms-flexbox;
#     display: flex;
#     width: 100%;
#     margin: 0 0.5rem;
# }
#
# .nav-search-1 .search-activated.nav-search .search.nav-search {
#   height: 100%;
#     padding: 0;
#     margin-right: 0;
#     -ms-flex-item-align: center;
#     -ms-grid-row-align: center;
#     align-self: center;
# }
#
# .nav-search-1 .search-activated.nav-search .search-field.nav-search {
#   width: 100%;
#     height: 100%;
#     box-sizing: border-box;
#     padding-left: 1rem;
#     border-radius: 0.5rem;
#     border: none;
#     font-size: 1.6rem;
#     text-align: center;
# }
#
# .nav-search-1 .search-activated.nav-search .search-field.nav-search:focus {
#   outline: none;
# }
#
# @keyframes fade-in-nav-search-1 {
# 0% {
#   opacity: 0;
# }
#
# 100% {
#   opacity: 1;
# }
#
# }
#
# .nav-search-1 .fade-in.nav-search {
#   animation: fade-in-nav-search-1 0.2s forwards;
# }
#
# @media (min-width: 890px) {
# .nav-search-1 .search.nav-search svg.nav-search {
#   display: inline;
#       width: 28px;
#       height: 28px;
#       vertical-align: -14px;
# }
#
# .nav-search-1 .search.nav-search path.nav-search {
#   fill: #333;
# }
#
# .nav-search-1 .search-inactive.nav-search,.nav-search-1 .search-activated.nav-search {
#   display: block;
#       position: static;
#       padding: 1.2rem 0.2rem;
#       background: transparent;
# }
#
# .nav-search-1 .search-activated.nav-search .highlight.nav-search {
#   width: 13rem;
#       height: 2.8rem;
#       -webkit-box-orient: horizontal;
#       -webkit-box-direction: reverse;
#       -ms-flex-direction: row-reverse;
#       flex-direction: row-reverse;
# }
#
# .nav-search-1 .search-activated.nav-search .search-field.nav-search {
#   width: calc(100% - 28px);
#       height: 100%;
#       padding-left: 0;
#       font-size: 1.4rem;
#       text-align: left;
# }
#
# .nav-search-1 .search-activated.nav-search .search.nav-search svg.nav-search {
#   width: 28px;
#       height: 28px;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for media-button -->
#    <style scope="media-button-1">
#     .media-button-1 a.media-button {
#   display: inline-block;
#     text-decoration: none;
# }
#
# .media-button-1 .menu-item.media-button {
#   display: inline-flex;
#     width: 100%;
#     padding: 0;
#     font-size: 1.6rem;
#     text-align: left;
#     background: transparent;
#     -webkit-box-align: center;
#     -ms-flex-align: center;
#     align-items: center;
# }
#
# .media-button-1 .menu-item.media-button:focus {
#   outline: none;
# }
#
# .media-button-1 .label.media-button {
#   display: inline-block;
#     padding: 0;
#     font-weight: 400;
#     color: #fff;
#     text-align: left;
#     vertical-align: middle;
# }
#
# .media-button-1 .menu-item.media-button > .icon.media-button {
#   display: inline-flex;
#     width: 42px;
#     height: 42px;
#     vertical-align: middle;
#     -webkit-box-align: center;
#     -ms-flex-align: center;
#     align-items: center;
#     -webkit-box-pack: center;
#     -ms-flex-pack: center;
#     justify-content: center;
# }
#
# .media-button-1 .menu-item.selected.media-button .icon.media-button {
#   background-color: #333;
#     border-radius: 1rem 0 0 1rem;
# }
#
# .media-button-1 .icon.media-button .fill-color.media-button {
#   fill: #999;
# }
#
# .media-button-1 .icon.active.media-button .fill-color.media-button {
#   fill: #fff;
# }
#
# .media-button-1 .donate.media-button .fill-color.media-button {
#   fill: #f00;
# }
#
# @media (min-width: 890px) {
# .media-button-1 .menu-item.media-button {
#   width: auto;
#       height: 5rem;
#       color: #999;
# }
#
# .media-button-1 .menu-item.media-button:hover,.media-button-1 .menu-item.media-button:active,.media-button-1 .menu-item.media-button:focus {
#   color: #fff;
# }
#
# .media-button-1 .menu-item.media-button:hover .fill-color.media-button,.media-button-1 .menu-item.media-button:active .fill-color.media-button,.media-button-1 .menu-item.media-button:focus .fill-color.media-button {
#   fill: #fff;
# }
#
# .media-button-1 .label.media-button {
#   display: none;
# }
#
# .media-button-1 .label.media-button,.media-button-1 .web.media-button:after {
#   padding-right: 1rem;
#       font-size: 1.3rem;
#       text-transform: uppercase;
#       color: inherit;
# }
#
# .media-button-1 .web.media-button:after {
#   display: none;
#       content: "web";
# }
#
# .media-button-1 .donate.media-button,.media-button-1 .more.media-button {
#   display: none;
# }
#
# .media-button-1 .menu-item.selected.media-button {
#   background: #474747;
# }
#
# .media-button-1 .menu-item.selected.media-button .label.media-button,.media-button-1 .menu-item.selected.web.media-button:after {
#   color: #fff;
# }
#
# .media-button-1 .menu-item.selected.media-button .icon.media-button {
#   background: transparent;
# }
#
# .media-button-1 .web.selected.media-button .fill-color.media-button {
#   fill: #ffcd27;
# }
#
# .media-button-1 .texts.selected.media-button .fill-color.media-button {
#   fill: #faab3c;
# }
#
# .media-button-1 .video.selected.media-button .fill-color.media-button {
#   fill: #f1644b;
# }
#
# .media-button-1 .audio.selected.media-button .fill-color.media-button {
#   fill: #00adef;
# }
#
# .media-button-1 .software.selected.media-button .fill-color.media-button {
#   fill: #9ecc4f;
# }
#
# .media-button-1 .images.selected.media-button .fill-color.media-button {
#   fill: #aa99c9;
# }
#
# }
#
# @media (min-width: 1300px) {
# .media-button-1 .label.media-button,.media-button-1 .web.media-button:after {
#   display: inline;
# }
#
# .media-button-1 .web.media-button .label.media-button {
#   display: none;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for media-menu -->
#    <style scope="media-menu-1">
#     .media-menu-1 {
#   outline: none;
# }
#
# .media-menu-1 .media-menu-inner.media-menu {
#   z-index: -1;
#     top: -40rem;
#     background-color: #222;
#     margin: 0;
#     overflow: hidden;
#     transition-duration: 0.2s;
#     transition-property: top;
#     transition-timing-function: ease;
# }
#
# .media-menu-1 .menu-group.media-menu {
#   position: relative;
#     line-height: normal;
# }
#
# @media (max-width: 889px) {
# .media-menu-1 .media-menu-container.media-menu {
#   position: relative;
# }
#
# .media-menu-1 .media-menu-inner.media-menu {
#   position: absolute;
#       width: 100%;
# }
#
# .media-menu-1 .open.media-menu .media-menu-inner.media-menu {
#   top: 0;
# }
#
# .media-menu-1 .overflow-clip.media-menu {
#   position: absolute;
#       z-index: -1;
#       top: 0;
#       left: 0;
#       height: 0;
#       width: 100%;
#       overflow: hidden;
#       transition-duration: 0.2s;
#       transition-property: height;
# }
#
# .media-menu-1 .open.media-menu .overflow-clip.media-menu {
#   height: 40rem;
# }
#
# }
#
# @media (min-width: 890px) {
# .media-menu-1 .media-menu-inner.media-menu {
#   display: inline-block;
#       position: static;
#       width: auto;
#       height: 5rem;
#       transition-property: none;
# }
#
# .media-menu-1 .menu-group.media-menu {
#   font-size: 0;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for primary-nav -->
#    <style scope="primary-nav-1">
#     .primary-nav-1 button.primary-nav:focus,.primary-nav-1 a.primary-nav:focus,.primary-nav-1 input.primary-nav:focus {
#   outline: none;
# }
#
# .primary-nav-1 nav.primary-nav {
#   position: relative;
#     display: -ms-grid;
#     display: grid;
#     height: 4rem;
#     grid-template-areas: 'hamburger empty search user';
#     -ms-grid-columns: 4rem minmax(1rem, 100%) 4.3rem 4rem;
#     grid-template-columns: 4rem auto 4.3rem 4rem;
#     -ms-grid-rows: 100%;
#     grid-template-rows: 100%;
#     background: #222;
#     border-bottom: 1px solid #333;
# }
#
# .primary-nav-1 button.primary-nav {
#   background: none;
#     color: inherit;
#     border: none;
#     font: inherit;
#     cursor: pointer;
# }
#
# .primary-nav-1 .branding.primary-nav {
#   position: static;
#     float: left;
#     padding: 0 5px 0 10px;
#     -webkit-transform: translate(0, 0);
#     -ms-transform: translate(0, 0);
#     transform: translate(0, 0);
# }
#
# .primary-nav-1 slot.primary-nav,.primary-nav-1 .branding.primary-nav {
#   display: flex;
#     justify-content: left;
#     align-items: center;
# }
#
# .primary-nav-1 media-menu.primary-nav {
#   grid-column-start: hamburger-start;
#     grid-column-end: user-end;
# }
#
# .primary-nav-1 .ia-logo.primary-nav,.primary-nav-1 .ia-wordmark.primary-nav {
#   margin-right: 5px;
# }
#
# .primary-nav-1 .hamburger.primary-nav {
#   -ms-grid-row: 1;
#     -ms-grid-column: 1;
#     grid-area: hamburger;
#     padding: 0;
# }
#
# .primary-nav-1 .search-trigger.primary-nav {
#   -ms-grid-row: 1;
#     -ms-grid-column: 3;
#     grid-area: search;
#     position: relative;
#     padding: 0;
#     z-index: 1;
#     width: 100%;
#     text-align: right;
#     -webkit-box-align: center;
#     -ms-flex-align: center;
#     align-items: center;
# }
#
# .primary-nav-1 .search-trigger.primary-nav .fill-color.primary-nav {
#   fill: #999;
# }
#
# .primary-nav-1 .search-activated.primary-nav {
#   position: relative;
#     z-index: 3;
# }
#
# .primary-nav-1 .upload.primary-nav {
#   display: none;
# }
#
# .primary-nav-1 .upload.primary-nav span.primary-nav {
#   display: none;
# }
#
# .primary-nav-1 .user-info.primary-nav {
#   -ms-grid-row: 1;
#     -ms-grid-column: 4;
#     grid-area: user;
#     -ms-grid-row-align: stretch;
#     align-self: stretch;
#     -ms-grid-column-align: end;
#     justify-self: end;
# }
#
# .primary-nav-1 .username.primary-nav {
#   display: none;
#     font-size: 1.3rem;
#     vertical-align: middle;
#     text-transform: uppercase;
# }
#
# .primary-nav-1 .user-menu.primary-nav {
#   height: 100%;
#     padding: 0.5rem 1rem;
#     color: #999;
# }
#
# .primary-nav-1 .user-menu.primary-nav:hover {
#   color: #fff;
# }
#
# .primary-nav-1 .user-menu.active.primary-nav {
#   border-radius: 1rem 1rem 0 0;
#     background: #333;
# }
#
# .primary-nav-1 .user-menu.primary-nav img.primary-nav {
#   display: block;
#     width: 30px;
#     height: 30px;
# }
#
# .primary-nav-1 .link-home.primary-nav {
#   display: flex;
#     text-decoration: none;
# }
#
# @media only screen and (min-width: 890px) and (max-device-width: 905px) {
# .primary-nav-1 .branding.second-logo.primary-nav {
#   padding-right: 0;
# }
#
# }
#
# @media (min-width: 906px) {
# .primary-nav-1 .branding.second-logo.primary-nav {
#   padding-right: 20px;
# }
#
# }
#
# @media (max-width: 889px) {
# .primary-nav-1 slot.primary-nav[name='opt-sec-logo'] {
#   display: none;
# }
#
# }
#
# @media (min-width: 890px) {
# .primary-nav-1 {
#   ;
# }
#
# .primary-nav-1 nav.primary-nav {
#   display: block;
#       z-index: 2;
#       height: 5rem;
#       padding-right: 1.5rem;
# }
#
# .primary-nav-1 slot.primary-nav[name='opt-sec-logo-mobile'] {
#   display: none;
# }
#
# .primary-nav-1 .branding.primary-nav {
#   margin-top: 1rem;
# }
#
# .primary-nav-1 .ia-logo.primary-nav,.primary-nav-1 .ia-wordmark.primary-nav {
#   margin-right: 10px;
# }
#
# .primary-nav-1 .hamburger.primary-nav,.primary-nav-1 .search-trigger.primary-nav {
#   display: none;
# }
#
# .primary-nav-1 .user-info.primary-nav {
#   float: right;
#       padding-top: 1rem;
# }
#
# .primary-nav-1 .user-menu.primary-nav {
#   padding-top: 0;
# }
#
# .primary-nav-1 .user-menu.active.primary-nav {
#   background: transparent;
# }
#
# .primary-nav-1 .user-menu.primary-nav img.primary-nav {
#   display: inline-block;
#       vertical-align: middle;
# }
#
# .primary-nav-1 .upload.primary-nav {
#   display: block;
#       float: right;
#       margin-top: 1rem;
#       font-size: 1.4rem;
#       text-transform: uppercase;
#       text-decoration: none;
#       color: #999;
# }
#
# .primary-nav-1 .upload.primary-nav:active,.primary-nav-1 .upload.primary-nav:focus,.primary-nav-1 .upload.primary-nav:hover {
#   color: #fff;
# }
#
# .primary-nav-1 .upload.primary-nav svg.primary-nav {
#   width: 32px;
#       height: 32px;
#       vertical-align: middle;
#       fill: #999;
# }
#
# .primary-nav-1 .upload.primary-nav:hover svg.primary-nav,.primary-nav-1 .upload.primary-nav:focus svg.primary-nav,.primary-nav-1 .upload.primary-nav:active svg.primary-nav {
#   fill: #fff;
# }
#
# .primary-nav-1 nav-search.primary-nav {
#   float: right;
#       margin-left: 1rem;
# }
#
# .primary-nav-1 login-button.primary-nav {
#   display: block;
#       margin-right: 1rem;
# }
#
# }
#
# @media (min-width: 990px) {
# .primary-nav-1 .username.primary-nav {
#   display: inline-block;
# }
#
# .primary-nav-1 .upload.primary-nav span.primary-nav {
#   display: inline;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for user-menu -->
#    <!-- Shady DOM styles for search-menu -->
#    <style scope="search-menu-1">
#     .search-menu-1 .menu-wrapper.search-menu {
#   position: relative;
# }
#
# .search-menu-1 button.search-menu:focus,.search-menu-1 input.search-menu:focus {
#   outline-color: #428bca;
#     outline-width: 0.16rem;
#     outline-style: auto;
# }
#
# .search-menu-1 .search-menu-inner.search-menu {
#   position: absolute;
#     right: 0;
#     left: 0;
#     z-index: 2;
#     padding: 0 4.5rem;
#     font-size: 1.6rem;
#     background-color: #333;
# }
#
# .search-menu-1 .tx-slide.search-menu {
#   overflow: hidden;
#     transition-property: top;
#     transition-duration: 0.2s;
#     transition-timing-function: ease;
# }
#
# .search-menu-1 .initial.search-menu,.search-menu-1 .closed.search-menu {
#   top: -1500px;
# }
#
# .search-menu-1 .closed.search-menu {
#   transition-duration: 0.2s;
# }
#
# .search-menu-1 label.search-menu,.search-menu-1 a.search-menu {
#   padding: 1rem;
#     display: block;
# }
#
# .search-menu-1 .advanced-search.search-menu {
#   text-decoration: none;
#     color: #428bca;
# }
#
# @media (min-width: 890px) {
# .search-menu-1 .search-menu-inner.search-menu {
#   overflow: visible;
#       right: 2rem;
#       left: auto;
#       z-index: 5;
#       padding: 1rem 2rem;
#       transition: opacity 0.2s ease-in-out;
#       font-size: 1.4rem;
#       color: #333;
#       border-radius: 2px;
#       background: #fff;
#       box-shadow: 0 1px 2px 1px rgba(0, 0, 0, 0.15);
# }
#
# .search-menu-1 .search-menu-inner.search-menu:after {
#   position: absolute;
#       right: 7px;
#       top: -7px;
#       width: 12px;
#       height: 7px;
#       box-sizing: border-box;
#       color: #fff;
#       content: '';
#       border-bottom: 7px solid currentColor;
#       border-left: 6px solid transparent;
#       border-right: 6px solid transparent;
# }
#
# .search-menu-1 .initial.search-menu,.search-menu-1 .closed.search-menu {
#   opacity: 0;
#       transition-duration: 0.2s;
# }
#
# .search-menu-1 .open.search-menu {
#   opacity: 1;
# }
#
# .search-menu-1 label.search-menu {
#   padding: 0;
# }
#
# .search-menu-1 label.search-menu + label.search-menu {
#   padding-top: 7px;
# }
#
# .search-menu-1 a.search-menu {
#   padding: 1rem 0 0 0;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for ia-wayback-search -->
#    <!-- Shady DOM styles for wayback-search -->
#    <style scope="wayback-search-1">
#     .wayback-search-1 {
#   font: normal 1.2rem/1.5 'Helvetica Neue', Helvetica, Arial, sans-serif;
# }
#
# .wayback-search-1 form.wayback-search {
#   max-width: 600px;
# }
#
# .wayback-search-1 p.wayback-search {
#   margin-top: 0;
#     font-weight: 200;
# }
#
# .wayback-search-1 a.wayback-search {
#   font-weight: 500;
#     text-decoration: none;
#     color: #fff;
# }
#
# .wayback-search-1 fieldset.wayback-search {
#   padding: 0.7rem 2rem;
#     margin: 1.5rem 0;
#     box-sizing: border-box;
#     text-align: center;
#     border: none;
#     border-radius: 7px;
#     background-color: #fcf5e6;
#     box-shadow: 3px 3px 0 0 #c3ad97;
# }
#
# .wayback-search-1 label.wayback-search {
#   display: none;
# }
#
# .wayback-search-1 img.wayback-search {
#   width: 100%;
#     max-width: 215px;
#     max-height: 60px;
#     margin-bottom: 1.3rem;
#     vertical-align: middle;
# }
#
# .wayback-search-1 input.wayback-search {
#   display: block;
#     width: 100%;
#     height: 3rem;
#     padding: 0.5rem 1rem 0.5rem 2.5rem;
#     font: normal 1.2rem/1.5 'Helvetica Neue', Helvetica, Arial, sans-serif;
#     color: #858585;
#     box-sizing: border-box;
#     border: 1px solid #ccc;
#     border-radius: 2rem;
#     background: #eee;
# }
#
# .wayback-search-1 input.wayback-search:focus {
#   border-color: #66afe9;
#     box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.075), 0 0 8px rgba(102, 175, 233, 0.6);
#     outline: none;
# }
#
# .wayback-search-1 .search-field.wayback-search {
#   position: relative;
#     overflow: hidden;
# }
#
# .wayback-search-1 .search-field.wayback-search svg.wayback-search {
#   position: absolute;
#     top: 2px;
#     left: 3px;
#     width: 24px;
#     height: 24px;
# }
#
# .wayback-search-1 .search-field.wayback-search .fill-color.wayback-search {
#   fill: #999;
# }
#
# .wayback-search-1 input.wayback-search:focus + svg.wayback-search {
#   display: none;
# }
#
# @media (min-width: 890px) {
# .wayback-search-1 form.wayback-search {
#   margin: 0 auto;
# }
#
# .wayback-search-1 p.wayback-search {
#   margin-bottom: 3rem;
#       font-size: 1.6rem;
#       text-align: center;
# }
#
# .wayback-search-1 img.wayback-search {
#   margin: 0;
# }
#
# .wayback-search-1 fieldset.wayback-search {
#   margin: 0 auto;
#       font-size: 0;
# }
#
# .wayback-search-1 fieldset.wayback-search a.wayback-search,.wayback-search-1 .search-field.wayback-search {
#   display: inline-block;
#       width: 50%;
#       vertical-align: middle;
# }
#
# .wayback-search-1 fieldset.wayback-search a.wayback-search {
#   text-align: center;
# }
#
# .wayback-search-1 .search-field.wayback-search svg.wayback-search {
#   width: 28px;
#       height: 28px;
# }
#
# .wayback-search-1 .search-field.wayback-search .fill-color.wayback-search {
#   fill: #333;
# }
#
# }
#
# .wayback-search-1 p.wayback-search {
#   margin-bottom: 1rem;
#     font-size: 1.6rem;
#     text-align: center;
# }
#
# .wayback-search-1 fieldset.wayback-search {
#   padding: .5rem;
#     border-radius: 5px;
#     box-shadow: none;
# }
#
# .wayback-search-1 input.wayback-search {
#   padding-left: 3rem;
#     margin-top: .3rem;
#     font-size: 1.4rem;
#     border-color: #bca38e;
#     background: #fff;
# }
#
# .wayback-search-1 input.wayback-search::placeholder,.wayback-search-1 input.wayback-search::-webkit-input-placeholder {
#   color: #8e8e8e;
# }
#
# .wayback-search-1 .search-field.wayback-search svg.wayback-search {
#   top: 50%;
#     transform: translateY(-50%);
# }
#
# @media (min-width: 890px) {
# .wayback-search-1 fieldset.wayback-search a.wayback-search,.wayback-search-1 .search-field.wayback-search {
#   display: block;
#       width: auto;
# }
#
# .wayback-search-1 fieldset.wayback-search a.wayback-search {
#   margin: 0 1.5rem;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for save-page-form -->
#    <style scope="save-page-form-1">
#     .save-page-form-1 div.save-page-form {
#   display: grid;
#     grid-template-columns: 1fr auto;
#     grid-column-gap: .8rem;
#     margin: 0;
#     padding: 0;
#     border: none;
# }
#
# .save-page-form-1 input.save-page-form[type="text"] {
#   width: 100%;
#     height: 30px;
#     box-sizing: border-box;
#     border: 1px solid #999;
#     border-radius: .5rem;
#     color: #222;
# }
#
# .save-page-form-1 input.save-page-form[type="submit"] {
#   -webkit-appearance: none;
#     -moz-appearance: none;
#     appearance: none;
#     padding: .4rem .8rem;
#     font: normal 1.3rem 'Helvetica Neue', Helvetica, Arial, sans-serif;
#     text-transform: uppercase;
#     color: #fff;
#     border: none;
#     border-radius: 16px;
#     background: #222;
#     cursor: pointer;
# }
#
# .save-page-form-1 .error.save-page-form {
#   display: none;
#     margin-top: .5rem;
#     font-weight: bold;
#     color: #ffcd27;
# }
#
# .save-page-form-1 .visible.save-page-form {
#   display: block;
# }
#
# @media (min-width: 890px) {
# .save-page-form-1 h3.save-page-form {
#   margin-top: 0;
#       font: normal 100 1.6rem 'Helvetica Neue', Helvetica, Arial, sans-serif;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for wayback-slider -->
#    <style scope="wayback-slider-1">
#     .wayback-slider-1 h4.wayback-slider {
#   font-size: 1.6rem;
# }
#
# .wayback-slider-1 a.wayback-slider {
#   text-decoration: none;
#     color: #fff;
# }
#
# .wayback-slider-1 ul.wayback-slider {
#   padding: 0;
#     margin: 0;
#     list-style: none;
# }
#
# .wayback-slider-1 li.wayback-slider + li.wayback-slider {
#   padding-top: 1.5rem;
# }
#
# @media (min-width: 890px) {
# .wayback-slider-1 h4.wayback-slider {
#   margin: 0 0 1rem 0;
#       font-weight: 100;
# }
#
# .wayback-slider-1 ul.wayback-slider {
#   font-size: 1.3rem;
# }
#
# .wayback-slider-1 li.wayback-slider {
#   padding-bottom: .5rem;
# }
#
# .wayback-slider-1 li.wayback-slider + li.wayback-slider {
#   padding-top: 0;
# }
#
# .wayback-slider-1 li.wayback-slider a.wayback-slider {
#   display: block;
#       overflow: hidden;
#       white-space: nowrap;
#       text-overflow: ellipsis;
# }
#
# }
#
# @media (min-width: 890px) {
# .wayback-slider-1 {
#   display: block;
#       grid-column: 1 / 4;
#       padding: 0 1.5rem;
# }
#
# .wayback-slider-1 h4.wayback-slider {
#   margin-top: 0;
#       font: normal 100 1.6rem 'Helvetica Neue', Helvetica, Arial, sans-serif;
# }
#
# .wayback-slider-1 .grid.wayback-slider {
#   display: grid;
#       grid-template-columns: minmax(auto, 260px) 1fr minmax(auto, 260px);
#
#       grid-column-gap: 2.5rem;
# }
#
# .wayback-slider-1 .link-lists.wayback-slider {
#   display: grid;
#       grid-template-columns: calc(50% - 1.25rem) calc(50% - 1.25rem);
#       grid-column-gap: 2.5rem;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for more-slider -->
#    <style scope="more-slider-1">
#     .more-slider-1 ul.more-slider {
#   padding: 0;
#     margin: -1rem 0 0 0;
#     list-style: none;
# }
#
# .more-slider-1 a.more-slider {
#   display: block;
#     padding: 1rem 0;
#     text-decoration: none;
#     color: #fff;
# }
#    </style>
#    <!-- Shady DOM styles for media-subnav -->
#    <style scope="media-subnav-1">
#     .media-subnav-1 h4.media-subnav {
#   font-size: 1.6rem;
# }
#
# .media-subnav-1 a.media-subnav {
#   text-decoration: none;
#     color: #fff;
# }
#
# .media-subnav-1 ul.media-subnav {
#   padding: 0;
#     margin: 0;
#     list-style: none;
# }
#
# .media-subnav-1 li.media-subnav + li.media-subnav {
#   padding-top: 1.5rem;
# }
#
# @media (min-width: 890px) {
# .media-subnav-1 h4.media-subnav {
#   margin: 0 0 1rem 0;
#       font-weight: 100;
# }
#
# .media-subnav-1 ul.media-subnav {
#   font-size: 1.3rem;
# }
#
# .media-subnav-1 li.media-subnav {
#   padding-bottom: .5rem;
# }
#
# .media-subnav-1 li.media-subnav + li.media-subnav {
#   padding-top: 0;
# }
#
# .media-subnav-1 li.media-subnav a.media-subnav {
#   display: block;
#       overflow: hidden;
#       white-space: nowrap;
#       text-overflow: ellipsis;
# }
#
# }
#
# .media-subnav-1 img.media-subnav {
#   display: block;
#     width: 90px;
#     height: 90px;
#     margin: 0 auto 1rem auto;
#     border-radius: 45px;
# }
#
# .media-subnav-1 h3.media-subnav {
#   margin-top: 0;
#     font-size: 1.8rem;
# }
#
# .media-subnav-1 .icon-links.media-subnav {
#   display: -webkit-box;
#     display: -ms-flexbox;
#     display: flex;
#     -webkit-box-pack: space-evenly;
#     -ms-flex-pack: space-evenly;
#     justify-content: space-evenly;
#     text-align: center;
# }
#
# .media-subnav-1 .icon-links.media-subnav a.media-subnav {
#   display: inline-block;
#     width: 120px;
#     margin-bottom: 1.5rem;
#     overflow: hidden;
#     white-space: nowrap;
#     text-align: center;
#     text-overflow: ellipsis;
# }
#
# .media-subnav-1 .icon-links.media-subnav a.media-subnav + a.media-subnav {
#   margin-left: 2rem;
# }
#
# .media-subnav-1 .featured.media-subnav h4.media-subnav {
#   display: none;
# }
#
# @media (min-width: 890px) {
# .media-subnav-1 {
#   display: -ms-grid;
#       display: grid;
#       -ms-grid-columns: 40% 20% 40%;
#       grid-template-columns: 40% 20% 40%;
# }
#
# .media-subnav-1 .wayback-search.media-subnav {
#   -ms-grid-column: 1;
#       -ms-grid-column-span: 3;
#       grid-column: 1 / 4;
# }
#
# .media-subnav-1 h3.media-subnav {
#   display: none;
# }
#
# .media-subnav-1 .icon-links.media-subnav {
#   -ms-grid-column: 1;
# }
#
# .media-subnav-1 .icon-links.media-subnav a.media-subnav {
#   padding-top: 3.5rem;
#       max-width: 160px;
# }
#
# .media-subnav-1 .links.media-subnav {
#   padding: 0 1.5rem;
# }
#
# .media-subnav-1 .featured.media-subnav {
#   -ms-grid-column: 2;
# }
#
# .media-subnav-1 .featured.media-subnav h4.media-subnav {
#   display: block;
# }
#
# .media-subnav-1 .top.media-subnav {
#   -ms-grid-column: 3;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav {
#   display: -ms-grid;
#       display: grid;
#       -ms-grid-columns: 50% 3rem 50%;
#       grid-template-columns: 50% 50%;
#       -ms-grid-rows: (auto)[7];
#       grid-template-rows: repeat(7, auto);
#       grid-column-gap: 3rem;
#       grid-auto-flow: column;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(1) {
#   -ms-grid-row: 1;
#       -ms-grid-column: 1;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(2) {
#   -ms-grid-row: 2;
#       -ms-grid-column: 1;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(3) {
#   -ms-grid-row: 3;
#       -ms-grid-column: 1;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(4) {
#   -ms-grid-row: 4;
#       -ms-grid-column: 1;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(5) {
#   -ms-grid-row: 5;
#       -ms-grid-column: 1;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(6) {
#   -ms-grid-row: 6;
#       -ms-grid-column: 1;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(7) {
#   -ms-grid-row: 7;
#       -ms-grid-column: 1;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(8) {
#   -ms-grid-row: 1;
#       -ms-grid-column: 3;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(9) {
#   -ms-grid-row: 2;
#       -ms-grid-column: 3;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(10) {
#   -ms-grid-row: 3;
#       -ms-grid-column: 3;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(11) {
#   -ms-grid-row: 4;
#       -ms-grid-column: 3;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(12) {
#   -ms-grid-row: 5;
#       -ms-grid-column: 3;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(13) {
#   -ms-grid-row: 6;
#       -ms-grid-column: 3;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(14) {
#   -ms-grid-row: 7;
#       -ms-grid-column: 3;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for media-slider -->
#    <style scope="media-slider-1">
#     .media-slider-1 .media-slider-container.media-slider {
#   position: relative;
# }
#
# .media-slider-1 .overflow-clip.media-slider {
#   display: none;
#     position: absolute;
#     top: 3rem;
#     right: 0;
#     left: 0;
#     height: 0;
#     overflow: hidden;
#     transition: height 0.2s ease;
# }
#
# .media-slider-1 .information-menu.media-slider {
#   position: absolute;
#     top: 0;
#     right: 0;
#     left: 0;
#     padding: 0;
#     height: 368px;
#     overflow-x: hidden;
#     font-size: 1.4rem;
#     background: #333;
# }
#
# .media-slider-1 .open.media-slider {
#   display: block;
# }
#
# .media-slider-1 .hidden.media-slider {
#   display: none;
# }
#
# .media-slider-1 .info-box.media-slider {
#   padding: 1rem;
# }
#
# @media (max-width: 889px) {
# .media-slider-1 .overflow-clip.open.media-slider {
#   display: block;
#       height: 367px;
#       left: 4rem;
#       top: 0;
# }
#
# }
#
# @media (min-width: 890px) {
# .media-slider-1 .overflow-clip.media-slider {
#   display: block;
# }
#
# .media-slider-1 .information-menu.media-slider {
#   left: 0;
#       z-index: 2;
#       height: auto;
#       min-height: 21rem;
#       background: #474747;
#       transform: translate(0, -100%);
#       transition: transform 0.2s ease;
# }
#
# .media-slider-1 .overflow-clip.open.media-slider {
#   height: 22rem;
# }
#
# .media-slider-1 .information-menu.open.media-slider {
#   transform: translate(0, 0);
# }
#
# .media-slider-1 .info-box.media-slider {
#   max-width: 1000px;
#       padding: 1.5rem 0;
#       margin: 0 auto;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for desktop-subnav -->
#    <style scope="desktop-subnav-1">
#     .desktop-subnav-1 ul.desktop-subnav {
#   position: relative;
#     z-index: 3;
#     padding: .8rem 0;
#     margin: 0;
#     font-size: 1.2rem;
#     text-transform: uppercase;
#     text-align: center;
#     background: #333;
# }
#
# .desktop-subnav-1 li.desktop-subnav {
#   display: inline-block;
#     padding: 0 15px;
# }
#
# .desktop-subnav-1 a.desktop-subnav {
#   text-decoration: none;
#     color: #aaa;
# }
#
# .desktop-subnav-1 a.desktop-subnav:hover,.desktop-subnav-1 a.desktop-subnav:active,.desktop-subnav-1 a.desktop-subnav:focus {
#   color: #fff;
# }
#
# .desktop-subnav-1 .donate.desktop-subnav svg.desktop-subnav {
#   width: 16px;
#     height: 16px;
#     vertical-align: -4px;
#     fill: #f00;
# }
#    </style>
#    <!-- Shady DOM styles for signed-out-dropdown -->
#    <style scope="signed-out-dropdown-1">
#     .signed-out-dropdown-1 .nav-container.signed-out-dropdown {
#   position: relative;
# }
#
# .signed-out-dropdown-1 nav.signed-out-dropdown {
#   position: absolute;
#     right: 0;
#     z-index: 2;
#     overflow: hidden;
#     font-size: 1.6rem;
#     background-color: #333;
#     transition-property: top;
#     transition-duration: 0.2s;
#     transition-timing-function: ease;
# }
#
# .signed-out-dropdown-1 .initial.signed-out-dropdown,.signed-out-dropdown-1 .closed.signed-out-dropdown {
#   top: -1500px;
# }
#
# .signed-out-dropdown-1 .closed.signed-out-dropdown {
#   transition-duration: 0.5s;
# }
#
# .signed-out-dropdown-1 .open.signed-out-dropdown {
#   max-width: 100vw;
#     overflow: auto;
# }
#
# .signed-out-dropdown-1 h3.signed-out-dropdown {
#   padding: 0.6rem 2rem;
#     margin: 0;
#     font-size: inherit;
#     overflow: hidden;
#     text-overflow: ellipsis;
# }
#
# .signed-out-dropdown-1 ul.signed-out-dropdown {
#   padding: 0.4rem 0 0.7rem 0;
#     margin: 0;
#     list-style: none;
#
#     max-height: calc(100vh - 7.2rem + 1px);
#     overflow: auto;
#     box-sizing: border-box;
# }
#
# .signed-out-dropdown-1 .divider.signed-out-dropdown {
#   margin: 0.5rem 0;
#     border-bottom: 1px solid #666;
# }
#
# .signed-out-dropdown-1 a.signed-out-dropdown,.signed-out-dropdown-1 .info-item.signed-out-dropdown {
#   display: block;
#     color: #fff;
#     text-decoration: none;
#     padding: 1rem 2rem;
# }
#
# .signed-out-dropdown-1 .info-item.signed-out-dropdown {
#   font-size: 0.8em;
#     color: #999;
# }
#
# @media (min-width: 890px) {
# .signed-out-dropdown-1 nav.signed-out-dropdown {
#   overflow: visible;
#       top: 0;
#       left: auto;
#       z-index: 5;
#       transition: opacity 0.2s ease-in-out;
#       font-size: 1.4rem;
#       border-radius: 2px;
#       background: #fff;
#       box-shadow: 0 1px 2px 1px rgba(0, 0, 0, 0.15);
# }
#
# .signed-out-dropdown-1 nav.signed-out-dropdown:after {
#   position: absolute;
#       right: 7px;
#       top: -7px;
#       width: 12px;
#       height: 7px;
#       box-sizing: border-box;
#       color: #fff;
#       content: '';
#       border-bottom: 7px solid currentColor;
#       border-left: 6px solid transparent;
#       border-right: 6px solid transparent;
# }
#
# .signed-out-dropdown-1 h3.signed-out-dropdown {
#   display: none;
# }
#
# .signed-out-dropdown-1 ul.signed-out-dropdown {
#   max-height: calc(100vh - 8.5rem + 1px);
# }
#
# .signed-out-dropdown-1 .divider.signed-out-dropdown {
#   border-bottom-color: #666;
# }
#
# .signed-out-dropdown-1 a.signed-out-dropdown {
#   padding: 0.5rem 2rem;
#       color: #333;
#       transition: background 0.1s ease-out, color 0.1s ease-out;
# }
#
# .signed-out-dropdown-1 .info-item.signed-out-dropdown {
#   padding: 0.5rem 2rem;
#       font-size: 0.8em;
# }
#
# .signed-out-dropdown-1 a.signed-out-dropdown:hover,.signed-out-dropdown-1 a.signed-out-dropdown:active,.signed-out-dropdown-1 a.signed-out-dropdown:focus {
#   color: #fff;
#       background: #428bca;
# }
#
# .signed-out-dropdown-1 .initial.signed-out-dropdown,.signed-out-dropdown-1 .closed.signed-out-dropdown {
#   opacity: 0;
#       transition-duration: 0.2s;
# }
#
# .signed-out-dropdown-1 .open.signed-out-dropdown {
#   opacity: 1;
#       overflow: visible;
# }
#
# }
#
# @media (min-width: 890px) {
# .signed-out-dropdown-1 .initial.signed-out-dropdown,.signed-out-dropdown-1 .closed.signed-out-dropdown,.signed-out-dropdown-1 .open.signed-out-dropdown {
#   right: 34rem;
# }
#
# .signed-out-dropdown-1 .search-hidden.initial.signed-out-dropdown,.signed-out-dropdown-1 .search-hidden.closed.signed-out-dropdown,.signed-out-dropdown-1 .search-hidden.open.signed-out-dropdown {
#   right: 18.5rem;
# }
#
# }
#
# @media (min-width: 990px) {
# .signed-out-dropdown-1 .initial.signed-out-dropdown,.signed-out-dropdown-1 .closed.signed-out-dropdown,.signed-out-dropdown-1 .open.signed-out-dropdown {
#   right: 40rem;
# }
#
# .signed-out-dropdown-1 .search-hidden.initial.signed-out-dropdown,.signed-out-dropdown-1 .search-hidden.closed.signed-out-dropdown,.signed-out-dropdown-1 .search-hidden.open.signed-out-dropdown {
#   right: 24.5rem;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for ia-topnav -->
#    <style scope="ia-topnav-1">
#     .ia-topnav-1 {
#   ;
#
#     color: #fff;
#     font-size: 2rem;
#     font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif;
# }
#
# .ia-topnav-1 primary-nav.ia-topnav:focus {
#   outline: none !important;
# }
#
# .ia-topnav-1 #close-layer.ia-topnav {
#   display: none;
#     position: fixed;
#     top: 0;
#     right: 0;
#     bottom: 0;
#     left: 0;
#     z-index: 0;
# }
#
# .ia-topnav-1 #close-layer.visible.ia-topnav {
#   display: block;
# }
#
# .ia-topnav-1 .topnav.ia-topnav {
#   position: relative;
#     z-index: 3;
# }
#
# @media (max-width: 889px) {
# .ia-topnav-1 desktop-subnav.ia-topnav {
#   display: none;
# }
#
# }
#    </style>
#    <style>
#     body {transition: opacity ease-in 0.2s; }
# body[unresolved] {opacity: 0; display: block; overflow: hidden; position: relative; }
#    </style>
#    <ia-topnav class="x-scope ia-topnav-1" locallinks="true" waybackpagesarchived="800 billion">
#     <!-- -->
#     <div class="topnav style-scope ia-topnav">
#      <primary-nav class="style-scope ia-topnav x-scope primary-nav-1">
#       <!-- -->
#       <nav class="style-scope primary-nav">
#        <div class="branding style-scope primary-nav">
#         <a class="link-home style-scope primary-nav" data-event-click-tracking="TopNav|NavHome" href="https://archive.org/" title="Go home">
#          <!--?lit$418799101$-->
#          <svg aria-labelledby="logoTitleID logoDescID" class="ia-logo style-scope primary-nav" height="30" viewbox="0 0 27 30" width="27" xmlns="http://www.w3.org/2000/svg">
#           <title class="style-scope primary-nav" id="logoTitleID">
#            Internet Archive logo
#           </title>
#           <desc class="style-scope primary-nav" id="logoDescID">
#            A line drawing of the Internet Archive headquarters building façade.
#           </desc>
#           <g class="style-scope primary-nav" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#            <mask class="style-scope primary-nav" fill="white" id="mask-2">
#             <path class="style-scope primary-nav" d="M26.6666667,28.6046512 L26.6666667,30 L0,30 L0.000283687943,28.6046512 L26.6666667,28.6046512 Z M25.6140351,26.5116279 L25.6140351,28.255814 L1.05263158,28.255814 L1.05263158,26.5116279 L25.6140351,26.5116279 Z M3.62469203,7.6744186 L3.91746909,7.82153285 L4.0639977,10.1739544 L4.21052632,13.9963932 L4.21052632,17.6725617 L4.0639977,22.255044 L4.03962296,25.3421929 L3.62469203,25.4651163 L2.16024641,25.4651163 L1.72094074,25.3421929 L1.55031755,22.255044 L1.40350877,17.6970339 L1.40350877,14.0211467 L1.55031755,10.1739544 L1.68423854,7.80887484 L1.98962322,7.6744186 L3.62469203,7.6744186 Z M24.6774869,7.6744186 L24.9706026,7.82153285 L25.1168803,10.1739544 L25.2631579,13.9963932 L25.2631579,17.6725617 L25.1168803,22.255044 L25.0927809,25.3421929 L24.6774869,25.4651163 L23.2130291,25.4651163 L22.7736357,25.3421929 L22.602418,22.255044 L22.4561404,17.6970339 L22.4561404,14.0211467 L22.602418,10.1739544 L22.7369262,7.80887484 L23.0420916,7.6744186 L24.6774869,7.6744186 Z M9.94042303,7.6744186 L10.2332293,7.82153285 L10.3797725,10.1739544 L10.5263158,13.9963932 L10.5263158,17.6725617 L10.3797725,22.255044 L10.3556756,25.3421929 L9.94042303,25.4651163 L8.47583122,25.4651163 L8.0362015,25.3421929 L7.86556129,22.255044 L7.71929825,17.6970339 L7.71929825,14.0211467 L7.86556129,10.1739544 L8.00005604,7.80887484 L8.30491081,7.6744186 L9.94042303,7.6744186 Z M18.0105985,7.6744186 L18.3034047,7.82153285 L18.449948,10.1739544 L18.5964912,13.9963932 L18.5964912,17.6725617 L18.449948,22.255044 L18.425851,25.3421929 L18.0105985,25.4651163 L16.5460067,25.4651163 L16.1066571,25.3421929 L15.9357367,22.255044 L15.7894737,17.6970339 L15.7894737,14.0211467 L15.9357367,10.1739544 L16.0702315,7.80887484 L16.3753664,7.6744186 L18.0105985,7.6744186 Z M25.6140351,4.53488372 L25.6140351,6.97674419 L1.05263158,6.97674419 L1.05263158,4.53488372 L25.6140351,4.53488372 Z M13.0806755,0 L25.9649123,2.93331338 L25.4484139,3.8372093 L0.771925248,3.8372093 L0,3.1041615 L13.0806755,0 Z" id="path-1">
#             </path>
#             <path class="style-scope primary-nav" d="m55.1990352 2.60391777c-.494781-1.7051627-.6341747-1.7051627-1.8709043-1.98640261v-.41183224h2.9994145l3.0301436 10.26548988h.0307289l2.9535438-10.26548988h1.0042584l-3.771647 12.60682378h-1.344949z">
#             </path>
#             <path class="style-scope primary-nav" d="m67.7842867 2.75363255c0-1.85487748-.0463161-1.85487748-1.4687557-2.13611739v-.41183224h7.4061269l.0463161 2.77228859h-.433323c0-1.49854698-.6488711-1.89218957-1.6696073-1.89218957h-1.2060007c-.7726777 0-.9735293.07462419-.9735293.97431206v3.7279446h1.8709043c1.0657162 0 1.174381-.82366447 1.2674586-1.44164603h.4324323v3.93316112h-.4324323c0-1.01162415-.3402454-1.61141607-1.2674586-1.61141607h-1.8709043v4.17755538c0 1.0489362.2008516 1.0867147.9735293 1.0867147h1.7168141c.8804518 0 1.2977423-.3749865 1.3908199-1.835755h.433323l-.0472068 2.715854h-6.1685065z">
#             </path>
#            </g>
#            <path class="style-scope primary-nav" d="m1.55575146 9.89647882v-7.6678574c0-1.39053729-.25677019-1.65867172-1.55575146-1.65867172v-.44528687h5.12561364v.44528687c-1.28118091 0-1.55575146.26813443-1.55575146 1.65867172v7.6678574c0 1.39097468.27457055 1.65735948 1.55575146 1.65735948v.4461617h-5.12561364v-.4461617c1.29898127 0 1.55575146-.2663848 1.55575146-1.65735948z">
#            </path>
#            <path class="style-scope primary-nav" d="m9.92299051 2.28198586c0-1.65823431-.25588017-1.58649851-1.83032201-1.88962601v-.39235985h3.8626781l5.7664266 9.70008019h.0364907v-9.70008019h1.1534634v12h-1.7577856l-6.0405521-10.14492965h-.0369358v10.14492965h-1.15346329z">
#            </path>
# ...
#                <!--?lit$418799101$-->
#                Projects
#               </a>
#              </li>
#              <!-- -->
#              <!-- -->
#              <li class="style-scope more-slider">
#               <a class="style-scope more-slider" data-event-click-tracking="TopNav|NavMoreHelp" href="https://archive.org/about/faqs.php">
#                <!--?lit$418799101$-->
#                Help
#               </a>
#              </li>
#              <!-- -->
#              <!-- -->
#              <li class="style-scope more-slider">
#               <a class="style-scope more-slider" data-event-click-tracking="TopNav|NavMoreDonate" href="https://archive.org/donate?origin=iawww-TopNavDonateButton">
#                <!--?lit$418799101$-->
#                Donate
#               </a>
#              </li>
#              <!-- -->
#              <!-- -->
#              <li class="style-scope more-slider">
#               <a class="style-scope more-slider" data-event-click-tracking="TopNav|NavMoreContact" href="https://archive.org/about/contact.php">
#                <!--?lit$418799101$-->
#                Contact
#               </a>
#              </li>
#              <!-- -->
#              <!-- -->
#              <li class="style-scope more-slider">
#               <a class="style-scope more-slider" data-event-click-tracking="TopNav|NavMoreJobs" href="https://archive.org/about/jobs.php">
#                <!--?lit$418799101$-->
#                Jobs
#               </a>
#              </li>
#              <!-- -->
#              <!-- -->
#              <li class="style-scope more-slider">
#               <a class="style-scope more-slider" data-event-click-tracking="TopNav|NavMoreVolunteer" href="https://archive.org/about/volunteerpositions.php">
#                <!--?lit$418799101$-->
#                Volunteer
#               </a>
#              </li>
#              <!-- -->
#              <!-- -->
#              <li class="style-scope more-slider">
#               <a class="style-scope more-slider" data-event-click-tracking="TopNav|NavMorePeople" href="https://archive.org/about/bios.php">
#                <!--?lit$418799101$-->
#                People
#               </a>
#              </li>
#              <!-- -->
#             </ul>
#            </more-slider>
#           </media-subnav>
#          </div>
#         </div>
#        </div>
#       </div>
#      </media-slider>
#     </div>
#     <!--?lit$418799101$-->
#     <signed-out-dropdown class="style-scope ia-topnav x-scope signed-out-dropdown-1" tabindex="-1">
#      <!-- -->
#      <div class="nav-container style-scope signed-out-dropdown">
#       <nav aria-expanded="false" aria-hidden="true" class="initial style-scope signed-out-dropdown">
#        <ul class="style-scope signed-out-dropdown">
#         <!--?lit$418799101$-->
#         <!-- -->
#         <li class="style-scope signed-out-dropdown">
#          <!--?lit$418799101$-->
#          <a class="style-scope signed-out-dropdown" data-event-click-tracking="TopNav|NavAvatarMenu-Signup" href="https://archive.org/account/signup">
#           <!--?lit$418799101$-->
#           Sign up for free
#          </a>
#         </li>
#         <!-- -->
#         <!-- -->
#         <li class="style-scope signed-out-dropdown">
#          <!--?lit$418799101$-->
#          <a class="style-scope signed-out-dropdown" data-event-click-tracking="TopNav|NavAvatarMenu-Login" href="https://archive.org/account/login">
#           <!--?lit$418799101$-->
#           Log in
#          </a>
#         </li>
#         <!-- -->
#        </ul>
#       </nav>
#      </div>
#     </signed-out-dropdown>
#     <search-menu class="style-scope ia-topnav x-scope search-menu-1" tabindex="-1">
#      <!-- -->
#      <div class="menu-wrapper style-scope search-menu">
#       <div aria-expanded="false" aria-hidden="true" class="search-menu-inner tx-slide closed style-scope search-menu">
#        <!--?lit$418799101$-->
#        <!-- -->
#        <label class="style-scope search-menu">
#         <input checked="" class="style-scope search-menu" form="nav-search" name="sin" type="radio" value=""/>
#         Search
#         <!--?lit$418799101$-->
#         metadata
#        </label>
#        <!-- -->
#        <!-- -->
#        <label class="style-scope search-menu">
#         <input class="style-scope search-menu" form="nav-search" name="sin" type="radio" value="TXT"/>
#         Search
#         <!--?lit$418799101$-->
#         text contents
#        </label>
#        <!-- -->
#        <!-- -->
#        <label class="style-scope search-menu">
#         <input class="style-scope search-menu" form="nav-search" name="sin" type="radio" value="TV"/>
#         Search
#         <!--?lit$418799101$-->
#         TV news captions
#        </label>
#        <!-- -->
#        <!-- -->
#        <label class="style-scope search-menu">
#         <input class="style-scope search-menu" form="nav-search" name="sin" type="radio" value="RADIO"/>
#         Search
#         <!--?lit$418799101$-->
#         radio transcripts
#        </label>
#        <!-- -->
#        <!-- -->
#        <label class="style-scope search-menu">
#         <input class="style-scope search-menu" form="nav-search" name="sin" type="radio" value="WEB"/>
#         Search
#         <!--?lit$418799101$-->
#         archived web sites
#        </label>
#        <!-- -->
#        <a class="advanced-search style-scope search-menu" data-event-click-tracking="TopNav|NavAdvancedSearch" href="https://archive.org/advancedsearch.php">
#         Advanced Search
#        </a>
#       </div>
#      </div>
#     </search-menu>
#     <desktop-subnav class="style-scope ia-topnav x-scope desktop-subnav-1">
#      <!-- -->
#      <ul class="style-scope desktop-subnav">
#       <!--?lit$418799101$-->
#       <!-- -->
#       <li class="style-scope desktop-subnav">
#        <a class="about style-scope desktop-subnav" href="https://archive.org/about/">
#         <!--?lit$418799101$-->
#         About
#         <!--?lit$418799101$-->
#         <!--?-->
#        </a>
#       </li>
#       <!-- -->
#       <!-- -->
#       <li class="style-scope desktop-subnav">
#        <a class="blog style-scope desktop-subnav" href="https://blog.archive.org">
#         <!--?lit$418799101$-->
#         Blog
#         <!--?lit$418799101$-->
#         <!--?-->
#        </a>
#       </li>
#       <!-- -->
#       <!-- -->
#       <li class="style-scope desktop-subnav">
#        <a class="projects style-scope desktop-subnav" href="https://archive.org/projects/">
#         <!--?lit$418799101$-->
#         Projects
#         <!--?lit$418799101$-->
#         <!--?-->
#        </a>
#       </li>
#       <!-- -->
#       <!-- -->
#       <li class="style-scope desktop-subnav">
#        <a class="help style-scope desktop-subnav" href="https://archive.org/about/faqs.php">
#         <!--?lit$418799101$-->
#         Help
#         <!--?lit$418799101$-->
#         <!--?-->
#        </a>
#       </li>
#       <!-- -->
#       <!-- -->
#       <li class="style-scope desktop-subnav">
#        <a class="donate style-scope desktop-subnav" href="https://archive.org/donate?origin=iawww-TopNavDonateButton">
#         <!--?lit$418799101$-->
#         Donate
#         <!--?lit$418799101$-->
#         <svg aria-labelledby="donateTitleID donateDescID" class="style-scope desktop-subnav" height="40" viewbox="0 0 40 40" width="40" xmlns="http://www.w3.org/2000/svg">
#          <title class="style-scope desktop-subnav" id="donateTitleID">
#           Donate icon
#          </title>
#          <desc class="style-scope desktop-subnav" id="donateDescID">
#           An illustration of a heart shape
#          </desc>
#          <path class="fill-color style-scope desktop-subnav" d="m30.0120362 11.0857287c-1.2990268-1.12627221-2.8599641-1.65258786-4.682812-1.57894699-.8253588.02475323-1.7674318.3849128-2.8262192 1.08047869-1.0587873.6955659-1.89622 1.5724492-2.512298 2.63065-.591311-1.0588196-1.4194561-1.9357029-2.4844351-2.63065-1.0649791-.69494706-2.0039563-1.05510663-2.8169316-1.08047869-1.2067699-.04950647-2.318187.17203498-3.3342513.66462439-1.0160643.4925893-1.82594378 1.2002224-2.42963831 2.1228992-.60369453.9226769-.91173353 1.9629315-.92411701 3.1207641-.03715043 1.9202322.70183359 3.7665141 2.21695202 5.5388457 1.2067699 1.4035084 2.912594 3.1606786 5.1174721 5.2715107 2.2048782 2.1108321 3.7565279 3.5356901 4.6549492 4.2745742.8253588-.6646243 2.355647-2.0647292 4.5908647-4.2003145s3.9747867-3.9171994 5.218707-5.3448422c1.502735-1.7723316 2.2355273-3.6186135 2.1983769-5.5388457-.0256957-1.7608832-.6875926-3.2039968-1.9866194-4.3302689z">
#          </path>
#         </svg>
#        </a>
#       </li>
#       <!-- -->
#       <!-- -->
#       <li class="style-scope desktop-subnav">
#        <a class="contact style-scope desktop-subnav" href="https://archive.org/about/contact.php">
#         <!--?lit$418799101$-->
#         Contact
#         <!--?lit$418799101$-->
#         <!--?-->
#        </a>
#       </li>
#       <!-- -->
#       <!-- -->
#       <li class="style-scope desktop-subnav">
#        <a class="jobs style-scope desktop-subnav" href="https://archive.org/about/jobs.php">
#         <!--?lit$418799101$-->
#         Jobs
#         <!--?lit$418799101$-->
#         <!--?-->
#        </a>
#       </li>
#       <!-- -->
#       <!-- -->
#       <li class="style-scope desktop-subnav">
#        <a class="volunteer style-scope desktop-subnav" href="https://archive.org/about/volunteerpositions.php">
#         <!--?lit$418799101$-->
#         Volunteer
#         <!--?lit$418799101$-->
#         <!--?-->
#        </a>
#       </li>
#       <!-- -->
#       <!-- -->
#       <li class="style-scope desktop-subnav">
#        <a class="people style-scope desktop-subnav" href="https://archive.org/about/bios.php">
#         <!--?lit$418799101$-->
#         People
#         <!--?lit$418799101$-->
#         <!--?-->
#        </a>
#       </li>
#       <!-- -->
#      </ul>
#     </desktop-subnav>
#     <div class="style-scope ia-topnav" id="close-layer">
#     </div>
#    </ia-topnav>
#   </div>
#   <input class="js-tvsearch" type="hidden" value='{"ands":[],"minday":"06/04/2009","maxday":"03/20/2023"}'/>
#   <script>
#    update_aoheader();
#   </script>
#   <div style="display: block; float: right; width: 28px; margin-top: 4px;">
#    <a class="social_button" href="#" onclick="window.open('https://www.facebook.com/sharer/sharer.php?u=' + encodeURIComponent(window.location.href), '', 'height=400,width=600'); return false;" title="Share on Facebook">
#     <span class="iconochive-facebook" style="color:#3b5998;font-size:160%;">
#     </span>
#    </a>
#    <a class="social_button" href="#" onclick="window.open('https://twitter.com/intent/tweet?text=' + encodeURIComponent(window.location.href) + '&amp;via=internetarchive', '', 'height=400,width=600'); return false;" title="Share on Twitter">
#     <span class="iconochive-twitter" style="color:#1dcaff;font-size:160%;">
#     </span>
#    </a>
#   </div>
#   <script>
#    var config = {"api_url_anchor": "/__wb/search/anchor?q={{query}}", "api_url_calendar_captures": "/__wb/calendarcaptures?url={{url}}\u0026selected_year={{year}}", "api_url_host": "/__wb/search/host?q={{query}}", "api_url_metadata": "/__wb/search/metadata?q={{query}}", "api_url_sitemap": "/web/timemap/json?url={{url}}/\u0026fl=timestamp:4,original,urlkey\u0026matchType=prefix\u0026filter=statuscode:200\u0026filter=mimetype:text/html\u0026collapse=urlkey\u0026collapse=timestamp:4\u0026limit=100000", "api_url_sparkline": "/__wb/sparkline?output=json\u0026url={{url}}\u0026collection=web", "bundling": {"public_path": "/static/bower_components/wayback-search-js/dist"}, "diff": {"cdxServer": "/web/timemap", "diffgraphPrefix": "/web/diffgraph/", "limit": 3000, "maxSunburstLevelLength": "70", "snapshotsPrefix": "/web/", "sparklineURL": "/__wb/sparkline", "urlPrefix": "/web/diff/", "waybackDiscoverDiff": "https://gext-api.archive.org/services/simhash", "webMonitoringProcessingURL": "https://gext-api.archive.org/services/diff"}, "features": {"beta_promo": false, "changes_calendar": true, "landing": "carousel", "landing_layout_with_trend": false, "search": "v1"}, "num_of_explored_web_pages": "803 billion", "search_v2": {"search_collections": {"defaultIntro": "Welcome to the Wayback Machine collection search service. This service is based on indexes of specific data from selected Collections.\n", "defaultMore": "Collections are groupings of Web archives related to a specific archiving method or source of URLs. For example the \u003ca href=\"https://archive.org/details/mediacloud\"\u003emediacloud\u003c/a\u003e Collection contains URLs sourced from \u003ca href=\"https://mediacloud.org\"\u003emediacloud.org\u003c/a\u003e.\u003cbr /\u003e\u003cbr /\u003e The specific Web page data we are indexing includes: anchor text, all URL parts (file names, hosts, domains), MIME Types, HTTP Status codes \u0026 Web Page Titles. In this way you can search for PDF files, from .mil websites that have the word \u201cnuclear\u201d in their file name.\n", "options": {"EndOfTerm2008WebCrawls": {"intro": "Search #count web pages using an index built from anchor text, all URL parts (file names, hosts, domains), MIME Types, language, HTTP Status codes and the full text of the web pages. \u003cbr /\u003e\u003cbr /\u003e Please send your questions, suggestions, bug reports, etc. to \u003ca href=\"mailto:info@archive.org\"\u003einfo@archive.org\u003c/a\u003e.\n", "more": " ", "search_types": {"default": "text", "horizontal_line_room": 1, "options": [{"icon": "iconochive-texts", "id": "text", "title": "Webpages", "type": "text"}]}, "title": "End Of Term (US Gov) 2008", "url": "https://archive.org/details/cdlweb"}, "EndOfTerm2012WebCrawls": {"intro": "Search #count web pages using an index built from anchor text, all URL parts (file names, hosts, domains), MIME Types, language, HTTP Status codes and the full text of the web pages. \u003cbr /\u003e\u003cbr /\u003e Please send your questions, suggestions, bug reports, etc. to \u003ca href=\"mailto:info@archive.org\"\u003einfo@archive.org\u003c/a\u003e.\n", "more": " ", "search_types": {"default": "text", "horizontal_line_room": 1, "index_mapping": {"text": "search2:eot2012-search-text-202210"}, "options": [{"icon": "iconochive-texts", "id": "text", "title": "Webpages", "type": "text"}]}, "title": "End Of Term (US Gov) 2012", "url": "https://archive.org/details/EndOfTerm2012WebCrawls"}, "EndOfTerm2016WebCrawls": {"intro": "Search #count web pages using an index built from anchor text, all URL parts (file names, hosts, domains), MIME Types, language, HTTP Status codes and the full text of the web pages. \u003cbr /\u003e\u003cbr /\u003e Please send your questions, suggestions, bug reports, etc. to \u003ca href=\"mailto:info@archive.org\"\u003einfo@archive.org\u003c/a\u003e.\n", "more": " ", "search_types": {"default": "text", "horizontal_line_room": 1, "options": [{"icon": "iconochive-texts", "id": "text", "title": "Webpa ...
#       $(document).ready(function(){
# 	var e = $('#react-wayback-search'), c = e.attr('component');
# 	ReactDOM.render(
# 	  React.createElement(window[c], { config: config }),
# 	  e.get(0)
# 	);
#       });
#   </script>
#   <div component="WaybackSearchComponent" id="react-wayback-search">
#   </div>
#   <noscript>
#    <div class="no-script-message">
#     The Wayback Machine requires your browser to support JavaScript, please email
#     <a href="mailto:info@archive.org">
#      info@archive.org
#     </a>
#     <br/>
#     if you have any questions about this.
#    </div>
#   </noscript>
#   <footer>
#    <div id="footerHome">
#     <p>
#      The Wayback Machine is an initiative of the
#      <a href="//archive.org/">
#       Internet Archive
#      </a>
#      ,
#           a 501(c)(3) non-profit, building a digital library of
#           Internet sites and other cultural artifacts in digital form.
#      <br/>
#      Other
#      <a href="//archive.org/projects/">
#       projects
#      </a>
#      include
#      <a href="https://openlibrary.org/">
#       Open Library
#      </a>
#      &amp;
#      <a href="https://archive-it.org">
#       archive-it.org
#      </a>
#      .
#     </p>
#     <p>
#      Your use of the Wayback Machine is subject to the Internet Archive's
#      <a href="//archive.org/about/terms.php">
#       Terms of Use
#      </a>
#      .
#     </p>
#    </div>
#   </footer>
#  </body>
# </html>

# %% [markdown]
# The above HTML generated doesn't contain anything in the `<div>` with the ID <b>react-wayback-search</b>, so we have to use Selenium

# %%
# Edge browser setup for Selenium
edge_driver_path = "edgedriver_win64/msedgedriver.exe"
edge_options = webdriver.EdgeOptions()
browser = webdriver.Edge(executable_path=edge_driver_path, options=edge_options)
action = ActionChains(browser)
# Out:
# /tmp/ipykernel_4138/2147376200.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Edge(executable_path=edge_driver_path, options=edge_options)

# %%
# Fetch kanye tweets calendar URL using Selenium
from selenium.common.exceptions import TimeoutException
browser.set_page_load_timeout(10) # ten seconds should be enough

try:
    browser.get(kanye_tweets_calendar_url)
except TimeoutException:
    browser.execute_script("window.stop();")

# %%
# Print the obtained html
html = BeautifulSoup(browser.page_source,'lxml')
print(html.prettify())
# Out:
# <html lang="en">
#  <head>
#   <style>
#    body {transition: opacity ease-in 0.2s; }
# body[unresolved] {opacity: 0; display: block; overflow: hidden; position: relative; }
#   </style>
#   <title>
#    Wayback Machine
#   </title>
#   <script>
#    /*
#     @licstart  The following is the entire license notice for the JavaScript code in this page.
#
#     Copyright (C) 2020 Internet Archive
#
#     The JavaScript code in this page is free software: you can
#     redistribute it and/or modify it under the terms of the GNU Affero
#     General Public License as published by the Free Software
#     Foundation, either version 3 of the License, or (at your option)
#     any later version.  The code is distributed WITHOUT ANY WARRANTY;
#     without even the implied warranty of MERCHANTABILITY or FITNESS
#     FOR A PARTICULAR PURPOSE.  See the GNU GPL for more details.
#
#     As additional permission under GNU AGPL version 3 section 7, you
#     may distribute non-source (e.g., minimized or compacted) forms of
#     that code without the copy of the GNU AGPL normally required by
#     section 4, provided you include this license notice and a URL
#     through which recipients can access the Corresponding Source.
#
#     @licend  The above is the entire license notice for the JavaScript code in this page.
#     */
#   </script>
#   <script type="text/javascript">
#    window.webComponentLoaderConfig = {
#       baseUrl: 'https://archive.org',
#       version: '29e56e87'
#       }
#   </script>
#   <script src="https://polyfill.archive.org/v3/polyfill.min.js?features=fetch,IntersectionObserver,ResizeObserver,globalThis,Element.prototype.getAttributeNames,String.prototype.startsWith,Array.prototype.flat,Element.prototype.closest,Element.prototype.scroll,Element.prototype.remove,Object.entries,Object.values,Object.fromEntries">
#   </script>
#   <script src="//archive.org/includes/analytics.js?v=99cd22af" type="text/javascript">
#   </script>
#   <script src="//archive.org/components/npm/lit/polyfill-support.js?v=99cd22af" type="text/javascript">
#   </script>
#   <script src="//archive.org/components/npm/@webcomponents/webcomponentsjs/webcomponents-bundle.js?v=99cd22af" type="text/javascript">
#   </script>
#   <script src="//archive.org/includes/build/js/ia-topnav.min.js?v=99cd22af" type="text/javascript">
#   </script>
#   <script src="//archive.org/includes/build/js/archive.min.js?v=99cd22af" type="text/javascript">
#   </script>
#   <link href="//archive.org/includes/build/css/archive.min.css?v=99cd22af" rel="stylesheet" type="text/css"/>
#   <meta content="" property="mediatype"/>
#   <meta content="" property="primary_collection"/>
#   <script type="text/javascript">
#    if('archive_analytics' in window){var v=archive_analytics.values;v.path='/web';v.service='wb';v.server_name='wwwb-app224.us.archive.org';v.server_ms=361;archive_analytics.send_pageview_on_load()}
#   </script>
#   <link href="/_static/images/archive.ico" rel="shortcut icon"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <link href="/_static/css/styles.css?v=X-Ndhul9" rel="stylesheet" type="text/css"/>
#   <script charset="utf-8" src="/_static/js/ui.js?v=NTAW0JFh" type="text/javascript">
#   </script>
#   <base target="_top"/>
#   <link href="/_static/css/web.css" rel="stylesheet" type="text/css"/>
#   <!-- include component js and css -->
#   <link href="/static/bower_components/wayback-search-js/dist/vendors~main.03b707f24a12f0713158.chunk.css" rel="stylesheet" type="text/css"/>
#   <link href="/static/bower_components/wayback-search-js/dist/main.c4ddbcab83782ceda455.chunk.css" rel="stylesheet" type="text/css"/>
#   <script src="/static/bower_components/wayback-search-js/dist/runtime.8c43e03bdeab7483f8ff.js">
#   </script>
#   <script src="/static/bower_components/wayback-search-js/dist/vendors~main.03b707f24a12f0713158.chunk.js">
#   </script>
#   <script src="/static/bower_components/wayback-search-js/dist/main.c4ddbcab83782ceda455.chunk.js">
#   </script>
#   <script src="https://archive.org/web/carouFredSel/jquery.carouFredSel-6.2.1-packed.js?v6.2.1" type="text/javascript">
#   </script>
#   <style>
#    html, body { margin:0; padding:0 }
#       #faux-header {
#         height: 50px;
#         width: 100%;
#         margin:0;
#         background-color:black;
#       }
#       #react-wayback-search {
#         max-width: 1170px;
#         margin: 0 auto;
#         padding: 10px;
#       }
#   </style>
#  </head>
#  <body class="navia">
#   <div class="ia-banners">
#    <div class="ia-banner info pre-court-day visible" data-campaign="pre-court-day">
#     <p>
#      We're fighting for the future of our library in court.
#      <a href="https://blog.archive.org/2023/03/17/heres-how-to-participate-in-mondays-oral-arguments/" rel="nofollow">
#       Show your support now!
#      </a>
#     </p>
#     <form action="" class="banner-close" data-action="ia-banner-close" method="get">
#      <fieldset>
#       <button aria-label="Close Banner" type="submit">
#       </button>
#      </fieldset>
#     </form>
#    </div>
#   </div>
#   <div id="topnav">
#    <input class="js_nav_tweaks" type="hidden" value="[]"/>
#    <!-- Shady DOM styles for icon-hamburger -->
#    <style scope="icon-hamburger-1">
#     .icon-hamburger-1 svg.icon-hamburger {
#   display: block;
# }
#
# .icon-hamburger-1 .fill-color.icon-hamburger {
#   fill: #fff;
# }
#    </style>
#    <!-- Shady DOM styles for login-button -->
#    <style scope="login-button-1">
#     .login-button-1 .dropdown-toggle.login-button {
#   display: block;
#     height: 4rem;
#     font-size: 1.6rem;
#     text-transform: uppercase;
#     text-decoration: none;
#     color: #ccc;
#     cursor: pointer;
# }
#
# .login-button-1 .dropdown-toggle.login-button .fill-color.login-button {
#   fill: #999;
# }
#
# .login-button-1 .dropdown-toggle.login-button:active .fill-color.login-button,.login-button-1 .dropdown-toggle.login-button:focus .fill-color.login-button,.login-button-1 .dropdown-toggle.login-button:hover .fill-color.login-button {
#   fill: #fff;
# }
#
# .login-button-1 .active.login-button {
#   border-radius: 1rem 1rem 0 0;
#     background: #333;
# }
#
# .login-button-1 .active.login-button .fill-color.login-button {
#   fill: #fff;
# }
#
# .login-button-1 span.login-button {
#   display: none;
#     font-size: 1.4rem;
#     text-transform: uppercase;
#     color: #999;
# }
#
# .login-button-1 span.login-button a.login-button {
#   color: inherit;
#     text-decoration: none;
# }
#
# .login-button-1 a.login-button:hover,.login-button-1 a.login-button:active,.login-button-1 a.login-button:focus {
#   color: #fff;
# }
#
# @media (min-width: 890px) {
# .login-button-1 .logged-out-toolbar.login-button {
#   transform: translateY(-.5rem);
# }
#
# .login-button-1 .active.login-button {
#   background: transparent;
# }
#
# .login-button-1 .dropdown-toggle.login-button {
#   display: inline-block;
#       vertical-align: middle;
# }
#
# .login-button-1 span.login-button {
#   display: inline;
#       vertical-align: middle;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for nav-search -->
#    <style scope="nav-search-1">
#     .nav-search-1 input.nav-search[type="text"] {
#   color: #222;
# }
#
# .nav-search-1 input.nav-search:focus {
#   outline: none;
# }
#
# .nav-search-1 button.nav-search {
#   background: none;
#     color: inherit;
#     border: none;
#     font: inherit;
#     cursor: pointer;
# }
#
# .nav-search-1 button.nav-search:focus {
#   outline: none;
# }
#
# .nav-search-1 .search.nav-search {
#   padding-top: 0;
#     margin-right: 0.5rem;
# }
#
# .nav-search-1 .search.nav-search svg.nav-search {
#   position: relative;
#     top: -5px;
#     right: -3px;
#     fill:;
# }
#
# .nav-search-1 .search-activated.nav-search {
#   display: -webkit-box;
#     display: -ms-flexbox;
#     display: flex;
#     position: absolute;
#     top: 0;
#     right: 4rem;
#     bottom: 0;
#     left: 4rem;
#     z-index: 3;
#     padding: 0.5rem 0.2rem;
#     border-radius: 1rem 1rem 0 0;
#     background: #333;
# }
#
# .nav-search-1 .search-inactive.nav-search {
#   display: none;
# }
#
# .nav-search-1 .search-activated.nav-search .highlight.nav-search,.nav-search-1 .search-activated.nav-search .search.nav-search {
#   background: #fff;
#     border-radius: 0.5rem;
# }
#
# .nav-search-1 .search-activated.nav-search .highlight.nav-search {
#   display: -webkit-box;
#     display: -ms-flexbox;
#     display: flex;
#     width: 100%;
#     margin: 0 0.5rem;
# }
#
# .nav-search-1 .search-activated.nav-search .search.nav-search {
#   height: 100%;
#     padding: 0;
#     margin-right: 0;
#     -ms-flex-item-align: center;
#     -ms-grid-row-align: center;
#     align-self: center;
# }
#
# .nav-search-1 .search-activated.nav-search .search-field.nav-search {
#   width: 100%;
#     height: 100%;
#     box-sizing: border-box;
#     padding-left: 1rem;
#     border-radius: 0.5rem;
#     border: none;
#     font-size: 1.6rem;
#     text-align: center;
# }
#
# .nav-search-1 .search-activated.nav-search .search-field.nav-search:focus {
#   outline: none;
# }
#
# @keyframes fade-in-nav-search-1 {
# 0% {
#   opacity: 0;
# }
#
# 100% {
#   opacity: 1;
# }
#
# }
#
# .nav-search-1 .fade-in.nav-search {
#   animation: fade-in-nav-search-1 0.2s forwards;
# }
#
# @media (min-width: 890px) {
# .nav-search-1 .search.nav-search svg.nav-search {
#   display: inline;
#       width: 28px;
#       height: 28px;
#       vertical-align: -14px;
# }
#
# .nav-search-1 .search.nav-search path.nav-search {
#   fill: #333;
# }
#
# .nav-search-1 .search-inactive.nav-search,.nav-search-1 .search-activated.nav-search {
#   display: block;
#       position: static;
#       padding: 1.2rem 0.2rem;
#       background: transparent;
# }
#
# .nav-search-1 .search-activated.nav-search .highlight.nav-search {
#   width: 13rem;
#       height: 2.8rem;
#       -webkit-box-orient: horizontal;
#       -webkit-box-direction: reverse;
#       -ms-flex-direction: row-reverse;
#       flex-direction: row-reverse;
# }
#
# .nav-search-1 .search-activated.nav-search .search-field.nav-search {
#   width: calc(100% - 28px);
#       height: 100%;
#       padding-left: 0;
#       font-size: 1.4rem;
#       text-align: left;
# }
#
# .nav-search-1 .search-activated.nav-search .search.nav-search svg.nav-search {
#   width: 28px;
#       height: 28px;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for media-button -->
#    <style scope="media-button-1">
#     .media-button-1 a.media-button {
#   display: inline-block;
#     text-decoration: none;
# }
#
# .media-button-1 .menu-item.media-button {
#   display: inline-flex;
#     width: 100%;
#     padding: 0;
#     font-size: 1.6rem;
#     text-align: left;
#     background: transparent;
#     -webkit-box-align: center;
#     -ms-flex-align: center;
#     align-items: center;
# }
#
# .media-button-1 .menu-item.media-button:focus {
#   outline: none;
# }
#
# .media-button-1 .label.media-button {
#   display: inline-block;
#     padding: 0;
#     font-weight: 400;
#     color: #fff;
#     text-align: left;
#     vertical-align: middle;
# }
#
# .media-button-1 .menu-item.media-button > .icon.media-button {
#   display: inline-flex;
#     width: 42px;
#     height: 42px;
#     vertical-align: middle;
#     -webkit-box-align: center;
#     -ms-flex-align: center;
#     align-items: center;
#     -webkit-box-pack: center;
#     -ms-flex-pack: center;
#     justify-content: center;
# }
#
# .media-button-1 .menu-item.selected.media-button .icon.media-button {
#   background-color: #333;
#     border-radius: 1rem 0 0 1rem;
# }
#
# .media-button-1 .icon.media-button .fill-color.media-button {
#   fill: #999;
# }
#
# .media-button-1 .icon.active.media-button .fill-color.media-button {
#   fill: #fff;
# }
#
# .media-button-1 .donate.media-button .fill-color.media-button {
#   fill: #f00;
# }
#
# @media (min-width: 890px) {
# .media-button-1 .menu-item.media-button {
#   width: auto;
#       height: 5rem;
#       color: #999;
# }
#
# .media-button-1 .menu-item.media-button:hover,.media-button-1 .menu-item.media-button:active,.media-button-1 .menu-item.media-button:focus {
#   color: #fff;
# }
#
# .media-button-1 .menu-item.media-button:hover .fill-color.media-button,.media-button-1 .menu-item.media-button:active .fill-color.media-button,.media-button-1 .menu-item.media-button:focus .fill-color.media-button {
#   fill: #fff;
# }
#
# .media-button-1 .label.media-button {
#   display: none;
# }
#
# .media-button-1 .label.media-button,.media-button-1 .web.media-button:after {
#   padding-right: 1rem;
#       font-size: 1.3rem;
#       text-transform: uppercase;
#       color: inherit;
# }
#
# .media-button-1 .web.media-button:after {
#   display: none;
#       content: "web";
# }
#
# .media-button-1 .donate.media-button,.media-button-1 .more.media-button {
#   display: none;
# }
#
# .media-button-1 .menu-item.selected.media-button {
#   background: #474747;
# }
#
# .media-button-1 .menu-item.selected.media-button .label.media-button,.media-button-1 .menu-item.selected.web.media-button:after {
#   color: #fff;
# }
#
# .media-button-1 .menu-item.selected.media-button .icon.media-button {
#   background: transparent;
# }
#
# .media-button-1 .web.selected.media-button .fill-color.media-button {
#   fill: #ffcd27;
# }
#
# .media-button-1 .texts.selected.media-button .fill-color.media-button {
#   fill: #faab3c;
# }
#
# .media-button-1 .video.selected.media-button .fill-color.media-button {
#   fill: #f1644b;
# }
#
# .media-button-1 .audio.selected.media-button .fill-color.media-button {
#   fill: #00adef;
# }
#
# .media-button-1 .software.selected.media-button .fill-color.media-button {
#   fill: #9ecc4f;
# }
#
# .media-button-1 .images.selected.media-button .fill-color.media-button {
#   fill: #aa99c9;
# }
#
# }
#
# @media (min-width: 1300px) {
# .media-button-1 .label.media-button,.media-button-1 .web.media-button:after {
#   display: inline;
# }
#
# .media-button-1 .web.media-button .label.media-button {
#   display: none;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for media-menu -->
#    <style scope="media-menu-1">
#     .media-menu-1 {
#   outline: none;
# }
#
# .media-menu-1 .media-menu-inner.media-menu {
#   z-index: -1;
#     top: -40rem;
#     background-color: #222;
#     margin: 0;
#     overflow: hidden;
#     transition-duration: 0.2s;
#     transition-property: top;
#     transition-timing-function: ease;
# }
#
# .media-menu-1 .menu-group.media-menu {
#   position: relative;
#     line-height: normal;
# }
#
# @media (max-width: 889px) {
# .media-menu-1 .media-menu-container.media-menu {
#   position: relative;
# }
#
# .media-menu-1 .media-menu-inner.media-menu {
#   position: absolute;
#       width: 100%;
# }
#
# .media-menu-1 .open.media-menu .media-menu-inner.media-menu {
#   top: 0;
# }
#
# .media-menu-1 .overflow-clip.media-menu {
#   position: absolute;
#       z-index: -1;
#       top: 0;
#       left: 0;
#       height: 0;
#       width: 100%;
#       overflow: hidden;
#       transition-duration: 0.2s;
#       transition-property: height;
# }
#
# .media-menu-1 .open.media-menu .overflow-clip.media-menu {
#   height: 40rem;
# }
#
# }
#
# @media (min-width: 890px) {
# .media-menu-1 .media-menu-inner.media-menu {
#   display: inline-block;
#       position: static;
#       width: auto;
#       height: 5rem;
#       transition-property: none;
# }
#
# .media-menu-1 .menu-group.media-menu {
#   font-size: 0;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for primary-nav -->
#    <style scope="primary-nav-1">
#     .primary-nav-1 button.primary-nav:focus,.primary-nav-1 a.primary-nav:focus,.primary-nav-1 input.primary-nav:focus {
#   outline: none;
# }
#
# .primary-nav-1 nav.primary-nav {
#   position: relative;
#     display: -ms-grid;
#     display: grid;
#     height: 4rem;
#     grid-template-areas: 'hamburger empty search user';
#     -ms-grid-columns: 4rem minmax(1rem, 100%) 4.3rem 4rem;
#     grid-template-columns: 4rem auto 4.3rem 4rem;
#     -ms-grid-rows: 100%;
#     grid-template-rows: 100%;
#     background: #222;
#     border-bottom: 1px solid #333;
# }
#
# .primary-nav-1 button.primary-nav {
#   background: none;
#     color: inherit;
#     border: none;
#     font: inherit;
#     cursor: pointer;
# }
#
# .primary-nav-1 .branding.primary-nav {
#   position: static;
#     float: left;
#     padding: 0 5px 0 10px;
#     -webkit-transform: translate(0, 0);
#     -ms-transform: translate(0, 0);
#     transform: translate(0, 0);
# }
#
# .primary-nav-1 slot.primary-nav,.primary-nav-1 .branding.primary-nav {
#   display: flex;
#     justify-content: left;
#     align-items: center;
# }
#
# .primary-nav-1 media-menu.primary-nav {
#   grid-column-start: hamburger-start;
#     grid-column-end: user-end;
# }
#
# .primary-nav-1 .ia-logo.primary-nav,.primary-nav-1 .ia-wordmark.primary-nav {
#   margin-right: 5px;
# }
#
# .primary-nav-1 .hamburger.primary-nav {
#   -ms-grid-row: 1;
#     -ms-grid-column: 1;
#     grid-area: hamburger;
#     padding: 0;
# }
#
# .primary-nav-1 .search-trigger.primary-nav {
#   -ms-grid-row: 1;
#     -ms-grid-column: 3;
#     grid-area: search;
#     position: relative;
#     padding: 0;
#     z-index: 1;
#     width: 100%;
#     text-align: right;
#     -webkit-box-align: center;
#     -ms-flex-align: center;
#     align-items: center;
# }
#
# .primary-nav-1 .search-trigger.primary-nav .fill-color.primary-nav {
#   fill: #999;
# }
#
# .primary-nav-1 .search-activated.primary-nav {
#   position: relative;
#     z-index: 3;
# }
#
# .primary-nav-1 .upload.primary-nav {
#   display: none;
# }
#
# .primary-nav-1 .upload.primary-nav span.primary-nav {
#   display: none;
# }
#
# .primary-nav-1 .user-info.primary-nav {
#   -ms-grid-row: 1;
#     -ms-grid-column: 4;
#     grid-area: user;
#     -ms-grid-row-align: stretch;
#     align-self: stretch;
#     -ms-grid-column-align: end;
#     justify-self: end;
# }
#
# .primary-nav-1 .username.primary-nav {
#   display: none;
#     font-size: 1.3rem;
#     vertical-align: middle;
#     text-transform: uppercase;
# }
#
# .primary-nav-1 .user-menu.primary-nav {
#   height: 100%;
#     padding: 0.5rem 1rem;
#     color: #999;
# }
#
# .primary-nav-1 .user-menu.primary-nav:hover {
#   color: #fff;
# }
#
# .primary-nav-1 .user-menu.active.primary-nav {
#   border-radius: 1rem 1rem 0 0;
#     background: #333;
# }
#
# .primary-nav-1 .user-menu.primary-nav img.primary-nav {
#   display: block;
#     width: 30px;
#     height: 30px;
# }
#
# .primary-nav-1 .link-home.primary-nav {
#   display: flex;
#     text-decoration: none;
# }
#
# @media only screen and (min-width: 890px) and (max-device-width: 905px) {
# .primary-nav-1 .branding.second-logo.primary-nav {
#   padding-right: 0;
# }
#
# }
#
# @media (min-width: 906px) {
# .primary-nav-1 .branding.second-logo.primary-nav {
#   padding-right: 20px;
# }
#
# }
#
# @media (max-width: 889px) {
# .primary-nav-1 slot.primary-nav[name='opt-sec-logo'] {
#   display: none;
# }
#
# }
#
# @media (min-width: 890px) {
# .primary-nav-1 {
#   ;
# }
#
# .primary-nav-1 nav.primary-nav {
#   display: block;
#       z-index: 2;
#       height: 5rem;
#       padding-right: 1.5rem;
# }
#
# .primary-nav-1 slot.primary-nav[name='opt-sec-logo-mobile'] {
#   display: none;
# }
#
# .primary-nav-1 .branding.primary-nav {
#   margin-top: 1rem;
# }
#
# .primary-nav-1 .ia-logo.primary-nav,.primary-nav-1 .ia-wordmark.primary-nav {
#   margin-right: 10px;
# }
#
# .primary-nav-1 .hamburger.primary-nav,.primary-nav-1 .search-trigger.primary-nav {
#   display: none;
# }
#
# .primary-nav-1 .user-info.primary-nav {
#   float: right;
#       padding-top: 1rem;
# }
#
# .primary-nav-1 .user-menu.primary-nav {
#   padding-top: 0;
# }
#
# .primary-nav-1 .user-menu.active.primary-nav {
#   background: transparent;
# }
#
# .primary-nav-1 .user-menu.primary-nav img.primary-nav {
#   display: inline-block;
#       vertical-align: middle;
# }
#
# .primary-nav-1 .upload.primary-nav {
#   display: block;
#       float: right;
#       margin-top: 1rem;
#       font-size: 1.4rem;
#       text-transform: uppercase;
#       text-decoration: none;
#       color: #999;
# }
#
# .primary-nav-1 .upload.primary-nav:active,.primary-nav-1 .upload.primary-nav:focus,.primary-nav-1 .upload.primary-nav:hover {
#   color: #fff;
# }
#
# .primary-nav-1 .upload.primary-nav svg.primary-nav {
#   width: 32px;
#       height: 32px;
#       vertical-align: middle;
#       fill: #999;
# }
#
# .primary-nav-1 .upload.primary-nav:hover svg.primary-nav,.primary-nav-1 .upload.primary-nav:focus svg.primary-nav,.primary-nav-1 .upload.primary-nav:active svg.primary-nav {
#   fill: #fff;
# }
#
# .primary-nav-1 nav-search.primary-nav {
#   float: right;
#       margin-left: 1rem;
# }
#
# .primary-nav-1 login-button.primary-nav {
#   display: block;
#       margin-right: 1rem;
# }
#
# }
#
# @media (min-width: 990px) {
# .primary-nav-1 .username.primary-nav {
#   display: inline-block;
# }
#
# .primary-nav-1 .upload.primary-nav span.primary-nav {
#   display: inline;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for user-menu -->
#    <!-- Shady DOM styles for search-menu -->
#    <style scope="search-menu-1">
#     .search-menu-1 .menu-wrapper.search-menu {
#   position: relative;
# }
#
# .search-menu-1 button.search-menu:focus,.search-menu-1 input.search-menu:focus {
#   outline-color: #428bca;
#     outline-width: 0.16rem;
#     outline-style: auto;
# }
#
# .search-menu-1 .search-menu-inner.search-menu {
#   position: absolute;
#     right: 0;
#     left: 0;
#     z-index: 2;
#     padding: 0 4.5rem;
#     font-size: 1.6rem;
#     background-color: #333;
# }
#
# .search-menu-1 .tx-slide.search-menu {
#   overflow: hidden;
#     transition-property: top;
#     transition-duration: 0.2s;
#     transition-timing-function: ease;
# }
#
# .search-menu-1 .initial.search-menu,.search-menu-1 .closed.search-menu {
#   top: -1500px;
# }
#
# .search-menu-1 .closed.search-menu {
#   transition-duration: 0.2s;
# }
#
# .search-menu-1 label.search-menu,.search-menu-1 a.search-menu {
#   padding: 1rem;
#     display: block;
# }
#
# .search-menu-1 .advanced-search.search-menu {
#   text-decoration: none;
#     color: #428bca;
# }
#
# @media (min-width: 890px) {
# .search-menu-1 .search-menu-inner.search-menu {
#   overflow: visible;
#       right: 2rem;
#       left: auto;
#       z-index: 5;
#       padding: 1rem 2rem;
#       transition: opacity 0.2s ease-in-out;
#       font-size: 1.4rem;
#       color: #333;
#       border-radius: 2px;
#       background: #fff;
#       box-shadow: 0 1px 2px 1px rgba(0, 0, 0, 0.15);
# }
#
# .search-menu-1 .search-menu-inner.search-menu:after {
#   position: absolute;
#       right: 7px;
#       top: -7px;
#       width: 12px;
#       height: 7px;
#       box-sizing: border-box;
#       color: #fff;
#       content: '';
#       border-bottom: 7px solid currentColor;
#       border-left: 6px solid transparent;
#       border-right: 6px solid transparent;
# }
#
# .search-menu-1 .initial.search-menu,.search-menu-1 .closed.search-menu {
#   opacity: 0;
#       transition-duration: 0.2s;
# }
#
# .search-menu-1 .open.search-menu {
#   opacity: 1;
# }
#
# .search-menu-1 label.search-menu {
#   padding: 0;
# }
#
# .search-menu-1 label.search-menu + label.search-menu {
#   padding-top: 7px;
# }
#
# .search-menu-1 a.search-menu {
#   padding: 1rem 0 0 0;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for ia-wayback-search -->
#    <!-- Shady DOM styles for wayback-search -->
#    <style scope="wayback-search-1">
#     .wayback-search-1 {
#   font: normal 1.2rem/1.5 'Helvetica Neue', Helvetica, Arial, sans-serif;
# }
#
# .wayback-search-1 form.wayback-search {
#   max-width: 600px;
# }
#
# .wayback-search-1 p.wayback-search {
#   margin-top: 0;
#     font-weight: 200;
# }
#
# .wayback-search-1 a.wayback-search {
#   font-weight: 500;
#     text-decoration: none;
#     color: #fff;
# }
#
# .wayback-search-1 fieldset.wayback-search {
#   padding: 0.7rem 2rem;
#     margin: 1.5rem 0;
#     box-sizing: border-box;
#     text-align: center;
#     border: none;
#     border-radius: 7px;
#     background-color: #fcf5e6;
#     box-shadow: 3px 3px 0 0 #c3ad97;
# }
#
# .wayback-search-1 label.wayback-search {
#   display: none;
# }
#
# .wayback-search-1 img.wayback-search {
#   width: 100%;
#     max-width: 215px;
#     max-height: 60px;
#     margin-bottom: 1.3rem;
#     vertical-align: middle;
# }
#
# .wayback-search-1 input.wayback-search {
#   display: block;
#     width: 100%;
#     height: 3rem;
#     padding: 0.5rem 1rem 0.5rem 2.5rem;
#     font: normal 1.2rem/1.5 'Helvetica Neue', Helvetica, Arial, sans-serif;
#     color: #858585;
#     box-sizing: border-box;
#     border: 1px solid #ccc;
#     border-radius: 2rem;
#     background: #eee;
# }
#
# .wayback-search-1 input.wayback-search:focus {
#   border-color: #66afe9;
#     box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.075), 0 0 8px rgba(102, 175, 233, 0.6);
#     outline: none;
# }
#
# .wayback-search-1 .search-field.wayback-search {
#   position: relative;
#     overflow: hidden;
# }
#
# .wayback-search-1 .search-field.wayback-search svg.wayback-search {
#   position: absolute;
#     top: 2px;
#     left: 3px;
#     width: 24px;
#     height: 24px;
# }
#
# .wayback-search-1 .search-field.wayback-search .fill-color.wayback-search {
#   fill: #999;
# }
#
# .wayback-search-1 input.wayback-search:focus + svg.wayback-search {
#   display: none;
# }
#
# @media (min-width: 890px) {
# .wayback-search-1 form.wayback-search {
#   margin: 0 auto;
# }
#
# .wayback-search-1 p.wayback-search {
#   margin-bottom: 3rem;
#       font-size: 1.6rem;
#       text-align: center;
# }
#
# .wayback-search-1 img.wayback-search {
#   margin: 0;
# }
#
# .wayback-search-1 fieldset.wayback-search {
#   margin: 0 auto;
#       font-size: 0;
# }
#
# .wayback-search-1 fieldset.wayback-search a.wayback-search,.wayback-search-1 .search-field.wayback-search {
#   display: inline-block;
#       width: 50%;
#       vertical-align: middle;
# }
#
# .wayback-search-1 fieldset.wayback-search a.wayback-search {
#   text-align: center;
# }
#
# .wayback-search-1 .search-field.wayback-search svg.wayback-search {
#   width: 28px;
#       height: 28px;
# }
#
# .wayback-search-1 .search-field.wayback-search .fill-color.wayback-search {
#   fill: #333;
# }
#
# }
#
# .wayback-search-1 p.wayback-search {
#   margin-bottom: 1rem;
#     font-size: 1.6rem;
#     text-align: center;
# }
#
# .wayback-search-1 fieldset.wayback-search {
#   padding: .5rem;
#     border-radius: 5px;
#     box-shadow: none;
# }
#
# .wayback-search-1 input.wayback-search {
#   padding-left: 3rem;
#     margin-top: .3rem;
#     font-size: 1.4rem;
#     border-color: #bca38e;
#     background: #fff;
# }
#
# .wayback-search-1 input.wayback-search::placeholder,.wayback-search-1 input.wayback-search::-webkit-input-placeholder {
#   color: #8e8e8e;
# }
#
# .wayback-search-1 .search-field.wayback-search svg.wayback-search {
#   top: 50%;
#     transform: translateY(-50%);
# }
#
# @media (min-width: 890px) {
# .wayback-search-1 fieldset.wayback-search a.wayback-search,.wayback-search-1 .search-field.wayback-search {
#   display: block;
#       width: auto;
# }
#
# .wayback-search-1 fieldset.wayback-search a.wayback-search {
#   margin: 0 1.5rem;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for save-page-form -->
#    <style scope="save-page-form-1">
#     .save-page-form-1 div.save-page-form {
#   display: grid;
#     grid-template-columns: 1fr auto;
#     grid-column-gap: .8rem;
#     margin: 0;
#     padding: 0;
#     border: none;
# }
#
# .save-page-form-1 input.save-page-form[type="text"] {
#   width: 100%;
#     height: 30px;
#     box-sizing: border-box;
#     border: 1px solid #999;
#     border-radius: .5rem;
#     color: #222;
# }
#
# .save-page-form-1 input.save-page-form[type="submit"] {
#   -webkit-appearance: none;
#     -moz-appearance: none;
#     appearance: none;
#     padding: .4rem .8rem;
#     font: normal 1.3rem 'Helvetica Neue', Helvetica, Arial, sans-serif;
#     text-transform: uppercase;
#     color: #fff;
#     border: none;
#     border-radius: 16px;
#     background: #222;
#     cursor: pointer;
# }
#
# .save-page-form-1 .error.save-page-form {
#   display: none;
#     margin-top: .5rem;
#     font-weight: bold;
#     color: #ffcd27;
# }
#
# .save-page-form-1 .visible.save-page-form {
#   display: block;
# }
#
# @media (min-width: 890px) {
# .save-page-form-1 h3.save-page-form {
#   margin-top: 0;
#       font: normal 100 1.6rem 'Helvetica Neue', Helvetica, Arial, sans-serif;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for wayback-slider -->
#    <style scope="wayback-slider-1">
#     .wayback-slider-1 h4.wayback-slider {
#   font-size: 1.6rem;
# }
#
# .wayback-slider-1 a.wayback-slider {
#   text-decoration: none;
#     color: #fff;
# }
#
# .wayback-slider-1 ul.wayback-slider {
#   padding: 0;
#     margin: 0;
#     list-style: none;
# }
#
# .wayback-slider-1 li.wayback-slider + li.wayback-slider {
#   padding-top: 1.5rem;
# }
#
# @media (min-width: 890px) {
# .wayback-slider-1 h4.wayback-slider {
#   margin: 0 0 1rem 0;
#       font-weight: 100;
# }
#
# .wayback-slider-1 ul.wayback-slider {
#   font-size: 1.3rem;
# }
#
# .wayback-slider-1 li.wayback-slider {
#   padding-bottom: .5rem;
# }
#
# .wayback-slider-1 li.wayback-slider + li.wayback-slider {
#   padding-top: 0;
# }
#
# .wayback-slider-1 li.wayback-slider a.wayback-slider {
#   display: block;
#       overflow: hidden;
#       white-space: nowrap;
#       text-overflow: ellipsis;
# }
#
# }
#
# @media (min-width: 890px) {
# .wayback-slider-1 {
#   display: block;
#       grid-column: 1 / 4;
#       padding: 0 1.5rem;
# }
#
# .wayback-slider-1 h4.wayback-slider {
#   margin-top: 0;
#       font: normal 100 1.6rem 'Helvetica Neue', Helvetica, Arial, sans-serif;
# }
#
# .wayback-slider-1 .grid.wayback-slider {
#   display: grid;
#       grid-template-columns: minmax(auto, 260px) 1fr minmax(auto, 260px);
#
#       grid-column-gap: 2.5rem;
# }
#
# .wayback-slider-1 .link-lists.wayback-slider {
#   display: grid;
#       grid-template-columns: calc(50% - 1.25rem) calc(50% - 1.25rem);
#       grid-column-gap: 2.5rem;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for more-slider -->
#    <style scope="more-slider-1">
#     .more-slider-1 ul.more-slider {
#   padding: 0;
#     margin: -1rem 0 0 0;
#     list-style: none;
# }
#
# .more-slider-1 a.more-slider {
#   display: block;
#     padding: 1rem 0;
#     text-decoration: none;
#     color: #fff;
# }
#    </style>
#    <!-- Shady DOM styles for media-subnav -->
#    <style scope="media-subnav-1">
#     .media-subnav-1 h4.media-subnav {
#   font-size: 1.6rem;
# }
#
# .media-subnav-1 a.media-subnav {
#   text-decoration: none;
#     color: #fff;
# }
#
# .media-subnav-1 ul.media-subnav {
#   padding: 0;
#     margin: 0;
#     list-style: none;
# }
#
# .media-subnav-1 li.media-subnav + li.media-subnav {
#   padding-top: 1.5rem;
# }
#
# @media (min-width: 890px) {
# .media-subnav-1 h4.media-subnav {
#   margin: 0 0 1rem 0;
#       font-weight: 100;
# }
#
# .media-subnav-1 ul.media-subnav {
#   font-size: 1.3rem;
# }
#
# .media-subnav-1 li.media-subnav {
#   padding-bottom: .5rem;
# }
#
# .media-subnav-1 li.media-subnav + li.media-subnav {
#   padding-top: 0;
# }
#
# .media-subnav-1 li.media-subnav a.media-subnav {
#   display: block;
#       overflow: hidden;
#       white-space: nowrap;
#       text-overflow: ellipsis;
# }
#
# }
#
# .media-subnav-1 img.media-subnav {
#   display: block;
#     width: 90px;
#     height: 90px;
#     margin: 0 auto 1rem auto;
#     border-radius: 45px;
# }
#
# .media-subnav-1 h3.media-subnav {
#   margin-top: 0;
#     font-size: 1.8rem;
# }
#
# .media-subnav-1 .icon-links.media-subnav {
#   display: -webkit-box;
#     display: -ms-flexbox;
#     display: flex;
#     -webkit-box-pack: space-evenly;
#     -ms-flex-pack: space-evenly;
#     justify-content: space-evenly;
#     text-align: center;
# }
#
# .media-subnav-1 .icon-links.media-subnav a.media-subnav {
#   display: inline-block;
#     width: 120px;
#     margin-bottom: 1.5rem;
#     overflow: hidden;
#     white-space: nowrap;
#     text-align: center;
#     text-overflow: ellipsis;
# }
#
# .media-subnav-1 .icon-links.media-subnav a.media-subnav + a.media-subnav {
#   margin-left: 2rem;
# }
#
# .media-subnav-1 .featured.media-subnav h4.media-subnav {
#   display: none;
# }
#
# @media (min-width: 890px) {
# .media-subnav-1 {
#   display: -ms-grid;
#       display: grid;
#       -ms-grid-columns: 40% 20% 40%;
#       grid-template-columns: 40% 20% 40%;
# }
#
# .media-subnav-1 .wayback-search.media-subnav {
#   -ms-grid-column: 1;
#       -ms-grid-column-span: 3;
#       grid-column: 1 / 4;
# }
#
# .media-subnav-1 h3.media-subnav {
#   display: none;
# }
#
# .media-subnav-1 .icon-links.media-subnav {
#   -ms-grid-column: 1;
# }
#
# .media-subnav-1 .icon-links.media-subnav a.media-subnav {
#   padding-top: 3.5rem;
#       max-width: 160px;
# }
#
# .media-subnav-1 .links.media-subnav {
#   padding: 0 1.5rem;
# }
#
# .media-subnav-1 .featured.media-subnav {
#   -ms-grid-column: 2;
# }
#
# .media-subnav-1 .featured.media-subnav h4.media-subnav {
#   display: block;
# }
#
# .media-subnav-1 .top.media-subnav {
#   -ms-grid-column: 3;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav {
#   display: -ms-grid;
#       display: grid;
#       -ms-grid-columns: 50% 3rem 50%;
#       grid-template-columns: 50% 50%;
#       -ms-grid-rows: (auto)[7];
#       grid-template-rows: repeat(7, auto);
#       grid-column-gap: 3rem;
#       grid-auto-flow: column;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(1) {
#   -ms-grid-row: 1;
#       -ms-grid-column: 1;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(2) {
#   -ms-grid-row: 2;
#       -ms-grid-column: 1;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(3) {
#   -ms-grid-row: 3;
#       -ms-grid-column: 1;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(4) {
#   -ms-grid-row: 4;
#       -ms-grid-column: 1;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(5) {
#   -ms-grid-row: 5;
#       -ms-grid-column: 1;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(6) {
#   -ms-grid-row: 6;
#       -ms-grid-column: 1;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(7) {
#   -ms-grid-row: 7;
#       -ms-grid-column: 1;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(8) {
#   -ms-grid-row: 1;
#       -ms-grid-column: 3;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(9) {
#   -ms-grid-row: 2;
#       -ms-grid-column: 3;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(10) {
#   -ms-grid-row: 3;
#       -ms-grid-column: 3;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(11) {
#   -ms-grid-row: 4;
#       -ms-grid-column: 3;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(12) {
#   -ms-grid-row: 5;
#       -ms-grid-column: 3;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(13) {
#   -ms-grid-row: 6;
#       -ms-grid-column: 3;
# }
#
# .media-subnav-1 .top.media-subnav ul.media-subnav > *.media-subnav:nth-child(14) {
#   -ms-grid-row: 7;
#       -ms-grid-column: 3;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for media-slider -->
#    <style scope="media-slider-1">
#     .media-slider-1 .media-slider-container.media-slider {
#   position: relative;
# }
#
# .media-slider-1 .overflow-clip.media-slider {
#   display: none;
#     position: absolute;
#     top: 3rem;
#     right: 0;
#     left: 0;
#     height: 0;
#     overflow: hidden;
#     transition: height 0.2s ease;
# }
#
# .media-slider-1 .information-menu.media-slider {
#   position: absolute;
#     top: 0;
#     right: 0;
#     left: 0;
#     padding: 0;
#     height: 368px;
#     overflow-x: hidden;
#     font-size: 1.4rem;
#     background: #333;
# }
#
# .media-slider-1 .open.media-slider {
#   display: block;
# }
#
# .media-slider-1 .hidden.media-slider {
#   display: none;
# }
#
# .media-slider-1 .info-box.media-slider {
#   padding: 1rem;
# }
#
# @media (max-width: 889px) {
# .media-slider-1 .overflow-clip.open.media-slider {
#   display: block;
#       height: 367px;
#       left: 4rem;
#       top: 0;
# }
#
# }
#
# @media (min-width: 890px) {
# .media-slider-1 .overflow-clip.media-slider {
#   display: block;
# }
#
# .media-slider-1 .information-menu.media-slider {
#   left: 0;
#       z-index: 2;
#       height: auto;
#       min-height: 21rem;
#       background: #474747;
#       transform: translate(0, -100%);
#       transition: transform 0.2s ease;
# }
#
# .media-slider-1 .overflow-clip.open.media-slider {
#   height: 22rem;
# }
#
# .media-slider-1 .information-menu.open.media-slider {
#   transform: translate(0, 0);
# }
#
# .media-slider-1 .info-box.media-slider {
#   max-width: 1000px;
#       padding: 1.5rem 0;
#       margin: 0 auto;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for desktop-subnav -->
#    <style scope="desktop-subnav-1">
#     .desktop-subnav-1 ul.desktop-subnav {
#   position: relative;
#     z-index: 3;
#     padding: .8rem 0;
#     margin: 0;
#     font-size: 1.2rem;
#     text-transform: uppercase;
#     text-align: center;
#     background: #333;
# }
#
# .desktop-subnav-1 li.desktop-subnav {
#   display: inline-block;
#     padding: 0 15px;
# }
#
# .desktop-subnav-1 a.desktop-subnav {
#   text-decoration: none;
#     color: #aaa;
# }
#
# .desktop-subnav-1 a.desktop-subnav:hover,.desktop-subnav-1 a.desktop-subnav:active,.desktop-subnav-1 a.desktop-subnav:focus {
#   color: #fff;
# }
#
# .desktop-subnav-1 .donate.desktop-subnav svg.desktop-subnav {
#   width: 16px;
#     height: 16px;
#     vertical-align: -4px;
#     fill: #f00;
# }
#    </style>
#    <!-- Shady DOM styles for signed-out-dropdown -->
#    <style scope="signed-out-dropdown-1">
#     .signed-out-dropdown-1 .nav-container.signed-out-dropdown {
#   position: relative;
# }
#
# .signed-out-dropdown-1 nav.signed-out-dropdown {
#   position: absolute;
#     right: 0;
#     z-index: 2;
#     overflow: hidden;
#     font-size: 1.6rem;
#     background-color: #333;
#     transition-property: top;
#     transition-duration: 0.2s;
#     transition-timing-function: ease;
# }
#
# .signed-out-dropdown-1 .initial.signed-out-dropdown,.signed-out-dropdown-1 .closed.signed-out-dropdown {
#   top: -1500px;
# }
#
# .signed-out-dropdown-1 .closed.signed-out-dropdown {
#   transition-duration: 0.5s;
# }
#
# .signed-out-dropdown-1 .open.signed-out-dropdown {
#   max-width: 100vw;
#     overflow: auto;
# }
#
# .signed-out-dropdown-1 h3.signed-out-dropdown {
#   padding: 0.6rem 2rem;
#     margin: 0;
#     font-size: inherit;
#     overflow: hidden;
#     text-overflow: ellipsis;
# }
#
# .signed-out-dropdown-1 ul.signed-out-dropdown {
#   padding: 0.4rem 0 0.7rem 0;
#     margin: 0;
#     list-style: none;
#
#     max-height: calc(100vh - 7.2rem + 1px);
#     overflow: auto;
#     box-sizing: border-box;
# }
#
# .signed-out-dropdown-1 .divider.signed-out-dropdown {
#   margin: 0.5rem 0;
#     border-bottom: 1px solid #666;
# }
#
# .signed-out-dropdown-1 a.signed-out-dropdown,.signed-out-dropdown-1 .info-item.signed-out-dropdown {
#   display: block;
#     color: #fff;
#     text-decoration: none;
#     padding: 1rem 2rem;
# }
#
# .signed-out-dropdown-1 .info-item.signed-out-dropdown {
#   font-size: 0.8em;
#     color: #999;
# }
#
# @media (min-width: 890px) {
# .signed-out-dropdown-1 nav.signed-out-dropdown {
#   overflow: visible;
#       top: 0;
#       left: auto;
#       z-index: 5;
#       transition: opacity 0.2s ease-in-out;
#       font-size: 1.4rem;
#       border-radius: 2px;
#       background: #fff;
#       box-shadow: 0 1px 2px 1px rgba(0, 0, 0, 0.15);
# }
#
# .signed-out-dropdown-1 nav.signed-out-dropdown:after {
#   position: absolute;
#       right: 7px;
#       top: -7px;
#       width: 12px;
#       height: 7px;
#       box-sizing: border-box;
#       color: #fff;
#       content: '';
#       border-bottom: 7px solid currentColor;
#       border-left: 6px solid transparent;
#       border-right: 6px solid transparent;
# }
#
# .signed-out-dropdown-1 h3.signed-out-dropdown {
#   display: none;
# }
#
# .signed-out-dropdown-1 ul.signed-out-dropdown {
#   max-height: calc(100vh - 8.5rem + 1px);
# }
#
# .signed-out-dropdown-1 .divider.signed-out-dropdown {
#   border-bottom-color: #666;
# }
#
# .signed-out-dropdown-1 a.signed-out-dropdown {
#   padding: 0.5rem 2rem;
#       color: #333;
#       transition: background 0.1s ease-out, color 0.1s ease-out;
# }
#
# .signed-out-dropdown-1 .info-item.signed-out-dropdown {
#   padding: 0.5rem 2rem;
#       font-size: 0.8em;
# }
#
# .signed-out-dropdown-1 a.signed-out-dropdown:hover,.signed-out-dropdown-1 a.signed-out-dropdown:active,.signed-out-dropdown-1 a.signed-out-dropdown:focus {
#   color: #fff;
#       background: #428bca;
# }
#
# .signed-out-dropdown-1 .initial.signed-out-dropdown,.signed-out-dropdown-1 .closed.signed-out-dropdown {
#   opacity: 0;
#       transition-duration: 0.2s;
# }
#
# .signed-out-dropdown-1 .open.signed-out-dropdown {
#   opacity: 1;
#       overflow: visible;
# }
#
# }
#
# @media (min-width: 890px) {
# .signed-out-dropdown-1 .initial.signed-out-dropdown,.signed-out-dropdown-1 .closed.signed-out-dropdown,.signed-out-dropdown-1 .open.signed-out-dropdown {
#   right: 34rem;
# }
#
# .signed-out-dropdown-1 .search-hidden.initial.signed-out-dropdown,.signed-out-dropdown-1 .search-hidden.closed.signed-out-dropdown,.signed-out-dropdown-1 .search-hidden.open.signed-out-dropdown {
#   right: 18.5rem;
# }
#
# }
#
# @media (min-width: 990px) {
# .signed-out-dropdown-1 .initial.signed-out-dropdown,.signed-out-dropdown-1 .closed.signed-out-dropdown,.signed-out-dropdown-1 .open.signed-out-dropdown {
#   right: 40rem;
# }
#
# .signed-out-dropdown-1 .search-hidden.initial.signed-out-dropdown,.signed-out-dropdown-1 .search-hidden.closed.signed-out-dropdown,.signed-out-dropdown-1 .search-hidden.open.signed-out-dropdown {
#   right: 24.5rem;
# }
#
# }
#    </style>
#    <!-- Shady DOM styles for ia-topnav -->
#    <style scope="ia-topnav-1">
#     .ia-topnav-1 {
#   ;
#
#     color: #fff;
#     font-size: 2rem;
#     font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif;
# }
#
# .ia-topnav-1 primary-nav.ia-topnav:focus {
#   outline: none !important;
# }
#
# .ia-topnav-1 #close-layer.ia-topnav {
#   display: none;
#     position: fixed;
#     top: 0;
#     right: 0;
#     bottom: 0;
#     left: 0;
#     z-index: 0;
# }
#
# .ia-topnav-1 #close-layer.visible.ia-topnav {
#   display: block;
# }
#
# .ia-topnav-1 .topnav.ia-topnav {
#   position: relative;
#     z-index: 3;
# }
#
# @media (max-width: 889px) {
# .ia-topnav-1 desktop-subnav.ia-topnav {
#   display: none;
# }
#
# }
#    </style>
#    <style>
#     body {transition: opacity ease-in 0.2s; }
# body[unresolved] {opacity: 0; display: block; overflow: hidden; position: relative; }
#    </style>
#    <ia-topnav class="x-scope ia-topnav-1" locallinks="true" waybackpagesarchived="800 billion">
#     <!-- -->
#     <div class="topnav style-scope ia-topnav">
#      <primary-nav class="style-scope ia-topnav x-scope primary-nav-1">
#       <!-- -->
#       <nav class="style-scope primary-nav">
#        <div class="branding style-scope primary-nav">
#         <a class="link-home style-scope primary-nav" data-event-click-tracking="TopNav|NavHome" href="https://archive.org/" title="Go home">
#          <!--?lit$418799101$-->
#          <svg aria-labelledby="logoTitleID logoDescID" class="ia-logo style-scope primary-nav" height="30" viewbox="0 0 27 30" width="27" xmlns="http://www.w3.org/2000/svg">
#           <title class="style-scope primary-nav" id="logoTitleID">
#            Internet Archive logo
#           </title>
#           <desc class="style-scope primary-nav" id="logoDescID">
#            A line drawing of the Internet Archive headquarters building façade.
#           </desc>
#           <g class="style-scope primary-nav" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#            <mask class="style-scope primary-nav" fill="white" id="mask-2">
#             <path class="style-scope primary-nav" d="M26.6666667,28.6046512 L26.6666667,30 L0,30 L0.000283687943,28.6046512 L26.6666667,28.6046512 Z M25.6140351,26.5116279 L25.6140351,28.255814 L1.05263158,28.255814 L1.05263158,26.5116279 L25.6140351,26.5116279 Z M3.62469203,7.6744186 L3.91746909,7.82153285 L4.0639977,10.1739544 L4.21052632,13.9963932 L4.21052632,17.6725617 L4.0639977,22.255044 L4.03962296,25.3421929 L3.62469203,25.4651163 L2.16024641,25.4651163 L1.72094074,25.3421929 L1.55031755,22.255044 L1.40350877,17.6970339 L1.40350877,14.0211467 L1.55031755,10.1739544 L1.68423854,7.80887484 L1.98962322,7.6744186 L3.62469203,7.6744186 Z M24.6774869,7.6744186 L24.9706026,7.82153285 L25.1168803,10.1739544 L25.2631579,13.9963932 L25.2631579,17.6725617 L25.1168803,22.255044 L25.0927809,25.3421929 L24.6774869,25.4651163 L23.2130291,25.4651163 L22.7736357,25.3421929 L22.602418,22.255044 L22.4561404,17.6970339 L22.4561404,14.0211467 L22.602418,10.1739544 L22.7369262,7.80887484 L23.0420916,7.6744186 L24.6774869,7.6744186 Z M9.94042303,7.6744186 L10.2332293,7.82153285 L10.3797725,10.1739544 L10.5263158,13.9963932 L10.5263158,17.6725617 L10.3797725,
#           <!--?lit$418799101$-->
#           Log in
#          </a>
#         </li>
#         <!-- -->
#        </ul>
#       </nav>
#      </div>
#     </signed-out-dropdown>
#     <search-menu class="style-scope ia-topnav x-scope search-menu-1" tabindex="-1">
#      <!-- -->
#      <div class="menu-wrapper style-scope search-menu">
#       <div aria-expanded="false" aria-hidden="true" class="search-menu-inner tx-slide closed style-scope search-menu">
#        <!--?lit$418799101$-->
#        <!-- -->
#        <label class="style-scope search-menu">
#         <input checked="" class="style-scope search-menu" form="nav-search" name="sin" type="radio" value=""/>
#         Search
#         <!--?lit$418799101$-->
#         metadata
#        </label>
#        <!-- -->
#        <!-- -->
#        <label class="style-scope search-menu">
#         <input class="style-scope search-menu" form="nav-search" name="sin" type="radio" value="TXT"/>
#         Search
#         <!--?lit$418799101$-->
#         text contents
#        </label>
#        <!-- -->
#        <!-- -->
#        <label class="style-scope search-menu">
#         <input class="style-scope search-menu" form="nav-search" name="sin" type="radio" value="TV"/>
#         Search
#         <!--?lit$418799101$-->
#         TV news captions
#        </label>
#        <!-- -->
#        <!-- -->
#        <label class="style-scope search-menu">
#         <input class="style-scope search-menu" form="nav-search" name="sin" type="radio" value="RADIO"/>
#         Search
#         <!--?lit$418799101$-->
#         radio transcripts
#        </label>
#        <!-- -->
#        <!-- -->
#        <label class="style-scope search-menu">
#         <input class="style-scope search-menu" form="nav-search" name="sin" type="radio" value="WEB"/>
#         Search
#         <!--?lit$418799101$-->
#         archived web sites
#        </label>
#        <!-- -->
#        <a class="advanced-search style-scope search-menu" data-event-click-tracking="TopNav|NavAdvancedSearch" href="https://archive.org/advancedsearch.php">
#         Advanced Search
#        </a>
#       </div>
#      </div>
#     </search-menu>
#     <desktop-subnav class="style-scope ia-topnav x-scope desktop-subnav-1">
#      <!-- -->
#      <ul class="style-scope desktop-subnav">
#       <!--?lit$418799101$-->
#       <!-- -->
#       <li class="style-scope desktop-subnav">
#        <a class="about style-scope desktop-subnav" href="https://archive.org/about/">
#         <!--?lit$418799101$-->
#         About
#         <!--?lit$418799101$-->
#         <!--?-->
#        </a>
#       </li>
#       <!-- -->
#       <!-- -->
#       <li class="style-scope desktop-subnav">
#        <a class="blog style-scope desktop-subnav" href="https://blog.archive.org">
#         <!--?lit$418799101$-->
#         Blog
#         <!--?lit$418799101$-->
#         <!--?-->
#        </a>
#       </li>
#       <!-- -->
#       <!-- -->
#       <li class="style-scope desktop-subnav">
#        <a class="projects style-scope desktop-subnav" href="https://archive.org/projects/">
#         <!--?lit$418799101$-->
#         Projects
#         <!--?lit$418799101$-->
#         <!--?-->
#        </a>
#       </li>
#       <!-- -->
#       <!-- -->
#       <li class="style-scope desktop-subnav">
#        <a class="help style-scope desktop-subnav" href="https://archive.org/about/faqs.php">
#         <!--?lit$418799101$-->
#         Help
#         <!--?lit$418799101$-->
#         <!--?-->
#        </a>
#       </li>
#       <!-- -->
#       <!-- -->
#       <li class="style-scope desktop-subnav">
#        <a class="donate style-scope desktop-subnav" href="https://archive.org/donate?origin=iawww-TopNavDonateButton">
#         <!--?lit$418799101$-->
#         Donate
#         <!--?lit$418799101$-->
#         <svg aria-labelledby="donateTitleID donateDescID" class="style-scope desktop-subnav" height="40" viewbox="0 0 40 40" width="40" xmlns="http://www.w3.org/2000/svg">
#          <title class="style-scope desktop-subnav" id="donateTitleID">
#           Donate icon
#          </title>
#          <desc class="style-scope desktop-subnav" id="donateDescID">
#           An illustration of a heart shape
#          </desc>
#          <path class="fill-color style-scope desktop-subnav" d="m30.0120362 11.0857287c-1.2990268-1.12627221-2.8599641-1.65258786-4.682812-1.57894699-.8253588.02475323-1.7674318.3849128-2.8262192 1.08047869-1.0587873.6955659-1.89622 1.5724492-2.512298 2.63065-.591311-1.0588196-1.4194561-1.9357029-2.4844351-2.63065-1.0649791-.69494706-2.0039563-1.05510663-2.8169316-1.08047869-1.2067699-.04950647-2.318187.17203498-3.3342513.66462439-1.0160643.4925893-1.82594378 1.2002224-2.42963831 2.1228992-.60369453.9226769-.91173353 1.9629315-.92411701 3.1207641-.03715043 1.9202322.70183359 3.7665141 2.21695202 5.5388457 1.2067699 1.4035084 2.912594 3.1606786 5.1174721 5.2715107 2.2048782 2.1108321 3.7565279 3.5356901 4.6549492 4.2745742.8253588-.6646243 2.355647-2.0647292 4.5908647-4.2003145s3.9747867-3.9171994 5.218707-5.3448422c1.502735-1.7723316 2.2355273-3.6186135 2.1983769-5.5388457-.0256957-1.7608832-.6875926-3.2039968-1.9866194-4.3302689z">
#          </path>
#         </svg>
#        </a>
#       </li>
#       <!-- -->
#       <!-- -->
#       <li class="style-scope desktop-subnav">
#        <a class="contact style-scope desktop-subnav" href="https://archive.org/about/contact.php">
#         <!--?lit$418799101$-->
#         Contact
#         <!--?lit$418799101$-->
#         <!--?-->
#        </a>
#       </li>
#       <!-- -->
#       <!-- -->
#       <li class="style-scope desktop-subnav">
#        <a class="jobs style-scope desktop-subnav" href="https://archive.org/about/jobs.php">
#         <!--?lit$418799101$-->
#         Jobs
#         <!--?lit$418799101$-->
#         <!--?-->
#        </a>
#       </li>
#       <!-- -->
#       <!-- -->
#       <li class="style-scope desktop-subnav">
#        <a class="volunteer style-scope desktop-subnav" href="https://archive.org/about/volunteerpositions.php">
#         <!--?lit$418799101$-->
#         Volunteer
#         <!--?lit$418799101$-->
#         <!--?-->
#        </a>
#       </li>
#       <!-- -->
#       <!-- -->
#       <li class="style-scope desktop-subnav">
#        <a class="people style-scope desktop-subnav" href="https://archive.org/about/bios.php">
#         <!--?lit$418799101$-->
#         People
#         <!--?lit$418799101$-->
#         <!--?-->
#        </a>
#       </li>
#       <!-- -->
#      </ul>
#     </desktop-subnav>
#     <div class="style-scope ia-topnav" id="close-layer">
#     </div>
#    </ia-topnav>
#   </div>
#   <input class="js-tvsearch" type="hidden" value='{"ands":[],"minday":"06/04/2009","maxday":"03/20/2023"}'/>
#   <script>
#    update_aoheader();
#   </script>
#   <div style="display: block; float: right; width: 28px; margin-top: 4px;">
#    <a class="social_button" href="#" onclick="window.open('https://www.facebook.com/sharer/sharer.php?u=' + encodeURIComponent(window.location.href), '', 'height=400,width=600'); return false;" title="Share on Facebook">
#     <span class="iconochive-facebook" style="color:#3b5998;font-size:160%;">
#     </span>
#    </a>
#    <a class="social_button" href="#" onclick="window.open('https://twitter.com/intent/tweet?text=' + encodeURIComponent(window.location.href) + '&amp;via=internetarchive', '', 'height=400,width=600'); return false;" title="Share on Twitter">
#     <span class="iconochive-twitter" style="color:#1dcaff;font-size:160%;">
#     </span>
#    </a>
#   </div>
#   <script>
#    var config = {"api_url_anchor": "/__wb/search/anchor?q={{query}}", "api_url_calendar_captures": "/__wb/calendarcaptures?url={{url}}\u0026selected_year={{year}}", "api_url_host": "/__wb/search/host?q={{query}}", "api_url_metadata": "/__wb/search/metadata?q={{query}}", "api_url_sitemap": "/web/timemap/json?url={{url}}/\u0026fl=timestamp:4,original,urlkey\u0026matchType=prefix\u0026filter=statuscode:200\u0026filter=mimetype:text/html\u0026collapse=urlkey\u0026collapse=timestamp:4\u0026limit=100000", "api_url_sparkline": "/__wb/sparkline?output=json\u0026url={{url}}\u0026collection=web", "bundling": {"public_path": "/static/bower_components/wayback-search-js/dist"}, "diff": {"cdxServer": "/web/timemap", "diffgraphPrefix": "/web/diffgraph/", "limit": 3000, "maxSunburstLevelLength": "70", "snapshotsPrefix": "/web/", "sparklineURL": "/__wb/sparkline", "urlPrefix": "/web/diff/", "waybackDiscoverDiff": "https://gext-api.archive.org/services/simhash", "webMonitoringProcessingURL": "https://gext-api.archive.org/services/diff"}, "features": {"beta_promo": false, "changes_calendar": true, "landing": "carousel", "landing_layout_with_trend": false, "search": "v1"}, "num_of_explored_web_pages": "803 billion", "search_v2": {"search_collections": {"defaultIntro": "Welcome to the Wayback Machine collection search service. This service is based on indexes of specific data from selected Collections.\n", "defaultMore": "Collections are groupings of Web archives related to a specific archiving method or source of URLs. For example the \u003ca href=\"https://archive.org/details/mediacloud\"\u003emediacloud\u003c/a\u003e Collection contains URLs sourced from \u003ca href=\"https://mediacloud.org\"\u003emediacloud.org\u003c/a\u003e.\u003cbr /\u003e\u003cbr /\u003e The specific Web page data we are indexing includes: anchor text, all URL parts (file names, hosts, domains), MIME Types, HTTP Status codes \u0026 Web Page Titles. In this way you can search for PDF files, from .mil websites that have the word \u201cnuclear\u201d in their file name.\n", "options": {"EndOfTerm2008WebCrawls": {"intro": "Search #count web pages using an index built from anchor text, all URL parts (file names, hosts, domains), MIME Types, language, HTTP Status codes and the full text of the web pages. \u003cbr /\u003e\u003cbr /\u003e Please send your questions, suggestions, bug reports, etc. to \u003ca href=\"mailto:info@archive.org\"\u003einfo@archive.org\u003c/a\u003e.\n", "more": " ", "search_types": {"default": "text", "horizontal_line_room": 1, "options": [{"icon": "iconochive-texts", "id": "text", "title": "Webpages", "type": "text"}]}, "title": "End Of Term (US Gov) 2008", "url": "https://archive.org/details/cdlweb"}, "EndOfTerm2012WebCrawls": {"intro": "Search #count web pages using an index built from anchor text, all URL parts (file names, hosts, domains), MIME Types, language, HTTP Status codes and the full text of the web pages. \u003cbr /\u003e\u003cbr /\u003e Please send your questions, suggestions, bug reports, etc. to \u003ca href=\"mailto:info@archive.org\"\u003einfo@archive.org\u003c/a\u003e.\n", "more": " ", "search_types": {"default": "text", "horizontal_line_room": 1, "index_mapping": {"text": "search2:eot2012-search-text-202210"}, "options": [{"icon": "iconochive-texts", "id": "text", "title": "Webpages", "type": "text"}]}, "title": "End Of Term (US Gov) 2012", "url": "https://archive.org/details/EndOfTerm2012WebCrawls"}, "EndOfTerm2016WebCrawls": {"intro": "Search #count web pages using an index built from anchor text, all URL parts (file names, hosts, domains), MIME Types, language, HTTP Status codes and the full text of the web pages. \u003cbr /\u003e\u003cbr /\u003e Please send your questions, suggestions, bug reports, etc. to \u003ca href=\"mailto:info@archive.org\"\u003einfo@archive.org\u003c/a\u003e.\n", "more": " ", "search_types": {"default": "text", "horizontal_line_room": 1, "options": [{"icon": "iconochive-texts", "id": "text", "title": "Webpa ...
#       $(document).ready(function(){
# 	var e = $('#react-wayback-search'), c = e.attr('component');
# 	ReactDOM.render(
# 	  React.createElement(window[c], { config: config }),
# 	  e.get(0)
# 	);
#       });
#   </script>
#   <div component="WaybackSearchComponent" id="react-wayback-search">
#    <div class="search-toolbar">
#     <div id="donation-link">
#      <a class="donation-button" data-event-click-tracking="Wayback|DonateButton" href="//archive.org/donate/?origin=wbwww-CalndrDonateButton">
#       <span class="beta_button">
#        DONATE
#       </span>
#      </a>
#     </div>
#     <div class="search-toolbar-logo-container">
#      <a href="/">
#       <div alt="logo: Internet Archive's Wayback Machine" class="search-toolbar-logo">
#       </div>
#      </a>
#     </div>
#     <div class="search-text-container">
#      <div class="global-saved-web-pages-count-boxout">
#       Explore more than 803 billion
#       <a href="https://blog.archive.org/2016/10/23/defining-web-pages-web-sites-and-web-captures/" rel="noopener noreferrer" target="_blank">
#        web pages
#       </a>
#       saved over time
#      </div>
#      <form>
#       <div class="rbt has-aux" style="outline: none; position: relative;" tabindex="-1">
#        <div style="display: flex; flex: 1 1 0%; height: 100%; position: relative;">
#         <input aria-autocomplete="both" aria-expanded="false" aria-haspopup="listbox" autocomplete="off" class="rbt-input-main form-control rbt-input focus" placeholder="Enter a URL or words related to a site’s home page" role="combobox" type="text" value="https://twitter.com/kanyewest"/>
#         <input aria-hidden="true" class="rbt-input-hint" readonly="" style="background-color: transparent; border-color: transparent; box-shadow: none; color: rgba(0, 0, 0, 0.54); left: 0px; pointer-events: none; position: absolute; top: 0px; width: 100%; border-style: solid; border-width: 0.8px; font-size: 14px; height: 34px; line-height: 20px; margin: 0px; padding: 6px 34px 6px 12px;" tabindex="-1" value=""/>
#        </div>
#        <div class="rbt-aux">
#         <button aria-label="Clear" class="close rbt-close" type="button">
#          <span aria-hidden="true">
#           ×
#          </span>
#          <span class="sr-only visually-hidden">
#           Clear
#          </span>
#         </button>
#        </div>
#       </div>
#       <input class="hidden-submit-btn" tabindex="-1" type="submit"/>
#      </form>
#     </div>
#    </div>
#    <div class="wbs__web_footer">
#     <a class="footer-item" href="https://archive.org/about/faqs.php#The_Wayback_Machine">
#      FAQ
#     </a>
#     |
#     <a class="footer-item" href="https://archive.org/about/contact.php">
#      Contact Us
#     </a>
#     |
#     <a class="footer-item" href="https://archive.org/about/terms.php">
#      Terms of Service (Dec 31, 2014)
#     </a>
#    </div>
#   </div>
#   <noscript>
#    <div class="no-script-message">
#     The Wayback Machine requires your browser to support JavaScript, please email
#     <a href="mailto:info@archive.org">
#      info@archive.org
#     </a>
#     <br/>
#     if you have any questions about this.
#    </div>
#   </noscript>
#   <footer>
#    <div id="footerHome">
#     <p>
#      The Wayback Machine is an initiative of the
#      <a href="//archive.org/">
#       Internet Archive
#      </a>
#      ,
#           a 501(c)(3) non-profit, building a digital library of
#           Internet sites and other cultural artifacts in digital form.
#      <br/>
#      Other
#      <a href="//archive.org/projects/">
#       projects
#      </a>
#      include
#      <a href="https://openlibrary.org/">
#       Open Library
#      </a>
#      &amp;
#      <a href="https://archive-it.org">
#       archive-it.org
#      </a>
#      .
#     </p>
#     <p>
#      Your use of the Wayback Machine is subject to the Internet Archive's
#      <a href="//archive.org/about/terms.php">
#       Terms of Use
#      </a>
#      .
#     </p>
#    </div>
#   </footer>
#  </body>
# </html>

# %% [markdown]
# The above HTML generated contains information in the `<div>` with the ID <b>react-wayback-search</b>

# %% [markdown]
# Now, we find all divs with the id `calendar-day`: Each div after hovering on it contains the required links

# %%
# obtain all calendar days that contain the actual links 
calendar_days = []
# wait for the page to load so that it contains the calendar days
while (len(calendar_days) == 0):
    time.sleep(0.1)
    calendar_days = browser.find_elements("xpath", "//div[contains(@class, 'calendar-day')]")

# %%
# obtain all links

def obtain_kanye_tweet_links(calendar_days):
    kanye_tweet_links = []
    
    for c in list(calendar_days):
        while (True):
            try: 
                time.sleep(0.2)
                action.move_to_element(c).perform()
                links = browser.find_elements("xpath", "//a[contains(@class, 'snapshot-link')]")
                # the page fetches the links sometimes, so need to wait
                while (len(links) == 0):
                    time.sleep(0.1)
                    links = browser.find_elements("xpath", "//a[contains(@class, 'snapshot-link')]")
                for link in links:
                    kanye_tweet_links.append(link.get_attribute("href"))
                    print(link.get_attribute("href"))
                break
            # if we encounter an exception, then redo operations again
            except (NoSuchElementException, StaleElementReferenceException) as e:
                print(e)
                pass
            
    return kanye_tweet_links

# %%
# store links as the above operation takes a lot of time
# kanye_tweet_links_2022 = obtain_kanye_tweet_links(calendar_days)
# with open('kanye_tweet_links_2022.pickle', 'wb') as file:
#     pickle.dump(kanye_tweet_links_2022, file)

# %%
browser.quit()

# %%
# retrieve all kanye tweet links for the year 2022
with open('kanye_tweet_links_2022.pickle', 'rb') as file:
    kanye_tweet_links_2022 = pickle.load(file)

# %%
# for the year 2022, obtain all the tweets
# since the tweets could repeat across snapshots, we store in a dictionary

def obtain_all_tweets():
    kanye_tweets_2022 = {}
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5)\
                AppleWebKit/537.36 (KHTML, like Gecko) Cafari/537.36'}

    for i in range(len(kanye_tweet_links_2022)):
        while (True):
            try: 
                print(i, len(kanye_tweets_2022), kanye_tweet_links_2022[i])
                time.sleep(0.3)
                response = requests.get(kanye_tweet_links_2022[i], headers=headers)
                html = BeautifulSoup(response.text, 'lxml')

                # type 1 - from normal Twitter archive
                tweets = html.find_all('p', {'class': 'tweet-text'})
                for tweet in tweets:
                    # remove pic.twitter.com/xyz text
                    modified_tweet = re.sub(r"pic\.twitter\.com/\S+", "", tweet.text)
                    kanye_tweets_2022[modified_tweet] = True

                # type 2 - from web archive archive
                tweets = html.find_all('div', {'data-testid': "tweetText"})
                for tweet in tweets:
                    modified_tweet = tweet.text
                    kanye_tweets_2022[modified_tweet] = True

                break
            except Exception: 
                time.sleep(1)
                pass
            
    return kanye_tweets_2022

# %%
# store tweets as the above operation takes a lot of time
# kanye_tweets_2022 = obtain_all_tweets()
# with open('kanye_tweet_2022.pickle', 'wb') as file:
#     pickle.dump(kanye_tweets_2022, file)

# %%
# retrieve all kanye tweet for the year 2022
with open('kanye_tweet_2022.pickle', 'rb') as file:
    kanye_tweets_2022 = pickle.load(file)

# %% [markdown]
# # Tweet Sentiment Analysis
#
# Once tweets are obtained, we perform sentiment analysis on it using NLTK

# %%
import nltk.corpus
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /home/maanas/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# download stopwords to remove from tweets
stopwords = nltk.corpus.stopwords.words("english")

# lemmatization - find root word
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/maanas/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# obtain all relevant words in tweets
all_words_tweets = {}
for tweet in kanye_tweets_2022:
    tweet_words = tweet.split(' ')
    for tweet_word in tweet_words:
        # lowercasing
        tweet_word = tweet_word.lower()
        # lemmatize
        tweet_word = nltk.WordNetLemmatizer().lemmatize(tweet_word)

        # remove stopwords and empty strings
        if tweet_word in stopwords or tweet_word == "":
            continue
            
        # remove hash of hashtag
        tweet_word = re.sub(r'#(\w+)', r'\1', tweet_word)
        
        if tweet_word not in all_words_tweets:
            all_words_tweets[tweet_word] = 0
        all_words_tweets[tweet_word] += 1

# %%
# visualization - wordcloud for tweet words
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# create a WordCloud object with the given parameters
wordcloud = WordCloud(width=800, height=800,
                      background_color='white',
                      min_font_size=10).generate_from_frequencies(all_words_tweets)

# plot the WordCloud image using matplotlib
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)

# display the image
plt.show()

# %% [markdown]
# From the tweets, we can notice that the most commonly used words, "love", "god", "people", "jesus", "life" suggest that the tweets are mostly "positive" in nature. This is because we also notice curse words like "fuck" that, even though less in number, could suggest that Kanye West has a "negative" social media presence as well.

# %%
# filter the dictionary for items with frequency >= 5
all_words_tweets_filtered = {k: v for k, v in all_words_tweets.items() if v >= 5}

# sort the dictionary by value (frequency) in descending order
all_words_tweets_sorted_freq = dict(sorted(all_words_tweets_filtered.items(), key=lambda item: item[1], reverse=True))

# print the sorted dictionary
print(all_words_tweets_sorted_freq)
# Out:
# {'love': 20, 'wa': 13, 'god': 11, 'ha': 11, 'people': 10, 'kanye': 9, 'jesus': 9, '&': 9, 'first': 8, 'life': 8, 'time': 8, 'i’m': 8, 'said': 8, 'make': 7, 'ye24': 7, 'world': 6, 'say': 6, 'everyone': 6, 'ye': 6, 'know': 6, '.': 6, 'every': 5, 'christ': 5, 'u': 5, 'man': 5, 'going': 5, '🇺🇸': 5, 'black': 5, 'cancel': 5, 'get': 5}

# %% [markdown]
# From the above visualization, we can see that Kanye's tweets have the above used words in `all_words_tweets_sorted_freq` the most (frequency >= 5).

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
kanye_tweets_pos = 0
kanye_tweets_neg = 0
kanye_tweets_neu = 0

kanye_tweets_sentiment_score = {}

sid = SentimentIntensityAnalyzer()
for tweet in kanye_tweets_2022:
    comp = sid.polarity_scores(tweet)
    comp = comp['compound']
    if comp >= 0.5:
        kanye_tweets_pos += 1
    elif comp > -0.5 and comp < 0.5:
        kanye_tweets_neu += 1
    else:
        kanye_tweets_neg += 1
    kanye_tweets_sentiment_score[tweet] = comp
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/maanas/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Plot pie chart 
plt.pie([kanye_tweets_pos, kanye_tweets_neg, kanye_tweets_neu], labels=['pos', 'neg', 'neu'], colors=['g', 'r', 'b'], autopct='%1.1f%%')
plt.title('Kanye\'s 2022 Tweets\' Sentiment Analysis')

# Show plot
plt.show()

# %% [markdown]
# As expected from the preliminary analysis, we see that 31.1% of the tweets are positive in nature while just a small 5.9% of the tweets are negative in nature.

# %%
# Sort the dictionary by values in ascending order
sorted_tweets = sorted(kanye_tweets_sentiment_score.items(), key=lambda x: x[1], reverse=True)

# Iterate over the dictionary and print tweets with comp <= 0.5
for tweet, comp in sorted_tweets:
    if comp >= 0.5:
        print(f'Comp score: {comp}')
        print(tweet, comp)
# Out:
# Comp score: 0.9723
# Praise God. Thank you so much #DoveAwards       God continues to send encouragement      Good is winning     Things are changing     Praise God 0.9723
# Comp score: 0.9703
# A PRAYER FOR WORLD PEACE
# Dear God, thank You for all creation. In the spirit of Jesus of Nazareth and all teachers of peace who inspire the many faith traditions, help me, and all the people of the world, learn how to replace hate, war, oppression, and division with love 0.9703
# Comp score: 0.9573
# Just to be CLEAR: WE ARE IN ENGAGED WITH HAITI’s GOVERNMENT  to make a transformational INVESTMENT to bring  JOBS,  DEVELOPMENT, HELP SUPPORT LOCAL  FARMERS and FISHERMEN and Build a  new « CITY OF THE FUTURE » in a very beautiful country. 0.9573
# Comp score: 0.9571
# God loves Balenciaga     Love is the answer       Jesus is the answer     Praying for all of the innocent artist and beautiful humans who make clothing that had nothing to do with the adds     Peoples grandmothers work their for Christ sake 0.9571
# Comp score: 0.9531
# EVERYDAY    JOEL’S NEW SERMONS ARE SUPER UPLIFTING AND INSPIRING      PRAISE GOD FOR THE MOTIVATION        JESUS STAYS WINNING 0.9531
# Comp score: 0.926
# This in not hate     We are love   God is love 0.926
# Comp score: 0.9168
# Some in Trump World want his 2016 senior adviser Karen Giorno put on a “block list” keeping her from all his properties after she was at the Kanye-Fuentes dinner
#
# Giorno: “I hope not. They have the best food. I really love their taco salad.” 0.9168
# Comp score: 0.9136
# I’m a bit sleepy but tomorrow…. : )))   I promise it will be allll love speech guys I promise 0.9136
# Comp score: 0.875
# Well that wraps up the craziest interview in modern history. Download it. Save it. That’s a free man walking. The most politically incorrect interview in history with the biggest entertainer of the modern era. He said everything you’re not supposed to say & said it.
#
# Thoughts? 0.875
# Comp score: 0.8748
# God is so good  Today I am voting for the first time in my life for the President of the United States, and it's for someone I truly trust...me.   0.8748
# Comp score: 0.8748
# God is so good 😊 Today I am voting for the first time in my life for the President of the United States, and it's for someone I truly trust...me. 🇺🇸 🕊 0.8748
# Comp score: 0.8442
# Iranian youth are leading a revolution against 44 years of dictatorship. The world needs to support them and honor their courage. 0.8442
# Comp score: 0.8381
# FREE NICHOLAS
# FREE SPEECH
# FREE @ALI 0.5371
# Comp score: 0.5267
# What should be obvious by now is that I was raised to stand for my truth regardless of the consequences
#
# So I will say this again    I was mentally misdiagnosed and nearly drugged out of my mind to make me a manageable well behaved celebrity 0.5267
# Comp score: 0.516
# DEAR FUTURE, I STILL BELIEVE IN YOU      PRINTED IN THE NEW YORK TIMES THIS MORNING     https://kanye2020.country 0.516

# %%
# Sort the dictionary by values in ascending order
sorted_tweets = sorted(kanye_tweets_sentiment_score.items(), key=lambda x: x[1])

# Iterate over the dictionary and print tweets with comp <= 0.5
for tweet, comp in sorted_tweets:
    if comp <= -0.5:
        print(f'Comp score: {comp}')
        print(tweet, comp)
# Out:
# Comp score: -0.7845
# I stand by Balenciaga and denounce all witch hunts and I cancel cancel culture  Jesus is King     Ending trafficking doesn’t start or end with a fashion campaign for Christ Sake -0.7845
# Comp score: -0.765
# I'm starting to think anti Semitic means nigger -0.765
# Comp score: -0.7263
# Opinion: What Ye did today was the Christian version of what many punks did in the 80s. "Fuck your villains!" A rebellion against weaponized ancestral pain. Like it or not, it was meant to slaughter a sacred cow. -0.7263
# Comp score: -0.6652
# I’m a bit sleepy tonight but when I wake up I’m going death con 3      On JEWISH PEOPLE     The funny thing is I actually can’t be Anti Semitic  because black people are actually Jew also    You guys have toyed with me and tried to black ball anyone whoever opposes your agenda -0.6652
# Comp score: -0.6597
# JPMorgan Chase and Deutsche Bank have been accused of profiting from and facilitating the sexual abuse of young women and girls by Jeffrey Epstein, according to two lawsuits -0.6597
# Comp score: -0.5859
# We’ve accepted far more than that from your opponents.
#
# DeSantis has rented our lists. Trump has rented our lists. Virtually every major Republican figure has rented our lists at some point.
#
# Stupid argument. twitter.com/kanyewest/stat… -0.5859
# Comp score: -0.5574
# Whether you took something away from the Alex Jones, Kanye West, Ali Alexander, Nick Fuentes, Laura Loomer mash up—or you thought it was a total shit show.
#
# Trump doesn’t make this statement if not for that podcast. #KanyeWest #AlexJones -0.5574

# %% [markdown]
# In the above result, we see the negatively attributed tweets. These tweets received a lot of backlash from the public and media, and this led to his account ban.

# %% [markdown]
# # Music Lyrics Sentiment Analysis
#
# Now, we extract lyrics to his songs and then perform a similar sentiment analysis on them.

# %%
# Using lyricsgenius to obtain song lyrics
import lyricsgenius
import json

# %%
# Setting up lyrics genius using genius API token
with open("client_access_token.txt", "r") as f:
    client_access_token = f.read()
genius = lyricsgenius.Genius(client_access_token)

# We exclude all non-songs and songs with these terms -> They indicate unofficial songs
genius.excluded_terms = ["(Remix)", "(Live)", "(Tour)", "(Award)", "(Speech)", "(Demo)", "(Solo)", 
                         "(Version)", "(Interlude)", "(Interview)", "(Freestyle)", "(Show)", "(Instrumental)", 
                         "(OG)", "(Booklet)", "(Original)", "(Reference)", "(Film)", "(Tarantino)", "(SNL)", "(Beat)",
                        "(Season)", "(GQ)", "(Philosophy)", "(Holland)", "(Poetry)"]
genius.remove_section_headers = True
genius.skip_non_songs = True
genius.retries = 20

# %%
# kanye_west_artist = genius.search_artist(artist_name="Kanye West", sort="title")
# Out:
# Searching for songs by Kanye West...
#
# Song 1: "."
# "03' Bonnie & Clyde (Live)" is not valid. Skipping.
# Song 2: "03 Electic Relaxation"
# Song 3: "12,000 Acres"
# Song 4: "18 Years"
# "1996 Fat Beats Freestyle" is not valid. Skipping.
# "2004 Tim Westwood Freestyle" is not valid. Skipping.
# "2010 BET Hip Hop Awards - Cypher 5" is not valid. Skipping.
# "2013 Jimmy Kimmel Interview (Part 1)" is not valid. Skipping.
# "2013 Jimmy Kimmel Interview (Part 2)" is not valid. Skipping.
# "2013 Yeezus Tour Dates" is not valid. Skipping.
# "2013 Zane Lowe BBC Radio Interview Part 1" is not valid. Skipping.
# "2013 Zane Lowe BBC Radio Interview Part 2" is not valid. Skipping.
# "2014 Yeezus Tour Dates" is not valid. Skipping.
# "2015 BET Honors Visionary Award Acceptance Speech" is not valid. Skipping.
# "2015 The Breakfast Club Interview" is not valid. Skipping.
# "2015 Zane Lowe BBC Radio Interview" is not valid. Skipping.
# "2016 MTV VMAs Speech" is not valid. Skipping.
# Song 5: "24"
# "24 (Buju Banton & SAINt JHN Demo)" is not valid. Skipping.
# "24 (Lancey Foux Demo)" is not valid. Skipping.
# "24 (Las Vegas Version)" is not valid. Skipping.
# "24 (Reference)" is not valid. Skipping.
# "24 / You’re Gonna Be OK (LP1 Version)" is not valid. Skipping.
# Song 6: "2geeked!"
# Song 7: "30 Hours"
# "30 Hours (Demo)" is not valid. Skipping.
# "310" is not valid. Skipping.
# "3/3/15 Show at Koko Setlist" is not valid. Skipping.
# "333" is not valid. Skipping.
# "3 (FourFiveSeconds Demo)" is not valid. Skipping.
# "47th Annual Grammy Speech" is not valid. Skipping.
# Song 8: "530"
# "530 / Dear Summer (Demo)" is not valid. Skipping.
# "808s & Heartbreak [Booklet]" is not valid. Skipping.
# "88 Bass Guitar" is not valid. Skipping.
# "A 97.1 Interview Part 2 (8/28/13)" is not valid. Skipping.
# Song 9: "Addiction"
# Song 10: "After You"
# Song 11: "Again"
# "Alien (October 2020 Demo)" is not valid. Skipping.
# "Alien (Quavo & Offset Version)" is not valid. Skipping.
# "Alien (Reference)" is not valid. Skipping.
# "Alien (Reference)" is not valid. Skipping.
# "Alien / SpaceX (Original)" is not valid. Skipping.
# Song 12: "All Day"
# "All Day (2 Chainz Version)" is not valid. Skipping.
# "All Day (Kendrick Lamar Reference)" is not valid. Skipping.
# Song 13: "All Dreams Real"
# "All Dreams Real (Solo)" is not valid. Skipping.
# Song 14: "All Eyes on Ye"
# Song 15: "All Falls Down"
# "All Falls Down (Instrumental)" is not valid. Skipping.
# "All Falls Down (Live at Abbey Road Studios)" is not valid. Skipping.
# "All Falls Down (Live From The House of Blues)" is not valid. Skipping.
# "All Falls Down (OG)" is not valid. Skipping.
# Song 16: "All I Have"
# "All I Know (Remix)" is not valid. Skipping.
# Song 17: "All Mine"
# Song 18: "All of the Lights"
# "All of the Lights (Interlude)" is not valid. Skipping.
# "All of the Lights (Remix)" is not valid. Skipping.
# Song 37: "Big Brother"
# "Bitch Better Have My Money (GTA Remix)" is not valid. Skipping.
# "Bitch Better Have My Money (R3HAB Remix)" is not valid. Skipping.
# Song 38: "Bitter Sweet"
# "Bittersweet Poetry" is not valid. Skipping.
# Song 39: "Black Men Don’t Cheat"
# Song 40: "Black Skinhead"
# "Black Skinhead (Demo)" is not valid. Skipping.
# "Black Skinhead (Live on SNL)" is not valid. Skipping.
# "Black Skinhead (Remix)" is not valid. Skipping.
# "Black Vietnam" is not valid. Skipping.
# Song 41: "Blame Game"
# "Blessings (Extended Version)" is not valid. Skipping.
# Song 42: "Blood of the Lamb"
# Song 43: "Blood On the Leaves"
# "Blue Note NYC Freestyle" is not valid. Skipping.
# "Blue Note NYC Freestyle (2nd Verse)" is not valid. Skipping.
# Song 44: "Blueprint Compilation"
# "Bonnie & Clyde Freestyle" is not valid. Skipping.
# Song 45: "Bottom Line"
# Song 46: "Bound 2"
# "Bound 2 (Later...with Jools Holland)" is not valid. Skipping.
# "Break the Simulation (Philosophy Book)" is not valid. Skipping.
# Song 47: "Breathe In Breathe Out"
# "Breathe In Breathe Out (Instrumental)" is not valid. Skipping.
# Song 48: "Bring Me Down"
# "Bring Me Down (Live at Abbey Road Studios)" is not valid. Skipping.
# Song 49: "Broken Road"
# Song 50: "Brothers"
# "Brothers (Ant Clemons Demo)" is not valid. Skipping.
# "Brothers (Freestyle)" is not valid. Skipping.
# "Buy U A Drank (Shawty Snappin’) [Remix]" is not valid. Skipping.
# "Buy You a Drank (Remix) [Snippet]" is not valid. Skipping.
# Song 51: "Bye Bye Baby"
# Song 52: "By Your Side"
# Song 53: "Candyland"
# "Candy Shop Medley (Live)" is not valid. Skipping.
# "Can I Live" is not valid. Skipping.
# "Can’t Get Away" is not valid. Skipping.
# Song 54: "Can’t Get Over Me"
# Song 55: "Can’t Tell Me Nothing"
# "Can’t Tell Me Nothing (Jeezy Remix)" is not valid. Skipping.
# "Can’t Tell Me Nothing (Remix)" is not valid. Skipping.
# "Can’t Tell Me Nothing (R.O.C. Remix)" is not valid. Skipping.
# Song 56: "Can’t Tell Me Nothing (Sunday Service Choir)"
# Song 57: "Can U Be"
# "Can U Be (Demo)" is not valid. Skipping.
# "Cash to Burn (Demo)" is not valid. Skipping.
# "Cash to Burn (Reference)" is not valid. Skipping.
# "Cash to Burn (Reference)" is not valid. Skipping.
# Song 58: "Celebration"
# Song 59: "Censori Overload*"
# Song 60: "Chain Heavy"
# Song 61: "Chakras"
# "Chakras (Dreezy Reference)" is not valid. Skipping.
# Song 62: "Chakras/We Free"
# Song 63: "Champion"
# "Champion (Nick Catchdubs Remix)" is not valid. Skipping.
# "Champions (Remix)" is not valid. Skipping.
# Song 64: "Charitable Work"
# "Chicago Shit" is not valid. Skipping.
# Song 65: "Christ"
# Song 66: "Christian Dior Denim Flow"
# "Christ Is My Friend" is not valid. Skipping.
# "Christ Is My Friend" is not valid. Skipping.
# Song 67: "Christmas in Harlem"
# "Christmas in Harlem (G.O.O.D. Fridays Version)" is not valid. Skipping.
# "Die" is not valid. Skipping.
# "Digital Girl (Remix)" is not valid. Skipping.
# "Digital Girl (Remix 2)" is not valid. Skipping.
# Song 91: "DIVORCE"
# Song 92: "DJ Khaled’s Son"
# "Dogs Out (Grand Champ)" is not valid. Skipping.
# Song 93: "Doing Fine"
# Song 94: "Donda"
# Song 95: "DONDA (2012)"
# Song 96: "Donda Chant"
# "Don’t Forget ’Em (Remix)" is not valid. Skipping.
# "Don’t Get Caught" is not valid. Skipping.
# Song 97: "Don’t Give Up"
# "Don’t Go Away" is not valid. Skipping.
# "Don’t Jump (Demo)" is not valid. Skipping.
# "Don’t Like.1 (Live from Spotify SXSW 2014)" is not valid. Skipping.
# Song 98: "Don’t Look Down"
# Song 99: "Down Town"
# Song 100: "Dragon 🐉 energy [April 25, 2018]"
# Song 101: "Dream Come True"
# "Dreams (Street Remix)" is not valid. Skipping.
# Song 102: "Drive Slow"
# "Drive Slow (A-Trak Remix)" is not valid. Skipping.
# "Drive Slow (Live at Abbey Road Studios)" is not valid. Skipping.
# "Drive Slow (Remix)" is not valid. Skipping.
# "Dr. Kanye West Honorary Doctorate Speech" is not valid. Skipping.
# Song 103: "Drop Dead Gorgeous"
# Song 104: "Drunk and Hot Girls"
# "Drunk in Love (Remix)" is not valid. Skipping.
# "Eazy (Demo)" is not valid. Skipping.
# Song 105: "Echelon"
# Song 106: "Ecstasy"
# "Ego Death (Juelz & RemK Remix)" is not valid. Skipping.
# "Ego (feat. Kanye West) [Live]" is not valid. Skipping.
# "Ego (Remix)" is not valid. Skipping.
# "Ellen DeGeneres Interview: Kanye Keeps it Real" is not valid. Skipping.
# Song 107: "EMPTY"
# Song 108: "Enya"
# "Erase Me (Remix)" is not valid. Skipping.
# Song 109: "Eternal"
# Song 110: "Eternal Life"
# Song 111: "Eternal Rest"
# "E.T. (Remix)" is not valid. Skipping.
# Song 112: "Euro (Switch Hands)"
# "Evangelica" is not valid. Skipping.
# Song 113: "Ever Since"
# Song 114: "Every Hour"
# "Every Hour (Piano Solo)" is not valid. Skipping.
# "Everyone Nose (All the Girls Standing in the Line for the Bathroom) [Remix]" is not valid. Skipping.
# Song 115: "Everything"
# "Everything" is not valid. Skipping.
# Song 116: "Everything I Am"
# "Everything I Am (SNL Freestyle)" is not valid. Skipping.
# Song 117: "Everything I Got"
# Song 118: "Everything We Need"
# "Excuse Me Miss Again (Remix)" is not valid. Skipping.
# Song 119: "Eyes Closed"
# Song 120: "Eyes Closed Intro"
# Song 121: "Face Down"
# "Face Down (Demo)" is not valid. Skipping.
# "Face Down (G.O.O.D. Music Version)" is not valid. Skipping.
# Song 122: "FACTS"
# "Facts (Charlie Heat Version)" is not valid. Skipping.
# Song 123: "Fade"
# "Fade (Dimitri Vegas & Like Mike Remix)" is not valid. Skipping.
# "Faithful (Live at the North Sea Jazz Festival, 2005)" is not valid. Skipping.
# "Fallin’ (Adrenaline) [AB6IX Remix]" is not valid. Skipping.
# "Fallin’ (Adrenaline) [Live]" is not valid. Skipping.
# "Fall In Love (Mula Demo)" is not valid. Skipping.
# "Fall Out of Heaven (Demo)" is not valid. Skipping.
# Song 124: "Family Business"
# "Family Business (Instrumental)" is not valid. Skipping.
# Song 125: "Famous"
# "Famous (Demo)" is not valid. Skipping.
# "Famous (Original Version)" is not valid. Skipping.
# "Famous (Remix)" is not valid. Skipping.
# "Father Stretch (Kendrick Lamar Demo)" is not valid. Skipping.
# "Father Stretch My Hands (OG)" is not valid. Skipping.
# Song 126: "Father Stretch My Hands, Pt. 1"
# "Father Stretch My Hands Pt. 1 (Demo)" is not valid. Skipping.
# Song 127: "Father Stretch My Hands Pt. 1 & Pt. 2"
# Song 128: "Feedback"
# Song 129: "Fighting Fires"
# "Fighting Fires (Reference)" is not valid. Skipping.
# "Fighting Fires (Reference)" is not valid. Skipping.
# Song 130: "Fight With the Best"
# "Find A Way" is not valid. Skipping.
# "Finding Forever" is not valid. Skipping.
# Song 131: "Find Out"
# Song 132: "Find Your Love"
# Song 133: "Fine Line"
# Song 134: "First Time In A Long Time"
# "First Time In A Long Time (CyHi Reference)" is not valid. Skipping.
# "First Time In A Long Time (Gunna Reference)" is not valid. Skipping.
# "Flagstaff" is not valid. Skipping.
# Song 135: "Flashing Lights"
# Song 136: "Flashing Lights 2"
# "Flashing Lights (Clipse Remix)" is not valid. Skipping.
# "Flashing Lights (HL:DR & Todd Helder Remix)" is not valid. Skipping.
# "Flashing Lights (Live from VH1 Storytellers)" is not valid. Skipping.
# "Flashing Lights (Remix)" is not valid. Skipping.
# Song 137: "Flowers"
# Song 138: "FML"
# "FML (Demo)" is not valid. Skipping.
# "FML (Metro Boomin Demo)" is not valid. Skipping.
# "FML (Original Demo)" is not valid. Skipping.
# Song 139: "Follow God"
# "Follow God (Clipse Remix)" is not valid. Skipping.
# "Follow God (Dr. Dre Remix)" is not valid. Skipping.
# "Follow Your Heart" is not valid. Skipping.
# Song 140: "Forever"
# "For the Children" is not valid. Skipping.
# "Fortnite Balls Freestyle" is not valid. Skipping.
# "Fortunate (Demo)" is not valid. Skipping.
# "FourFiveSeconds (DJ Mustard Remix)" is not valid. Skipping.
# "FourFiveSeconds (Live at Power Station)" is not valid. Skipping.
# Song 141: "Frank’s Track"
# "Freedom (Reference)" is not valid. Skipping.
# "Freeee (Demo)" is not valid. Skipping.
# "Freeee (Ghost Town, Pt. 2) (Chance Version)" is not valid. Skipping.
# "Freeee (Ghost Town, Pt. 2) (Demo)" is not valid. Skipping.
# "Free Hoover" is not valid. Skipping.
# "Free (Love Everyone Demo)" is not valid. Skipping.
# "Freestyle" is not valid. Skipping.
# "Freestyle 4" is not valid. Skipping.
# "Freestyle 4 (Demo)" is not valid. Skipping.
# "Freestyle 4 (Remix)" is not valid. Skipping.
# "Freestyle from Before Infamous Accident" is not valid. Skipping.
# "Freestyle with Forbes 01" is not valid. Skipping.
# "Freestyle with Forbes 02" is not valid. Skipping.
# "Freestyle with Forbes 03" is not valid. Skipping.
# Song 142: "Friday Morning, May 25th, 2007"
# "Friends" is not valid. Skipping.
# "Grammy Family (Freestyle)" is not valid. Skipping.
# "Grammy Red Carpet Interview with Kanye West" is not valid. Skipping.
# "Grammy Red Carpet Interview with Kanye West" is not valid. Skipping.
# "Green Eggs & Ham" is not valid. Skipping.
# Song 176: "Grinder"
# "Grown Man (Remix)" is not valid. Skipping.
# Song 177: "Guilt Trip"
# Song 178: "Half Price"
# Song 179: "Hands On"
# Song 180: "Happy"
# Song 181: "Happy Birthday"
# Song 182: "Happy (Explicit)"
# Song 183: "Hard Horn Nightmare"
# "Harvard Design Speech" is not valid. Skipping.
# Song 184: "Have It Your Way"
# Song 185: "Heard ’Em Say"
# "Heard ’Em Say (Live at Abbey Road Studios)" is not valid. Skipping.
# Song 186: "Hear Our Prayers"
# "Heartbeat" is not valid. Skipping.
# "Heartbeat" is not valid. Skipping.
# Song 187: "Heartbreaker"
# Song 188: "Heartless"
# "Heartless / Pinocchio Story (Live from VH1 Storytellers)" is not valid. Skipping.
# "Heartless (Remix)" is not valid. Skipping.
# "Heartless (Studio Version)" is not valid. Skipping.
# "Heart of the City (Ain’t No Love) [Demo]" is not valid. Skipping.
# Song 189: "Heaven and Hell"
# "Heaven and Hell (Demo)" is not valid. Skipping.
# "Heaven and Hell (Symba Demo)" is not valid. Skipping.
# Song 190: "Heavy Hitters"
# Song 191: "Heavy Hitters (One Love Blend)"
# "He Gave It All (Reference)" is not valid. Skipping.
# Song 192: "Hell of a Life"
# "Hell Of A Life (Remix)" is not valid. Skipping.
# "He’s Back (Freestyle)" is not valid. Skipping.
# Song 193: "Hey Mama"
# "Hey Mama (Grammy Version)" is not valid. Skipping.
# "Hey Mama (Original Demo)" is not valid. Skipping.
# "Higher" is not valid. Skipping.
# "Higher (Remix)" is not valid. Skipping.
# Song 194: "Highlights"
# "Highlights (Madonna Demo)" is not valid. Skipping.
# "Highlights (The-Dream Demo)" is not valid. Skipping.
# "Highlights (Young Thug Demo)" is not valid. Skipping.
# "HIIII WYD (New Again Demo)" is not valid. Skipping.
# "Holding Me Back (HW Version)" is not valid. Skipping.
# Song 195: "Hold My Liquor"
# "Hold On (Live from Spotify SXSW 2014)" is not valid. Skipping.
# "Hold On (Remix)" is not valid. Skipping.
# "Hold On (Remix)" is not valid. Skipping.
# Song 196: "Hold The Line"
# Song 197: "Hold Tight"
# "Hollywood (Reference)" is not valid. Skipping.
# "Holy Water / Vogue (Live)" is not valid. Skipping.
# Song 198: "Homecoming"
# "Homecoming (Clean Version)" is not valid. Skipping.
# "Homecoming (Demo)" is not valid. Skipping.
# "Homecoming (Instrumental)" is not valid. Skipping.
# "Homecoming (Live from VH1 Storytellers)" is not valid. Skipping.
# Song 199: "Home (Windy)"
# Song 200: "Honesty"
# "Hot 107.9 Birthday Bash 2015 Freestyle" is not valid. Skipping.
# "Hot 97 Freestyle" is not valid. Skipping.
# Song 201: "Hot Sauce"
# "Hot Shit (Instrumental)" is not valid. Skipping.
# "Hurricane (6ix9ine Demo)" is not valid. Skipping.
# "Hurricane (9.30.18 Demo)" is not valid. Skipping.
# "Hurricane (Ant Clemons Demo)" is not valid. Skipping.
# "Hurricane (Big Sean & Ty Dolla $ign Version)" is not valid. Skipping.
# "Hurricane (Big Sean Version)" is not valid. Skipping.
# "Hurricane (Demo)" is not valid. Skipping.
# "Hurricane (Donda Demo)" is not valid. Skipping.
# Song 202: "Hurricane (Explicit)"
# "Hurricane (July 2020 Demo)" is not valid. Skipping.
# "Hurricane (Lil Yachty Reference)" is not valid. Skipping.
# "Hurricane (Live)" is not valid. Skipping.
# "Hurricane (Sunday Service Choir Version)" is not valid. Skipping.
# "Hurricane (Young Thug & Ty Dolla $ign Version)" is not valid. Skipping.
# "Hurry (Demo)" is not valid. Skipping.
# "Hurry (Reference Demo)" is not valid. Skipping.
# Song 203: "Hybrid"
# Song 204: "Hype"
# Song 205: "I Am a God"
# "I Am a God (TGFD Demo)" is not valid. Skipping.
# "I Am Not Here (Clearance Demo)" is not valid. Skipping.
# Song 206: "I Am Not Home"
# "I Changed My Mind (Remix)" is not valid. Skipping.
# "I Don’t Like (Remix)" is not valid. Skipping.
# "I Don’t Want to Be Liked (Freestyle)" is not valid. Skipping.
# Song 207: "I Feel Like That"
# "I Feel Like That (2017 Demo)" is not valid. Skipping.
# "I Feel Like That (Album Version)" is not valid. Skipping.
# Song 208: "I Feel Terrific"
# "If I Ain’t Got You (Kanye West Remix)" is not valid. Skipping.
# Song 209: "If I Let Go"
# "If I Shoot You Remix" is not valid. Skipping.
# "If You Know You Know (Demo)" is not valid. Skipping.
# "I Know God Breathed On This (Donda Demo)" is not valid. Skipping.
# "I Know God Breathed On This (JIK Demo)" is not valid. Skipping.
# Song 210: "I Know I Know"
# Song 211: "I’ll Be Alright"
# "Illest Motherfucker Alive" is not valid. Skipping.
# Song 212: "I’ll Fly Away"
# "Illuminati (Demo)" is not valid. Skipping.
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Kanye-west-i-love-ballin-lyrics
# Song 213: "I love ballin"
# "I Love It (Demo)" is not valid. Skipping.
# "I Love It (Remix)" is not valid. Skipping.
# Song 214: "I Love Kanye"
# Song 215: "I’m a New Man"
# Song 216: "I Met Oprah"
# Song 217: "I’m In It"
# Song 218: "Impossible"
# Song 219: "Improvise"
# "I’m the Shit (Remix)" is not valid. Skipping.
# "In Abundance (Demo)" is not valid. Skipping.
# "In Camera: Live Interview" is not valid. Skipping.
# "In Cold Blood (Remix)" is not valid. Skipping.
# "In Common (Remix)" is not valid. Skipping.
# "INDUSTRY BABY / Beat It / POWER / All Of The Lights Mashup" is not valid. Skipping.
# "INDUSTRY BABY (Clean Radio Version)" is not valid. Skipping.
# "Industry Baby (Remix)" is not valid. Skipping.
# Song 220: "I Need to Know"
# "I Need to Know (Demo)" is not valid. Skipping.
# "In For The Kill (Kanye West Remix)" is not valid. Skipping.
# Song 221: "In God’s Country"
# "In God’s Country (Demo)" is not valid. Skipping.
# "In God’s Country (Reference)" is not valid. Skipping.
# Song 222: "Insane"
# "Interview Magazine: Cover Story Excerpt" is not valid. Skipping.
# "Interviews (Interlude)" is not valid. Skipping.
# Song 223: "In The Morning"
# Song 224: "Intro"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Kanye-west-intro-2003-lyrics
# Song 225: "Intro (2003)"
# Song 226: "Intro / Every Hour / Selah"
# Song 227: "Intro (Freshmen Adjustment)"
# Song 228: "Intro (Get Well Soon)"
# Song 229: "Intro (I’m Good)"
# "Intro (Original Version)" is not valid. Skipping.
# "Intro (The “Original” College Dropout)" is not valid. Skipping.
# Song 230: "Intro (World Record Holders)"
# Song 231: "In Your Arms"
# "Is It You? (Deja Vu) (Remix)" is not valid. Skipping.
# "I Still Love H.E.R. (Instrumental)" is not valid. Skipping.
# Song 232: "I Thought About Killing You"
# Song 233: "It’s Alright"
# "It’s Only Right" is not valid. Skipping.
# Song 234: "It’s Up*"
# "I Want You (E-Smoove Remix)" is not valid. Skipping.
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Smooth-jazz-all-stars-i-want-you-janet-jackson-lyrics
# Song 235: "I Wonder"
# "I Wonder Freestyle" is not valid. Skipping.
# Song 236: "Jail"
# "Jail (Demo)" is not valid. Skipping.
# "Jail (June 2021 Demo)" is not valid. Skipping.
# Song 237: "Jail pt 2"
# Song 238: "Jam 14 (Don’t Get 2 Excited)"
# Song 239: "Jam 15"
# Song 240: "Jam 19"
# "Jeet Freestyle (The Storm Demo)" is not valid. Skipping.
# Song 241: "Jesse"
# Song 242: "Jesus Is Lord"
# Song 243: "Jesus Lord"
# "Jesus Lord (Las Vegas Version)" is not valid. Skipping.
# "Jesus Lord (Lil Yachty & Vory Reference)" is not valid. Skipping.
# Song 244: "Jesus Lord pt 2"
# Song 245: "Jesus Walks"
# "Jesus Walks (Instrumental)" is not valid. Skipping.
# Song 246: "Jesus Walks (Intro)"
# "Jesus Walks (Live)" is not valid. Skipping.
# "Jesus Walks (Live at Abbey Road Studios)" is not valid. Skipping.
# "Jesus Walks (Original Rhymefest Version)" is not valid. Skipping.
# "Jesus Walks (Remix)" is not valid. Skipping.
# "Jesus Walks (Remix) [Version 2]" is not valid. Skipping.
# "Jockin’ Jay-Z (Dopeboy Fresh) (Travis Barker Remix)" is not valid. Skipping.
# Song 247: "Jonah"
# "Jonah (Demo)" is not valid. Skipping.
# Song 248: "Jonah (Explicit)"
# "Jonah (Juelz Remix)" is not valid. Skipping.
# Song 249: "Junya"
# Song 250: "Junya (Explicit)"
# Song 251: "Junya pt 2"
# "Junya pt 2 (Explicit Version)" is not valid. Skipping.
# Song 252: "Junya Watanabe"
# "Just Soprano Freestyle" is not valid. Skipping.
# Song 253: "Kanye on the Bound 2 Video"
# Song 254: "Kanye vs. Paparazzi: “Don’t Talk”"
# Song 255: "Kanye vs. Paparazzi: “Mosquito Bully”"
# "Kanye West - 47th Grammy: Best Rap Album Acceptance Speech" is not valid. Skipping.
# "​kanye west / charlamagne interview [Full Transcript]*" is not valid. Skipping.
# "Kanye West Interview for TIME 100" is not valid. Skipping.
# "Kanye West monologue at the White House" is not valid. Skipping.
# Song 256: "Kanye West’s Grammy Honors"
# Song 257: "Kanye West’s Tattoos"
# "Kanye West Sway Freestyle" is not valid. Skipping.
# Song 258: "Kanye West Talks Fashion and Surprise Concerts in Paris"
# "Mrs. Officer (Video Version)" is not valid. Skipping.
# "Mrs. Robinson" is not valid. Skipping.
# "MTV VMAs 2015: Vanguard Acceptance Speech" is not valid. Skipping.
# Song 305: "My All (Performed by The Sunday Service Choir)"
# "My Beautiful Dark Twisted Fantasy [Booklet]" is not valid. Skipping.
# "My Drink N’ My 2 Step (Remix)" is not valid. Skipping.
# Song 306: "My Girlfriend"
# Song 307: "My Mind"
# Song 308: "My Way"
# Song 309: "My Way Home"
# Song 310: "Nah Nah Nah"
# "Nah Nah Nah (Remix)" is not valid. Skipping.
# Song 311: "NASDAQ"
# "Nebraska" is not valid. Skipping.
# Song 312: "Nebuchadnezzar*"
# Song 313: "Neva Gonna Stop Me"
# Song 314: "Never Abandon Your Family"
# "Never Abandon Your Family (Demo)" is not valid. Skipping.
# Song 315: "Never Coming Back*"
# Song 316: "Never Forgive Yourself / Yeah I Know"
# Song 317: "Never Let Me Down"
# Song 318: "Never Let Me Down (Cinematic)"
# "Never Let Me Down (Instrumental)" is not valid. Skipping.
# Song 319: "Never Let Me Go"
# Song 320: "Never Letting Go (The Stalker Song)"
# Song 321: "Never Lose"
# Song 322: "Never See Me Again"
# Song 323: "New Again"
# "New Again (Atlanta LP1 Version)" is not valid. Skipping.
# "New Again (Chris Brown Reference)" is not valid. Skipping.
# "New Again (Original Donda Version)" is not valid. Skipping.
# Song 324: "New Angels"
# Song 325: "New Body"
# "New Body (6ix9ine Demo)" is not valid. Skipping.
# "New Body (Ant Clemons Demo)" is not valid. Skipping.
# "New Body (Demo)" is not valid. Skipping.
# "New Body (Desiigner Demo)" is not valid. Skipping.
# "New God Flow (Live from Spotify SXSW 2014)" is not valid. Skipping.
# "New God Flow (Remix)" is not valid. Skipping.
# Song 326: "New Slaves"
# "New Slaves (Demo)" is not valid. Skipping.
# "New Slaves (Live on SNL)" is not valid. Skipping.
# "New York Times Interview (Excerpt)" is not valid. Skipping.
# "Nina Chop (Chance The Rapper Version)" is not valid. Skipping.
# "Nina Chop (Rihanna Version)" is not valid. Skipping.
# "Nina Chop (Young Thug Version)" is not valid. Skipping.
# Song 327: "No"
# "Nobody To Love (Bound 2 Demo)" is not valid. Skipping.
# Song 328: "No Child Left Behind"
# "No Church In the Wild Freestyle" is not valid. Skipping.
# "No Man’s Sky" is not valid. Skipping.
# Song 329: "No Mistakes"
# Song 330: "No More For Me"
# "No More Parties in LA (Demo)" is not valid. Skipping.
# "No More Parties In LA (Good Ass Job Demo)" is not valid. Skipping.
# Song 331: "No More Parties In LA"
# Song 332: "No No No"
# "No One (Remix)" is not valid. Skipping.
# "No Reason (Version 1)" is not valid. Skipping.
# Song 333: "Northside Kings"
# "Nosetalgia (Live from Spotify SXSW 2014)" is not valid. Skipping.
# "Nothin Gotta Stop" is not valid. Skipping.
# Song 334: "Nothing’s Gonna Stop Me"
# "Nothing’s Gonna Stop Me (Freestyle)" is not valid. Skipping.
# Song 335: "Not The Same"
# "Numb Encore (Remix)" is not valid. Skipping.
# "Numbers On The Boards (Live from Spotify SXSW 2014)" is not valid. Skipping.
# Song 336: "Nyce Vieux"
# Song 337: "Off The Grid"
# "Off The Grid (Demo)" is not valid. Skipping.
# Song 338: "Off The Grid (Explicit)"
# "Off the Grid (KayCyy Reference)" is not valid. Skipping.
# "Off the Grid (Reference)" is not valid. Skipping.
# "Off The Grid (Reference)" is not valid. Skipping.
# "Off The Grid (Visual Album Version)" is not valid. Skipping.
# "Ohmygod" is not valid. Skipping.
# Song 339: "Oh Yeah"
# Song 340: "Ok Ok"
# Song 341: "Ok Ok (Explicit)"
# "Ok Ok (Fivio Foreign Demo)" is not valid. Skipping.
# Song 342: "Ok Ok pt 2"
# Song 343: "Ok Ok pt 2 (Explicit)"
# "Ok Ok pt 2 (Deluxe Version)" is not valid. Skipping.
# Song 344: "On Achievement and Creativity"
# Song 345: "On Albums and Radio"
# Song 346: "On Being a Celebrity"
# Song 347: "On Bob Ezrin"
# Song 348: "On Bonnaroo Music Festival"
# Song 349: "On Business People and Corporations"
# Song 350: "On Creative Frustration"
# Song 351: "On Deadmau5"
# Song 352: "On Dreaming and Success"
# "One Day" is not valid. Skipping.
# "One I Love (Interlude)" is not valid. Skipping.
# "One Minute (Demo 2)" is not valid. Skipping.
# Song 353: "One Night Star"
# Song 354: "On Fern Mallis"
# Song 355: "On Genius and Fashion"
# Song 356: "On God"
# "On God (Demo)" is not valid. Skipping.
# Song 357: "On Hurricane Katrina"
# Song 358: "On Jimmy Kimmel"
# Song 359: "On Kid Cudi"
# Song 360: "Only One"
# "Only One (Demo)" is not valid. Skipping.
# Song 361: "“Only One” Single Art"
# Song 362: "Only Ye"
# Song 363: "On MediaTakeout"
# Song 364: "On Meeting with Donald Trump"
# Song 365: "On Michael Jordan"
# Song 366: "On Mind Control"
# Song 367: "On Obama: “I’m Past That”"
# Song 368: "On Paparazzi, Celebrities, and Activists"
# Song 369: "On Politics"
# Song 370: "On “Pop Style”"
# Song 371: "On Pusha-T"
# Song 372: "On Radio, JAY Z, and Mark Zuckerberg"
# Song 373: "On Rich People"
# Song 374: "On Saint Paul and Personal Debt"
# "On sight" is not valid. Skipping.
# Song 375: "On Sight"
# "On Sight (Demo)" is not valid. Skipping.
# Song 376: "On Taylor Swift and Artistry"
# Song 377: "On the 2009 VMAs"
# Song 378: "On the 2009 VMAs (2)"
# Song 379: "On The College Dropout’s 10-Year Anniversary"
# "On The Corner [Remix]" is not valid. Skipping.
# Song 380: "On the Grammys"
# Song 381: "On the Grammys (2)"
# "On Top of the World (Demo)" is not valid. Skipping.
# Song 382: "On Truthfulness"
# Song 383: "On Voting for Trump"
# Song 384: "On Wiz Khalifa"
# "Ops Block" is not valid. Skipping.
# "Otis Freestyle" is not valid. Skipping.
# Song 385: "Our King"
# "Our King (Reference)" is not valid. Skipping.
# Song 386: "Out of Your Mind"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Kanye-west-outro-lyrics
# Song 387: "Outro"
# Song 388: "Out The Game"
# "Over" is not valid. Skipping.
# Song 389: "Overreact"
# Song 390: "Oxford Lecture"
# Song 391: "Ozark"
# Song 392: "Ozark (full)"
# Song 393: "Pablo"
# "Pablo (Baby Keem Reference)" is not valid. Skipping.
# "Pain" is not valid. Skipping.
# "Palm Springs (Reference)" is not valid. Skipping.
# Song 394: "Paralells"
# Song 395: "Paranoid"
# "Paranoid (Remix)" is not valid. Skipping.
# "Party (Homecoming Live)" is not valid. Skipping.
# "Party (Remix)" is not valid. Skipping.
# "Perfect Bitch" is not valid. Skipping.
# Song 396: "Petals"
# "Petty Too (Original)" is not valid. Skipping.
# "Photo (Demo)" is not valid. Skipping.
# "Pick Up Your Seed" is not valid. Skipping.
# Song 397: "Pinocchio Story"
# "Pinocchio Story (Freestyle Live At Hollywood Bowl 2015)" is not valid. Skipping.
# "Piss on Your Grave (Demo)" is not valid. Skipping.
# "Piss on Your Grave (Demo)" is not valid. Skipping.
# "Piss on Your Grave (Reference)" is not valid. Skipping.
# "Play Me" is not valid. Skipping.
# "Play Me (Remix)" is not valid. Skipping.
# "Plentiful (Originals)" is not valid. Skipping.
# "Plenty Of It" is not valid. Skipping.
# Song 398: "Poem Dedicated to Martin Luther King Jr."
# "Poppin’ Tags (Remix)" is not valid. Skipping.
# "Pop Style (Demo)" is not valid. Skipping.
# "Pop Style (Single Version)" is not valid. Skipping.
# "Porno (Interlude)" is not valid. Skipping.
# Song 399: "POWER"
# "Power Freestyle" is not valid. Skipping.
# "POWER (John Mayer Remix)" is not valid. Skipping.
# "POWER (Music Video Version)" is not valid. Skipping.
# "POWER (Remix)" is not valid. Skipping.
# "Power (Saturday Night Live Version)" is not valid. Skipping.
# Song 400: "Praise God"
# Song 401: "Praise God (2020)"
# "Praise God (Demo)" is not valid. Skipping.
# Song 402: "Praise God (Explicit)"
# "Praise God (Reference)" is not valid. Skipping.
# "Prayer" is not valid. Skipping.
# "Pray It and Leave It" is not valid. Skipping.
# Song 403: "Precious / With Child / Stay On Em"
# "Presidential Campaign Rally Speech South Carolina July 2020" is not valid. Skipping.
# Song 404: "Pressure"
# "Pretty Girl Rock (Remix)" is not valid. Skipping.
# Song 405: "Problem"
# Song 406: "Promised Land Pt.1"
# Song 407: "Pt. 2"
# "Puer" is not valid. Skipping.
# "Pull Up (Freestyle)" is not valid. Skipping.
# Song 408: "Pulp Fiction"
# Song 409: "Pure"
# Song 410: "Pure Souls"
# "Pure Souls (Demo)" is not valid. Skipping.
# Song 411: "Pure Souls (Explicit)"
# "Pusha Man (Remix)" is not valid. Skipping.
# "Put On (Mega Remix)" is not valid. Skipping.
# "Put That Shit On (Remix)" is not valid. Skipping.
# "Queen Bitch (WWMD Demo)" is not valid. Skipping.
# "Question Mark" is not valid. Skipping.
# Song 412: "Quiet"
# "Raf Simons for Interview Magazine" is not valid. Skipping.
# "Raindrops (Kanye West & TGOD808 REMIX)" is not valid. Skipping.
# "Rap City Freestyle" is not valid. Skipping.
# "Rap Tarantino" is not valid. Skipping.
# Song 413: "Real Friends"
# "Real Friends (Remix)" is not valid. Skipping.
# "Real Friends (Solo Demo)" is not valid. Skipping.
# "Real Gon’ Come" is not valid. Skipping.
# "Real People (Live at the North Sea Jazz Festival, 2005)" is not valid. Skipping.
# Song 414: "Reasons To Lie"
# Song 415: "Redo"
# "​redruM (MistaJam Remix)" is not valid. Skipping.
# "Relax Your Mind (Freestyle)" is not valid. Skipping.
# "Remix #1" is not valid. Skipping.
# Song 416: "Remote Control"
# Song 417: "Remote Control (Explicit)"
# "Remote Control (Original)" is not valid. Skipping.
# Song 418: "Remote Control pt 2"
# Song 419: "Remote Control pt 2 (Explicit)"
# "Remote Control (Soulja Boy Demo)" is not valid. Skipping.
# Song 420: "Remove Worry [April 29, 2018]"
# Song 421: "Rich Nigga Drunk"
# Song 422: "RoboCop"
# "RoboCop (Live from VH1 Storytellers)" is not valid. Skipping.
# "Rock The Mic Freestyle" is not valid. Skipping.
# "Rocky, Ferg and Kanye Freestyle" is not valid. Skipping.
# Song 423: "Roommates"
# "Room To Breathe" is not valid. Skipping.
# Song 424: "Roses"
# "Rough Love (Demo)" is not valid. Skipping.
# Song 425: "Rule The World"
# Song 426: "Runaway"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Ramin-djawadi-runaway-lyrics
# "Runaway (Free Larry Hoover Benefit Concert Version)" is not valid. Skipping.
# "Runaway (Full-length Film)" is not valid. Skipping.
# "Runaway (HW Version)" is not valid. Skipping.
# "Runaway (Live from Spotify SXSW 2014)" is not valid. Skipping.
# "Runaway Love (Remix)" is not valid. Skipping.
# "Runaway (Watch The Throne Tour Freestyle)" is not valid. Skipping.
# Song 427: "Run It Up"
# "Run This Town (Live)" is not valid. Skipping.
# "R U Ready?" is not valid. Skipping.
# Song 428: "Sacramento Concert Rant"
# Song 429: "SAIC Commencement Lecture"
# Song 430: "Saint Pablo"
# "Santeria (Demo)" is not valid. Skipping.
# "Santeria (KSG Demo)" is not valid. Skipping.
# "Santeria (Original)" is not valid. Skipping.
# Song 431: "Say You Will"
# "Say You Will Freestyle" is not valid. Skipping.
# "Say You Will (Live from VH1 Storytellers)" is not valid. Skipping.
# "Say You Will (Remix)" is not valid. Skipping.
# Song 432: "School Spirit"
# "School Spirit (Instrumental)" is not valid. Skipping.
# Song 433: "School Spirit (Skit 1)"
# Song 434: "School Spirit (Skit 2)"
# Song 435: "Sci Fi"
# Song 436: "Security"
# "Security (Baby Keem Reference)" is not valid. Skipping.
# "Security (DaBaby Reference)" is not valid. Skipping.
# "Security (Demo)" is not valid. Skipping.
# Song 437: "Security [V3]"
# Song 438: "See How These Niggas Is"
# Song 439: "See Me Again"
# Song 440: "See Me Now"
# Song 441: "See You In My Nightmares"
# "See You in My Nightmares (Live from VH1 Storytellers)" is not valid. Skipping.
# Song 442: "Selah"
# "Selah (Demo)" is not valid. Skipping.
# "Selah (JESUS IS KING Demo)" is not valid. Skipping.
# Song 443: "Self Conscious"
# "Self Conscious (Poetry Style)" is not valid. Skipping.
# "Self Conscious (spoken word version)" is not valid. Skipping.
# Song 444: "Selfish"
# "Selfish (Jack Harlow Reference)" is not valid. Skipping.
# "Selfish (Shenseaa Reference)" is not valid. Skipping.
# "Selfish (Will.i.am Reference)" is not valid. Skipping.
# "Sell Your Soul (Interlude)" is not valid. Skipping.
# Song 445: "Send It Up"
# "SEND ME AWAY" is not valid. Skipping.
# "Serving God (Reference)" is not valid. Skipping.
# "Serving God (Reference)" is not valid. Skipping.
# "Serving God (Reference)" is not valid. Skipping.
# Song 446: "Set My People Free*"
# "S.E.X. (Demo)" is not valid. Skipping.
# Song 447: "Shoot It"
# Song 448: "Shoot Up"
# "Show Goes On" is not valid. Skipping.
# "Show Me a Good Time" is not valid. Skipping.
# "Showtime*" is not valid. Skipping.
# "Shy Can’t Look" is not valid. Skipping.
# "Side 2 Side (Extended Remix)" is not valid. Skipping.
# "Side Bar Take Over Freestyle" is not valid. Skipping.
# "Sierra Canyon (Glory Demo)" is not valid. Skipping.
# Song 449: "Siiiiiiiiilver Surffffeeeeer Intermission"
# Song 450: "Simulation Baptize"
# Song 451: "Sinners"
# "Sinners (Wheezy Version)" is not valid. Skipping.
# "SKELETONS (Demo)" is not valid. Skipping.
# "Ski (Remix)" is not valid. Skipping.
# Song 452: "Skit #1"
# Song 453: "Skit #2"
# Song 454: "Skit #3"
# Song 455: "Skit #4"
# Song 456: "Skurrr"
# "Skuuurr (ref)" is not valid. Skipping.
# Song 457: "Sky City"
# "Sky City (Demo)" is not valid. Skipping.
# Song 458: "Slave Name"
# Song 459: "Slavery Was a Choice Pt. 1 [May 1, 2018]"
# Song 460: "Slavery Was a Choice Pt. 2 [May 1, 2018]"
# "Slow Jamz (Instrumental)" is not valid. Skipping.
# "Smoked Up" is not valid. Skipping.
# Song 461: "So Appalled"
# "So Appalled (Freestyle/Remix)" is not valid. Skipping.
# "SOB’s Freestyle" is not valid. Skipping.
# "Someday (Ghost Town Demo)" is not valid. Skipping.
# Song 462: "Someday We’ll All Be Free"
# "SOTH Freestyle" is not valid. Skipping.
# Song 463: "Soul De La"
# Song 464: "Souleross"
# Song 465: "Soulful"
# "Souls Are Animated" is not valid. Skipping.
# "South Carolina (Donda Original)" is not valid. Skipping.
# "South Carolina (Las Vegas Version)" is not valid. Skipping.
# Song 466: "Southside Serenade"
# "Southside Serenade (Demo)" is not valid. Skipping.
# Song 467: "Spaceship"
# "Spaceship (Instrumental)" is not valid. Skipping.
# "Spaceships" is not valid. Skipping.
# "Spaceships (Live Version)" is not valid. Skipping.
# Song 468: "Space X / Alien"
# "Spaghetti" is not valid. Skipping.
# "Special (Demo)" is not valid. Skipping.
# "Speech at Harvard Graduate School of Design" is not valid. Skipping.
# "Speechless" is not valid. Skipping.
# Song 469: "Spotlight"
# Song 470: "Spread Your Wings"
# Song 471: "Stand United"
# "Stand United (French Montana reference)" is not valid. Skipping.
# "Stand Up (Remix)" is not valid. Skipping.
# "Started A Church I Wasn’t Christian Enough (Freestyle)" is not valid. Skipping.
# "Start It Up (Remix)" is not valid. Skipping.
# "Start the Show" is not valid. Skipping.
# "Start the Show" is not valid. Skipping.
# "Start the Show (Extended)" is not valid. Skipping.
# Song 472: "Statement on Beck Winning AOTY"
# "Stay Up" is not valid. Skipping.
# "Stop Looking For This (Freestyle)" is not valid. Skipping.
# "Stop Looking For This (Reference)" is not valid. Skipping.
# "Story Begins (Big Brother Demo)" is not valid. Skipping.
# Song 473: "Street Lights"
# "Street Lights (Live from VH1 Storytellers)" is not valid. Skipping.
# Song 474: "Stronger"
# "Stronger (Andrew Dawson Remix)" is not valid. Skipping.
# "Stronger (A-Trak Remix)" is not valid. Skipping.
# "Stronger (BBC Live Version)" is not valid. Skipping.
# "Stronger (Demo/Lost)" is not valid. Skipping.
# "Stronger (Live from VH1 Storytellers)" is not valid. Skipping.
# Song 475: "Stronger (Snippet)"
# Song 476: "SUCK ON MY NUTS"
# "Summer Jam Freestyle" is not valid. Skipping.
# Song 477: "Summer of Dreams"
# "Summer Sixteen (Demo)" is not valid. Skipping.
# "Superhero (Heroes & Villains) (Instrumental)" is not valid. Skipping.
# "SuperLuva (G.O.O.D. Music Remix)" is not valid. Skipping.
# "Superman" is not valid. Skipping.
# "Supernova (Calvin Harris Remix)" is not valid. Skipping.
# "Super Starred (Floatin Demo)" is not valid. Skipping.
# "Supervillain" is not valid. Skipping.
# "Survived (Ty Dolla $ign Reference)" is not valid. Skipping.
# "Survive (Reference)" is not valid. Skipping.
# "Suzy" is not valid. Skipping.
# "Sway in the Morning interview with Kanye West (Excerpts)" is not valid. Skipping.
# Song 478: "Sweat on My Face"
# Song 479: "Sweet Jesus*"
# "Sweet Serenade (Live from Spotify SXSW 2014)" is not valid. Skipping.
# Song 480: "Swole"
# "Take Me Now (Freestyle)" is not valid. Skipping.
# "Take Me to the Light (Demo)" is not valid. Skipping.
# "Take Me to the Light (Demo)" is not valid. Skipping.
# Song 481: "Take One for the Team"
# "Takeover Freestyle" is not valid. Skipping.
# "Talk to Me (I’m In It Demo)" is not valid. Skipping.
# "Teddy" is not valid. Skipping.
# "TEKKEN" is not valid. Skipping.
# "Tekken (KANGA Demo)" is not valid. Skipping.
# "Tell Me When to Go (Remix)" is not valid. Skipping.
# Song 482: "Tell The Vision"
# "Tell The Vision (Deluxe Version)" is not valid. Skipping.
# "Tell The Vision (Demo)" is not valid. Skipping.
# "Tell Your Friends (MET Gala Remix)" is not valid. Skipping.
# "Tell Your Friends (Remix)" is not valid. Skipping.
# Song 483: "Tempat Hantu"
# "Testify (Live at the North Sea Jazz Festival, 2005)" is not valid. Skipping.
# Song 484: "Thanksgiving Prayer"
# "THat Part (The Late Show Performance)" is not valid. Skipping.
# "The Best IS" is not valid. Skipping.
# "The Chase" is not valid. Skipping.
# "The College Dropout [Booklet]" is not valid. Skipping.
# "The Corner (Remix)" is not valid. Skipping.
# "The Daily’s Fashion Los Angeles Awards Speech" is not valid. Skipping.
# "The Ellen Show: On Having More Kids" is not valid. Skipping.
# "The Food (Live)" is not valid. Skipping.
# Song 485: "The Garden"
# Song 486: "The Glory"
# "The Killing Season" is not valid. Skipping.
# Song 487: "The Life Of Pablo Studio Notepad"
# Song 488: "The Making of “Ye Vs The People”"
# "The Mall" is not valid. Skipping.
# Song 489: "The McDonald’s Man"
# Song 513: "Two Words (Cinematic)"
# "Two Words (Demo)" is not valid. Skipping.
# "Two Words (Instrumental)" is not valid. Skipping.
# Song 514: "U Know"
# Song 515: "Ultimate Lie"
# "Ultimate Lie (Demo)" is not valid. Skipping.
# Song 516: "Ultralight Beam"
# "Ultralight Beam (Demo)" is not valid. Skipping.
# "Ultralight Beam (Overture Intro) [Live at Coachella 2019]" is not valid. Skipping.
# "Ultralight Beam (Overture Outro) [Live at Coachella 2019]" is not valid. Skipping.
# Song 517: "Ultralight Prayer"
# "Ultralight Prayer (Live at Coachella 2019)" is not valid. Skipping.
# Song 518: "Ultrasounds"
# "U Mad (Flint Water Crisis Remix)" is not valid. Skipping.
# "Unbreakable (Live)" is not valid. Skipping.
# "Untitled" is not valid. Skipping.
# Song 519: "Up From The Ashes"
# "Upper Echelon (Demo)" is not valid. Skipping.
# Song 520: "Use This Gospel"
# "U That Type" is not valid. Skipping.
# "Victim" is not valid. Skipping.
# "Videography of Kanye West" is not valid. Skipping.
# Song 521: "Violent Crimes"
# "Violent Crimes (Demo)" is not valid. Skipping.
# "Violent Crimes (OG)" is not valid. Skipping.
# "Violent Nights (Demo)*" is not valid. Skipping.
# "Voice Mail (Interlude)" is not valid. Skipping.
# Song 522: "Wack Niggas"
# Song 523: "Wait"
# Song 524: "Waiting for God (End of It)"
# Song 525: "Wake the Dead"
# Song 526: "Wake Up Mr. West"
# "Wakey Wakey" is not valid. Skipping.
# "Walkin’ On the Moon [Seamus Haji & Paul Emanuel Radio Edit (Bonus Track)]" is not valid. Skipping.
# Song 527: "Want It All"
# "Want You (Reference)" is not valid. Skipping.
# Song 528: "Wash Us in the Blood"
# "Wash Us in the Blood (Demo)" is not valid. Skipping.
# "Wash Us in the Blood (Demo 3)" is not valid. Skipping.
# "Wash Us in the Blood (Solo)" is not valid. Skipping.
# Song 529: "Water"
# "Water (Piano Solo)" is not valid. Skipping.
# "Water (Reference)" is not valid. Skipping.
# Song 530: "Waves"
# "Waves (Demo)" is not valid. Skipping.
# "Waves (Original Demo)" is not valid. Skipping.
# "Wavy (Feel a Way Demo)" is not valid. Skipping.
# "We Alright (Remix)" is not valid. Skipping.
# "We Are Young" is not valid. Skipping.
# Song 531: "We Can Make It Better"
# Song 532: "We Can’t Tell"
# Song 533: "We Did It Kid"
# "We Did It Kid (Dem Jointz Reference)" is not valid. Skipping.
# "We Did It Kid (Fivio Foreign & Fat Money Reference)" is not valid. Skipping.
# "We Did It Kid (June 2022 Demo)*" is not valid. Skipping.
# "We Did It Kid (March 2022 Demo)" is not valid. Skipping.
# Song 534: "We Don’t Care"
# "We Don’t Care (Instrumental)" is not valid. Skipping.
# "We Don’t Care (Live)" is not valid. Skipping.
# Song 535: "We Don’t Care (Reprise)"
# "We Fight/We Love (Remix)" is not valid. Skipping.
# Song 536: "We Free*"
# "We Free (Interlude)" is not valid. Skipping.
# "WE FUCK (Freestyle 4 Demo)" is not valid. Skipping.
# Song 537: "We Got Love"
# "We Got Love (Original)" is not valid. Skipping.
# Song 567: "You’re My Type"
# Song 568: "You Was Right"
# "Zulu" is not valid. Skipping.
# Done. Found 568 songs.

# %%
# the above fetch takes ~1-2 hours, so save artist data
# with open('kanye_west_artist.pickle', 'wb') as file:
#     pickle.dump(kanye_west_artist, file)

# %%
with open('kanye_west_artist.pickle', 'rb') as file:
    kanye_west_artist = pickle.load(file)

# %%
import unicodedata
# preprocessing for future analysis

modified_lyrics = []

for i in range(len(kanye_west_artist.songs)):
    song = kanye_west_artist.songs[i]
    song_title = song.title
    lyrics = song.lyrics
    
    lyrics_sentences = lyrics.split("\n")
    if ("Lyrics" in lyrics_sentences[0]): # Remove "Lyrics" in the beginning
        lyrics_sentences[0] = lyrics_sentences[0].split("Lyrics")[1]
    if lyrics_sentences[-1][-5:] == "Embed":
        lyrics_sentences[-1] = lyrics_sentences[-1][:-5] # Remove Embed
    if lyrics_sentences[-1][-19:] == "You might also like":
        lyrics_sentences[-1] = lyrics_sentences[-1][:-19] # Remove "You might also like"
    
    # replace unicode with actual characters
    for j in range(len(lyrics_sentences)):
        lyrics_sentences[j] = unicodedata.normalize('NFKD', lyrics_sentences[j]).encode('ASCII', 'ignore').decode() 
                
    song_details = [song_title, lyrics_sentences]
    
    modified_lyrics.append(song_details)

# %%
# word analysis for all songs combined
all_words_songs = {}
for song_details in modified_lyrics:
    song_lyrics = song_details[1]
    for sentence in song_lyrics:
        sentence_song = sentence.split(' ')
        for song_word in sentence_song:    
            # lowercasing
            song_word = song_word.lower()
            # lemmatize
            song_word = nltk.WordNetLemmatizer().lemmatize(song_word)

            # remove stopwords and empty strings
            if song_word in stopwords or song_word == "":
                continue

            if song_word not in all_words_songs:
                all_words_songs[song_word] = 0
            all_words_songs[song_word] += 1

# %%
# visualization - wordcloud for song words

# create a WordCloud object with the given parameters
wordcloud = WordCloud(width=800, height=800,
                      background_color='white',
                      min_font_size=10).generate_from_frequencies(all_words_songs)

# plot the WordCloud image using matplotlib
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)

# display the image
plt.show()

# %%
# filter the dictionary for items with frequency >= 200
all_words_songs_filtered = {k: v for k, v in all_words_songs.items() if v >= 200}

# sort the dictionary by value (frequency) in descending order
all_words_songs_sorted_freq = dict(sorted(all_words_songs_filtered.items(), key=lambda item: item[1], reverse=True))

# print the sorted dictionary
print(all_words_songs_sorted_freq)
# Out:
# {'like': 2157, "i'm": 1798, 'get': 1356, 'know': 1314, 'got': 1285, 'wa': 1068, "ain't": 824, 'nigga': 812, 'one': 670, 'need': 668, "that's": 662, 'go': 635, 'make': 614, "can't": 594, 'love': 593, 'yeah,': 583, 'let': 573, 'might': 566, 'say': 559, 'see': 548, 'back': 515, 'never': 509, 'feel': 502, 'time': 499, 'want': 496, 'tell': 483, 'right': 474, 'take': 457, 'also': 452, 'oh,': 449, 'shit': 445, 'me,': 403, 'way': 399, 'it,': 395, 'new': 394, 'still': 381, 'up,': 372, 'people': 372, 'come': 368, 'look': 360, 'could': 357, 'fuck': 357, "'cause": 353, 'wanna': 352, 'thing': 348, 'life': 345, 'yeah': 344, "gon'": 329, 'god': 329, "'em": 329, 'keep': 327, 'man': 326, 'u': 326, 'bitch': 324, 'put': 319, 'give': 315, 'gotta': 292, "y'all": 285, 'think': 280, 'even': 279, 'told': 273, 'you,': 273, 'im': 267, 'la': 267, 'hand': 265, 'good': 265, 'every': 264, 'real': 258, 'really': 254, 'uh': 247, 'girl': 243, 'ever': 243, 'oh': 241, 'everything': 236, 'made': 235, 'better': 226, 'always': 223, 'said': 222, 'would': 217, 'gonna': 216, 'uh,': 216, 'day': 213, 'now,': 208, 'like,': 207, 'something': 203, '(i': 203, 'hold': 201, 'long': 200}

# %% [markdown]
# From this, we cannot conclude anything, because the presence of curse words is a common occurrence in the rap genre. Therefore, it's difficult to say anything about the lyrics and their sentiment analysis.

# %%
# pie chart for sentences
kanye_sentences_pos = 0
kanye_sentences_neg = 0
kanye_sentences_neu = 0

kanye_sentences_sentiment_score = {}

sid = SentimentIntensityAnalyzer()

for song_details in modified_lyrics:
    song_lyrics = song_details[1]
    song_title = song_details[0]
    for sentence in song_lyrics:        
        comp = sid.polarity_scores(sentence)
        comp = comp['compound']
        if comp >= 0.5:
            kanye_sentences_pos += 1
        elif comp > -0.5 and comp < 0.5:
            kanye_sentences_neu += 1
        else:
            kanye_sentences_neg += 1
        kanye_sentences_sentiment_score[sentence] = (comp, song_title)

# %%
# Plot pie chart 
plt.pie([kanye_sentences_pos, kanye_sentences_neg, kanye_sentences_neu], labels=['pos', 'neg', 'neu'], colors=['g', 'r', 'b'], autopct='%1.1f%%')
plt.title('Kanye\'s Songs\' Sentences\' Sentiment Analysis')

# Show plot
plt.show()

# %% [markdown]
# No song level inference can be obtained. We can still say that Kanye's positive sentences have a higher share than the negative ones.

# %%
# Sort the dictionary by values in ascending order
sorted_sentences = sorted(kanye_sentences_sentiment_score.items(), key=lambda x: x[1][0])

# Iterate over the dictionary and print tweets with comp <= 0.5
for sentence, val in sorted_sentences[:20]:
    if val[0] <= -0.5:
        print(f'Comp score: {val[0]} from the song: {val[1]}')
        print(sentence)
# Out:
# Comp score: -0.9954 from the song: On Genius and Fashion
# But he wouldnt say that to Anna Wintour. He wouldnt say that to . And now his whole shit based off of rock and roll, and you trying to tell the number one rock star on the planet where the fuck he can go? So he can sell yall, some motherfucking $10,000 pair of jeans? Fuck fashion. Fuck fashion. I mean, whats the worst thing they gonna do, not help me again? Whats the worst they gonna do tell me I cant go to these shows again? Whats the worst they gonna do, tell me that because Im a musician, I dont have any ideas for clothing again? Whats the worst they gonna do, marginalize me again? And never let Pharrell get his shot, and never let Lenny get his shot?
# Comp score: -0.9852 from the song: On Dreaming and Success
# Cause most people, you know they say, they say people in my position, what ever that position is, like a celebrity or you make money, you have some type of status or some shit, you don't wanna fuck it up right? You don't wanna ruin your name, you don't wanna say anything wrong. So what you do is you get on TV you just smile, you just wave, and you try to be as safe as possible, cause you don't wanna fuck up enough, BUT I WANNA FUCK EVERYTHING UP!!! I WANNA FUCK EVERYTHING UP! I WANNA FUCK UP AS MUCH AS POSSIBLE 'CAUSE I'm STILL BEATING! As long as my heart is beating, as long as I'm dreaming. And I'mma stay kicking and dreaming, kicking and screaming, kicking and dreaming
# Comp score: 0.9816 from the song: DONDA (2012)
# I appreciate having the most nominations at the Grammys but I feel so conflicted by the fact that award shows sometimes are completely illogical. Good logic tells me smile Kanye, the world likes you again. Red or blue pill?...aaaaand Swallow. LOL. I wouldnt have the prestige I have if it wasnt partially for the Grammy's validation and I honor that
# Comp score: 0.9815 from the song: Dragon 🐉 energy [April 25, 2018]
# I said express love more because we have love but we don't express it.  My friend Tmills will always say "I love you" and it used to make me feel weird to hear that. Now I tell everyone I love them.  He sparked me to start expressing love more.

# %% [markdown]
# From this, we see that the most positive songs have a very strong positive meaning.

# %% [markdown]
# From just sentence analysis, concluding anything might be a bit difficult. Still, we can say as per the pie chart that the songs are slightly inclined towards being more positive.

# %%
# pie chart for songs

kanye_songs_pos = 0
kanye_songs_neg = 0
kanye_songs_neu = 0

kanye_songs_sentiment_score = {}

sid = SentimentIntensityAnalyzer()

for song_details in modified_lyrics:
    song_lyrics = song_details[1]
    song_title = song_details[0]
    average_comp_score = 0.0
    for sentence in song_lyrics:        
        comp = sid.polarity_scores(sentence)
        comp = comp['compound']
        average_comp_score += comp
    average_comp_score /= float(len(song_lyrics))    
    if average_comp_score >= 0.5:
        kanye_songs_pos += 1
    elif average_comp_score < 0.5 and average_comp_score > -0.5:
        kanye_songs_neu += 1
    else:
        kanye_songs_neg += 1
    kanye_songs_sentiment_score[song_title] = average_comp_score

# %%
# Plot pie chart 
plt.pie([kanye_songs_pos, kanye_songs_neg, kanye_songs_neu], labels=['pos', 'neg', 'neu'], colors=['g', 'r', 'b'], autopct='%1.1f%%')
plt.title('Kanye\'s Songs\' Sentiment Analysis')

# Show plot
plt.show()

# %% [markdown]
# As we can see from the above graph, we see that the number of positive and negative songs are more or less same, with positive having just one more.

# %%
# Sort the dictionary by values in ascending order
sorted_songs = sorted(kanye_songs_sentiment_score.items(), key=lambda x: x[1])

# Iterate over the dictionary and print songs with comp <= 0.5
for song, val in sorted_songs:
    if val <= -0.5:
        print(f'Comp score: {val}')
        print(song)
# Out:
# Comp score: -0.71718
# On Being a Celebrity
# Comp score: -0.693975
# On Hurricane Katrina
# Comp score: -0.5789666666666666
# On Obama: “I’m Past That”

# %%
# Sort the dictionary by values in descending order
sorted_songs = sorted(kanye_songs_sentiment_score.items(), key=lambda x: x[1], reverse=True)

# Iterate over the dictionary and print songs with comp >= 0.5
for song, val in sorted_songs:
    if val >= 0.5:
        print(f'Comp score: {val}')
        print(song)
# Out:
# Comp score: 0.9672
# On Truthfulness
# Comp score: 0.9513
# On Fern Mallis
# Comp score: 0.8294
# Tempat Hantu
# Comp score: 0.6385238095238097
# Kanye West’s Grammy Honors
# Comp score: 0.58845
# On Creative Frustration

# %% [markdown]
# From the above results, we can see that the positive and negative songs are more or less same in number.

# %% [markdown]
# From the sentence analysis above, we can see that the type and meaning of words and sentences used that contribute to the highest negative scores may actually show a thought process which is reflected in the most negative tweets. While this study doesn't correlate negativity in song lyrics and tweets, it gives an insight into a possibility of song lyrics representing a person's state of mind.
